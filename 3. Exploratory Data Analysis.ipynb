# %% [markdown]
# ### Descriptive analysis:
# - How many positive and negative reviews
# - How many reviews for each year

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import date
df = pd.read_csv('../Employee Reviews/DBS Reviews/All DBS Reviews/All_DBS_Reviews.csv')
df = df.drop_duplicates()
df = df[~pd.isna(df['Date'])]
df
# Out:
#            Review_type          Date                 Occupation  \
# 0     DBS Bank Reviews  18 Jun 2022                   Associate
# 1     DBS Bank Reviews  18 Jun 2022            Senior Associate
# 2     DBS Bank Reviews  17 Jun 2022    Customer Service Officer
# 3     DBS Bank Reviews  17 Jun 2022         AVP-Project Manager
# 4     DBS Bank Reviews  17 Jun 2022              Vice President
# ...                ...           ...                        ...
# 4563  DBS Bank Reviews   6 Nov 2009               Summer Intern
# 4564  DBS Bank Reviews  20 Oct 2009                     Analyst
# 4565  DBS Bank Reviews  27 Aug 2009    Assistant Vice President
# 4566  DBS Bank Reviews   3 Aug 2009    Assistant Vice President
# 4567  DBS Bank Reviews  22 Aug 2008        Vice President - DII
#
#                             Employee Type  \
# 0                        Current Employee
# 1     Current Employee, more than 5 years
# 2                        Current Employee
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4568 entries, 0 to 4567
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Review_type         4568 non-null   object
#  1   Date                4568 non-null   object
#  2   Occupation          4568 non-null   object
#  3   Employee Type       4568 non-null   object
#  4   Pros                4568 non-null   object
#  5   Cons                4568 non-null   object
#  6   Recommended Or Not  4568 non-null   object
#  7   CEO Approval        4568 non-null   object
#  8   Business Outlook    4568 non-null   object
#  9   Rating              4568 non-null   float64
# dtypes: float64(1), object(9)
# memory usage: 392.6+ KB

# %% [markdown]
# ### Number Of Reviews Per Year

# %%
good_ratings = df[df['Rating'] >= 4]
neutral_ratings = df[df['Rating'] == 3]
subpar_ratings = df[df['Rating'] <= 2]
good_ratings
# Out:
#            Review_type          Date              Occupation  \
# 0     DBS Bank Reviews  18 Jun 2022                Associate
# 1     DBS Bank Reviews  18 Jun 2022         Senior Associate
# 4     DBS Bank Reviews  17 Jun 2022           Vice President
# 5     DBS Bank Reviews  16 Jun 2022     Anonymous Contractor
# 6     DBS Bank Reviews  16 Jun 2022                   Seeder
# ...                ...           ...                     ...
# 4555  DBS Bank Reviews   2 Jan 2011                  Analyst
# 4556  DBS Bank Reviews   1 Dec 2010            Summer Intern
# 4557  DBS Bank Reviews  15 Jul 2010                  Analyst
# 4560  DBS Bank Reviews  15 Jun 2010    Relationships Manager
# 4563  DBS Bank Reviews   6 Nov 2009            Summer Intern
#
#                             Employee Type  \
# 0                        Current Employee
# 1     Current Employee, more than 5 years
# 4      Former Employee, more than 3 years
# 5                       Former Contractor
# ...

# %%
neutral_ratings
# Out:
#            Review_type          Date                    Occupation  \
# 2     DBS Bank Reviews  17 Jun 2022       Customer Service Officer
# 15    DBS Bank Reviews  14 Jun 2022                 Senior Officer
# 16    DBS Bank Reviews  14 Jun 2022    Digital Marketing Executive
# 17    DBS Bank Reviews  14 Jun 2022             Operations Analyst
# 20    DBS Bank Reviews  13 Jun 2022                 Vice President
# ...                ...           ...                           ...
# 4559  DBS Bank Reviews  27 Jun 2010
# 4561  DBS Bank Reviews   9 May 2010
# 4562  DBS Bank Reviews  18 Dec 2009
# 4565  DBS Bank Reviews  27 Aug 2009       Assistant Vice President
# 4567  DBS Bank Reviews  22 Aug 2008           Vice President - DII
#
#                             Employee Type  \
# 2                        Current Employee
# 15    Current Employee, more than 3 years
# 16     Current Employee, more than 1 year
# 17     Current Employee, more than 1 year
# ...

# %%
def get_year(dt_object):
    return dt_object[-5:-1]
good_ratings['Year'] = good_ratings['Date'].apply(get_year)
print(good_ratings['Year'].value_counts())
good_ratings['Year'].value_counts().plot(kind='bar')
# Out:
# 2021    1118
# 2022     499
# 2020     416
# 2019     359
# 2018     149
# 2017     144
# 2016     102
# 2015      68
# 2014      32
# 2013      23
# 2012      16
# 2010       3
# 2011       2
# 2009       1
# Name: Year, dtype: int64
# C:\Users\jingh\AppData\Local\Temp\ipykernel_10748\1490906020.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   good_ratings['Year'] = good_ratings['Date'].apply(get_year)
# <AxesSubplot:>

# %%
neutral_ratings
# Out:
#            Review_type          Date                    Occupation  \
# 2     DBS Bank Reviews  17 Jun 2022       Customer Service Officer
# 15    DBS Bank Reviews  14 Jun 2022                 Senior Officer
# 16    DBS Bank Reviews  14 Jun 2022    Digital Marketing Executive
# 17    DBS Bank Reviews  14 Jun 2022             Operations Analyst
# 20    DBS Bank Reviews  13 Jun 2022                 Vice President
# ...                ...           ...                           ...
# 4559  DBS Bank Reviews  27 Jun 2010
# 4561  DBS Bank Reviews   9 May 2010
# 4562  DBS Bank Reviews  18 Dec 2009
# 4565  DBS Bank Reviews  27 Aug 2009       Assistant Vice President
# 4567  DBS Bank Reviews  22 Aug 2008           Vice President - DII
#
#                             Employee Type  \
# 2                        Current Employee
# 15    Current Employee, more than 3 years
# 16     Current Employee, more than 1 year
# 17     Current Employee, more than 1 year
# ...

# %%
neutral_ratings['Year'] = neutral_ratings['Date'].apply(get_year)
print(neutral_ratings['Year'].value_counts())
neutral_ratings['Year'].value_counts().plot(kind='bar')
# Out:
# 2021    335
# 2022    160
# 2020    134
# 2019    129
# 2018     66
# 2016     44
# 2017     43
# 2015     37
# 2014     24
# 2013     18
# 2012     13
# 2011      6
# 2010      3
# 2009      2
# 2008      1
# Name: Year, dtype: int64
# C:\Users\jingh\AppData\Local\Temp\ipykernel_10748\450818355.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   neutral_ratings['Year'] = neutral_ratings['Date'].apply(get_year)
# <AxesSubplot:>

# %%
subpar_ratings['Year'] = subpar_ratings['Date'].apply(get_year)
print(subpar_ratings['Year'].value_counts())
subpar_ratings['Year'].value_counts().plot(kind='bar')
# Out:
# 2021    190
# 2020     95
# 2019     85
# 2022     80
# 2018     69
# 2017     37
# 2015     16
# 2016     14
# 2014     11
# 2013      8
# 2012      8
# 2011      6
# 2009      2
# Name: Year, dtype: int64
# C:\Users\jingh\AppData\Local\Temp\ipykernel_10748\2184381943.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subpar_ratings['Year'] = subpar_ratings['Date'].apply(get_year)
# <AxesSubplot:>

# %% [markdown]
# ### Number Of Recommended/ Neutral/ Not Recommended

# %%
df['Recommended Or Not'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
good_ratings['Recommended Or Not'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
neutral_ratings['Recommended Or Not'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
subpar_ratings['Recommended Or Not'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Further Analysis
# Before doing the bottom analysis, find the counts of the relevant recommended vs ratings and store them is a table. Can showcase the table in a presentation slide before doing the following analysis.
#
# To analyse the following kinds of ratings:
# - Those with high ratings (`good_ratings`) but not recommended
# - Those with low ratings (`subpar_ratings`) but recommended

# %%
len(df[(df['Recommended Or Not'] == "Not Recommended") & (df['Rating'] == 1)])
# Out:
# 271

# %%
subpar_ratings[subpar_ratings['Recommended Or Not'] == 'Recommended']
# Out:
#            Review_type           Date                              Occupation  \
# 110   DBS Bank Reviews   20 May 2022                    Senior Vice President
# 802   DBS Bank Reviews    7 Dec 2021                         Business Analyst
# 949   DBS Bank Reviews   25 Oct 2021                         Business Analyst
# 971   DBS Bank Reviews   20 Oct 2021             Business Analyst Entry Level
# 1106  DBS Bank Reviews  15 Sept 2021                       Anonymous Employee
# 1142  DBS Bank Reviews   8 Sept 2021                           Vice President
# 1149  DBS Bank Reviews   7 Sept 2021                       Anonymous Employee
# 1451  DBS Bank Reviews   22 Jun 2021                 Assistant Vice President
# 1460  DBS Bank Reviews   21 Jun 2021                           Senior Officer
# 1683  DBS Bank Reviews   11 May 2021                        Senior Accountant
# 1723  DBS Bank Reviews    3 May 2021                               Operations
# ...

# %%
good_ratings[good_ratings['Recommended Or Not'] == 'Not Recommended']
# Out:
#            Review_type          Date                 Occupation  \
# 7     DBS Bank Reviews  15 Jun 2022        Relationship Manager
# 89    DBS Bank Reviews  24 May 2022              Vice President
# 237   DBS Bank Reviews  20 Apr 2022          Technology Analyst
# 243   DBS Bank Reviews  19 Apr 2022                       Sales
# 272   DBS Bank Reviews  11 Apr 2022              Wealth Planner
# ...                ...           ...                        ...
# 4309  DBS Bank Reviews  31 Aug 2015          Anonymous Employee
# 4352  DBS Bank Reviews  13 May 2015        Relationship Manager
# 4395  DBS Bank Reviews  26 Nov 2014               Bancassurance
# 4446  DBS Bank Reviews   8 Mar 2014              Vice President
# 4498  DBS Bank Reviews   3 Mar 2013    Assistant Vice President
#
#                             Employee Type  \
# 7                         Former Employee
# 89    Current Employee, more than 3 years
# 237   Current Employee, more than 5 years
# ...
