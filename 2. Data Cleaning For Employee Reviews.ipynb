# %% [markdown]
# ### Analysis ideas:
# - Across time, how have the topics changed? Can also view how the topics have changed for each occupation
# - What are the aspects that cause ratings to be high?
# - Among current employees/ those who have left, what are some aspects that cause them to remain/ leave?
# - Why recommend/ not recommend DBS?
# - For those who have chosen to stay for a long period of time (e.g., more than 3 years), why have they stayed on?

# %% [markdown]
# ### To run the following codes for data cleaning, run the following command in anaconda prompt first:
# *`conda activate dbs_employee_reviews`*
#
# Main idea of script:
# - Split sentences (pros and cons) up based on new line/ fullstop
# - Add the index (review number) to each sentence
# - Preprocess the pros and cons

# %%
# import pandas as pd
# intermediate = pd.read_csv(r'C:\Users\jingh\OneDrive\Desktop\DBS Internship stuff\Employee Reviews Documents\Employee Reviews\Microsoft Reviews\All_Microsoft_reviews.csv')
# intermediate.to_excel(r'C:\Users\jingh\OneDrive\Desktop\DBS Internship stuff\Employee Reviews Documents\Employee Reviews\Microsoft Reviews\All_Microsoft_reviews.xlsx', index=False)

# %%
import re
import time
import nltk
import string
import timeit
import unidecode
import numpy as np
import pandas as pd

from bs4 import BeautifulSoup
from nltk import word_tokenize
from autocorrect import Speller
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# nltk.download('punkt')
# nltk.download('wordnet')
# nltk.download('omw-1.4')
# nltk.download('stopwords')

df = pd.read_excel('../Employee Reviews/DBS Reviews/All DBS Reviews/All DBS Reviews.xlsx').drop_duplicates().reset_index().drop(['index'],axis=1)
df = df[~pd.isna(df['Date'])]
df['Employee Status'], df['Duration'] = df['Employee Type'].str.split(',', 1).str
df = df.drop(['Employee Type'],axis=1)
df = df[['Review_type', 'Date', 'Occupation', 'Employee Status', 'Duration', 'Pros', 'Cons', 'Recommended Or Not', 'CEO Approval', 'Business Outlook', 'Rating']]
df
# Out:
# C:\Users\jingh\AppData\Local\Temp\ipykernel_8836\890466661.py:24: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   df['Employee Status'], df['Duration'] = df['Employee Type'].str.split(',', 1).str
#            Review_type          Date                 Occupation  \
# 0     DBS Bank Reviews  27 Jun 2022           Software Engineer
# 1     DBS Bank Reviews  27 Jun 2022            Senior Associate
# 2     DBS Bank Reviews  27 Jun 2022            Senior Associate
# 3     DBS Bank Reviews  27 Jun 2022         Senior Data Analyst
# 4     DBS Bank Reviews  27 Jun 2022          Graduate Associate
# ...                ...           ...                        ...
# 4593  DBS Bank Reviews   6 Nov 2009               Summer Intern
# 4594  DBS Bank Reviews  20 Oct 2009                     Analyst
# 4595  DBS Bank Reviews  27 Aug 2009    Assistant Vice President
# 4596  DBS Bank Reviews   3 Aug 2009    Assistant Vice President
# 4597  DBS Bank Reviews  22 Aug 2008        Vice President - DII
#
#         Employee Status            Duration  \
# 0      Current Employee   more than 5 years
# 1      Current Employee                 NaN
# 2      Current Employee                 NaN
# 3     Former Contractor    more than 1 year
# 4      Current Employee    more than 1 year
# ...                 ...                 ...
# 4593    Former Employee                 NaN
# 4594    Former Employee                 NaN
# 4595    Former Employee                 NaN
# 4596   Current Employee                 NaN
# 4597    Former Employee                 NaN
#
#                                                    Pros  \
# 0                     Good work life balance and salary
# 1                 Annual leave granted per year is good
# 2               Infrastructure is good and the ambience
# 3     opportunities to work on interesting and chall...
# 4                 you get exposed to multiple skillsets
# ...                                                 ...
# 4593  The environment at DBS is very friendly. My co...
# 4594                      the brand name of the company
# 4595  The brand name in the Asia arena; stability, l...
# 4596  people are not the smartest around; hence very...
# 4597  DBS has good job security for personel, the pa...
#
#                                                    Cons Recommended Or Not  \
# 0     Hierarchical, does not listen to feedback from...        Recommended
# 1     Number of carry forward leave allow is too little            Neutral
# 2     No work Life balance.. managers force to work ...    Not Recommended
# 3        some politics, heavy workload on some projects            Neutral
# 4         you need to get exposed to multiple skillsets            Neutral
# ...                                                 ...                ...
# 4593  No much to criticize or comment about. I guess...        Recommended
# 4594  my boss was a slave driver who did not promote...    Not Recommended
# 4595  Very bureaucratic. Seniority matters the most,...            Neutral
# 4596  far too many deadwood esp in middle management...            Neutral
# 4597  DBS is a big dinosaur, as in slow to respond t...    Not Recommended
#
#          CEO Approval Business Outlook  Rating
# 0         Recommended      Recommended     4.0
# 1             Neutral          Neutral     4.0
# 2             Neutral          Neutral     1.0
# 3             Neutral          Neutral     3.0
# 4             Neutral          Neutral     4.0
# ...               ...              ...     ...
# 4593      Recommended          Neutral     5.0
# 4594          Neutral          Neutral     2.0
# 4595          Neutral          Neutral     3.0
# 4596  Not Recommended          Neutral     2.0
# 4597          Neutral          Neutral     3.0
#
# [4598 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4598 entries, 0 to 4597
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Review_type         4598 non-null   object
#  1   Date                4598 non-null   object
#  2   Occupation          4598 non-null   object
#  3   Employee Status     4598 non-null   object
#  4   Duration            2650 non-null   object
#  5   Pros                4598 non-null   object
#  6   Cons                4598 non-null   object
#  7   Recommended Or Not  4598 non-null   object
#  8   CEO Approval        4598 non-null   object
#  9   Business Outlook    4598 non-null   object
#  10  Rating              4598 non-null   float64
# dtypes: float64(1), object(10)
# memory usage: 560.1+ KB

# %% [markdown]
# ### Break up all pros and cons based on new line
# Rationale for breaking up sentences: BERTopic maps a review to a certain topic (One to one mapping)

# %%
def split_sentences_after_new_line(sentence):
    return sentence.split('\n')
def split_sentences_after_fullstop(sentence_list):
    lis = []
    for i in sentence_list:
        lis.extend(i.split('. '))
    return lis
def split_sentences_after_semicolon(sentence_list):
    lis = []
    for i in sentence_list:
        lis.extend(i.split('; '))
    return lis
def split_sentences_after_exclamation(sentence_list):
    lis = []
    for i in sentence_list:
        lis.extend(i.split('! '))
    return lis

# %%
def remove_newlines_tabs(text):
    """
    This function will remove all the occurrences of newlines, tabs, and combinations like: \\n, \\.
    
    arguments:
        input_text: "text" of type "String". 
                    
    return:
        value: "text" after removal of newlines, tabs, \\n, \\ characters.
        
    Example:
    Input : This is her \\ first day at this place.\n Please,\t Be nice to her.\\n
    Output : This is her first day at this place. Please, Be nice to her. 
    
    """
    
    # Replacing all the occurrences of \n,\\n,\t,\\ with a space.
    Formatted_text = text.replace('\\n', '').replace('\n', '').replace('\\t','').replace('\\', '').replace('\r','')
    return Formatted_text

def remove_whitespace(text):
    """ This function will remove 
        extra whitespaces from the text
    arguments:
        input_text: "text" of type "String". 
                    
    return:
        value: "text" after extra whitespaces removed .
        
    Example:
    Input : How   are   you   doing   ?
    Output : How are you doing ?     
        
    """
    pattern = re.compile(r'\s+') 
    Without_whitespace = re.sub(pattern, ' ', text)
    # There are some instances where there is no space after '?' & ')', 
    # So I am replacing these with one space so that It will not consider two words as one token.
    text = Without_whitespace.replace('?', ' ? ').replace(')', ') ')
    return text

# %%
CONTRACTION_MAP = {
"ain't": "is not",
"aren't": "are not",
"can't": "cannot",
"can't've": "cannot have",
"'cause": "because",
"could've": "could have",
"couldn't": "could not",
"couldn't've": "could not have",
"didn't": "did not",
"doesn't": "does not",
"don't": "do not",
"hadn't": "had not",
"hadn't've": "had not have",
"hasn't": "has not",
"haven't": "have not",
"he'd": "he would",
"he'd've": "he would have",
"he'll": "he will",
"he'll've": "he he will have",
"he's": "he is",
"how'd": "how did",
"how'd'y": "how do you",
"how'll": "how will",
"how's": "how is",
"i'd": "i would",
"i'd've": "i would have",
"i'll": "i will",
"i'll've": "i will have",
"i'm": "i am",
"i've": "i have",
"isn't": "is not",
"it'd": "it would",
"it'd've": "it would have",
"it'll": "it will",
"it'll've": "it will have",
"it's": "it is",
"let's": "let us",
"ma'am": "madam",
"mayn't": "may not",
"might've": "might have",
"mightn't": "might not",
"mightn't've": "might not have",
"must've": "must have",
"mustn't": "must not",
"mustn't've": "must not have",
"needn't": "need not",
"needn't've": "need not have",
"o'clock": "of the clock",
"oughtn't": "ought not",
"oughtn't've": "ought not have",
"shan't": "shall not",
"sha'n't": "shall not",
"shan't've": "shall not have",
"she'd": "she would",
"she'd've": "she would have",
"she'll": "she will",
"she'll've": "she will have",
"she's": "she is",
"should've": "should have",
"shouldn't": "should not",
"shouldn't've": "should not have",
"so've": "so have",
"so's": "so as",
"that'd": "that would",
"that'd've": "that would have",
"that's": "that is",
"there'd": "there would",
"there'd've": "there would have",
"there's": "there is",
"they'd": "they would",
"they'd've": "they would have",
"they'll": "they will",
"they'll've": "they will have",
"they're": "they are",
"they've": "they have",
"to've": "to have",
"wasn't": "was not",
"we'd": "we would",
"we'd've": "we would have",
"we'll": "we will",
"we'll've": "we will have",
"we're": "we are",
"we've": "we have",
"weren't": "were not",
"what'll": "what will",
"what'll've": "what will have",
"what're": "what are",
"what's": "what is",
"what've": "what have",
"when's": "when is",
"when've": "when have",
"where'd": "where did",
"where's": "where is",
"where've": "where have",
"who'll": "who will",
"who'll've": "who will have",
"who's": "who is",
"who've": "who have",
"why's": "why is",
"why've": "why have",
"will've": "will have",
"won't": "will not",
"won't've": "will not have",
"would've": "would have",
"wouldn't": "would not",
"wouldn't've": "would not have",
"y'all": "you all",
"y'all'd": "you all would",
"y'all'd've": "you all would have",
"y'all're": "you all are",
"y'all've": "you all have",
"you'd": "you would",
"you'd've": "you would have",
"you'll": "you will",
"you'll've": "you will have",
"you're": "you are",
"you've": "you have",
}
# The code for expanding contraction words
def expand_contractions(text, contraction_mapping =  CONTRACTION_MAP):
    """expand shortened words to the actual form.
       e.g. don't to do not
    
       arguments:
            input_text: "text" of type "String".
         
       return:
            value: Text with expanded form of shorthened words.
        
       Example: 
       Input : ain't, aren't, can't, cause, can't've
       Output :  is not, are not, cannot, because, cannot have 
    
     """
    # Tokenizing text into tokens.
    list_Of_tokens = text.split(' ')

    # Checking for whether the given token matches with the Key & replacing word with key's value.
    
    # Check whether Word is in lidt_Of_tokens or not.
    for Word in list_Of_tokens: 
        # Check whether found word is in dictionary "Contraction Map" or not as a key. 
         if Word in CONTRACTION_MAP: 
                # If Word is present in both dictionary & list_Of_tokens, replace that word with the key value.
                list_Of_tokens = [item.replace(Word, CONTRACTION_MAP[Word]) for item in list_Of_tokens]
                
    # Converting list of tokens to String.
    String_Of_tokens = ' '.join(str(e) for e in list_Of_tokens) 
    return String_Of_tokens

def removing_special_characters(text):
    """Removing all the special characters except the one that is passed within 
       the regex to match, as they have imp meaning in the text provided.
   
    
    arguments:
         input_text: "text" of type "String".
         
    return:
        value: Text with removed special characters that don't require.
        
    Example: 
    Input : Hello, K-a-j-a-l. Thi*s is $100.05 : the payment that you will recieve! (Is this okay?) 
    Output :  Hello, Kajal. This is $100.05 : the payment that you will recieve! Is this okay?
    
   """
    # The formatted text after removing not necessary punctuations.
    Formatted_Text = re.sub(r"[^a-zA-Z0-9:$-,%.?!]+", ' ', text) 
    # In the above regex expression,I am providing necessary set of punctuations that are frequent in this particular dataset.
    return Formatted_Text

# %%
def joining(text):
    return ' '.join(text)
def to_lower(text):
    return text.lower()
def removing_x000d(text):
    text = text.replace(' x000d ', '')
    return text

# %%
df['Pros']=df['Pros'].apply(to_lower).apply(split_sentences_after_new_line)
df['Cons']=df['Cons'].apply(to_lower).apply(split_sentences_after_new_line)
df['Pros']=df['Pros'].apply(split_sentences_after_fullstop).apply(split_sentences_after_semicolon)
df['Cons']=df['Cons'].apply(split_sentences_after_fullstop).apply(split_sentences_after_semicolon)
df
# Out:
#            Review_type          Date                 Occupation  \
# 0     DBS Bank Reviews  27 Jun 2022           Software Engineer
# 1     DBS Bank Reviews  27 Jun 2022            Senior Associate
# 2     DBS Bank Reviews  27 Jun 2022            Senior Associate
# 3     DBS Bank Reviews  27 Jun 2022         Senior Data Analyst
# 4     DBS Bank Reviews  27 Jun 2022          Graduate Associate
# ...                ...           ...                        ...
# 4593  DBS Bank Reviews   6 Nov 2009               Summer Intern
# 4594  DBS Bank Reviews  20 Oct 2009                     Analyst
# 4595  DBS Bank Reviews  27 Aug 2009    Assistant Vice President
# 4596  DBS Bank Reviews   3 Aug 2009    Assistant Vice President
# 4597  DBS Bank Reviews  22 Aug 2008        Vice President - DII
#
#         Employee Status            Duration  \
# 0      Current Employee   more than 5 years
# 1      Current Employee                 NaN
# 2      Current Employee                 NaN
# 3     Former Contractor    more than 1 year
# 4      Current Employee    more than 1 year
# ...                 ...                 ...
# 4593    Former Employee                 NaN
# 4594    Former Employee                 NaN
# 4595    Former Employee                 NaN
# 4596   Current Employee                 NaN
# 4597    Former Employee                 NaN
#
#                                                    Pros  \
# 0                   [good work life balance and salary]
# 1               [annual leave granted per year is good]
# 2             [infrastructure is good and the ambience]
# 3     [opportunities to work on interesting and chal...
# 4               [you get exposed to multiple skillsets]
# ...                                                 ...
# 4593  [the environment at dbs is very friendly, my c...
# 4594                    [the brand name of the company]
# 4595  [the brand name in the asia arena, stability, ...
# 4596  [people are not the smartest around, hence ver...
# 4597  [dbs has good job security for personel, the p...
#
#                                                    Cons Recommended Or Not  \
# 0     [hierarchical, does not listen to feedback fro...        Recommended
# 1     [number of carry forward leave allow is too li...            Neutral
# 2     [no work life balance., managers force to work...    Not Recommended
# 3      [some politics, heavy workload on some projects]            Neutral
# 4       [you need to get exposed to multiple skillsets]            Neutral
# ...                                                 ...                ...
# 4593  [no much to criticize or comment about, i gues...        Recommended
# 4594  [my boss was a slave driver who did not promot...    Not Recommended
# 4595  [very bureaucratic, seniority matters the most...            Neutral
# 4596  [far too many deadwood esp in middle managemen...            Neutral
# 4597  [dbs is a big dinosaur, as in slow to respond ...    Not Recommended
#
#          CEO Approval Business Outlook  Rating
# 0         Recommended      Recommended     4.0
# 1             Neutral          Neutral     4.0
# 2             Neutral          Neutral     1.0
# 3             Neutral          Neutral     3.0
# 4             Neutral          Neutral     4.0
# ...               ...              ...     ...
# 4593      Recommended          Neutral     5.0
# 4594          Neutral          Neutral     2.0
# 4595          Neutral          Neutral     3.0
# 4596  Not Recommended          Neutral     2.0
# 4597          Neutral          Neutral     3.0
#
# [4598 rows x 11 columns]

# %% [markdown]
# ### Appending index to review

# %%
pros_and_idx_lis = []
cons_and_idx_lis = []

for i in range(len(df)):
    date = [df.loc[i, 'Date']] * len(df.loc[i, 'Pros']) 
    occupation = [df.loc[i, 'Occupation']] * len(df.loc[i, 'Pros'])
    employee_status = [df.loc[i, 'Employee Status']] * len(df.loc[i, 'Pros'])
    duration = [df.loc[i, 'Duration']] * len(df.loc[i, 'Pros'])
    pros = df.loc[i, 'Pros']
    recommended_or_not = [df.loc[i, 'Recommended Or Not']] * len(df.loc[i, 'Pros']) 
    ceo_approval = [df.loc[i, 'CEO Approval']] * len(df.loc[i, 'Pros'])
    business_outlook = [df.loc[i, 'Business Outlook']] * len(df.loc[i, 'Pros'])
    index = [i] * len(df.loc[i, 'Pros'])
    pros_and_idx_lis.append(list(zip(date, occupation, employee_status, duration, pros, recommended_or_not,\
                                     ceo_approval, business_outlook, index)))
    
    date = [df.loc[i, 'Date']] * len(df.loc[i, 'Cons'])
    occupation = [df.loc[i, 'Occupation']] * len(df.loc[i, 'Cons'])
    employee_status = [df.loc[i, 'Employee Status']] * len(df.loc[i, 'Cons'])
    duration = [df.loc[i, 'Duration']] * len(df.loc[i, 'Cons'])
    cons = df.loc[i, 'Cons']
    recommended_or_not = [df.loc[i, 'Recommended Or Not']] * len(df.loc[i, 'Cons']) 
    ceo_approval = [df.loc[i, 'CEO Approval']] * len(df.loc[i, 'Cons'])
    business_outlook = [df.loc[i, 'Business Outlook']] * len(df.loc[i, 'Cons'])
    index = [i] * len(df.loc[i, 'Cons'])
    cons_and_idx_lis.append(list(zip(date, occupation, employee_status, duration, cons, recommended_or_not,\
                                     ceo_approval, business_outlook, index)))
pros_and_idx_lis
# Out:
# [[('27 Jun 2022 ',
#    ' Software Engineer',
#    'Current Employee',
#    ' more than 5 years',
#    'good work life balance and salary',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    0)],
#  [('27 Jun 2022 ',
#    ' Senior Associate',
#    'Current Employee',
#    nan,
#    'annual leave granted per year is good',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    1)],
#  [('27 Jun 2022 ',
#    ' Senior Associate',
#    'Current Employee',
#    nan,
#    'infrastructure is good and the ambience',
#    'Not Recommended',
#    'Neutral',
#    'Neutral',
#    2)],
#  [('27 Jun 2022 ',
#    ' Senior Data Analyst',
#    'Former Contractor',
#    ' more than 1 year',
#    'opportunities to work on interesting and challenging projects',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    3)],
#  [('27 Jun 2022 ',
#    ' Graduate Associate',
#    'Current Employee',
#    ' more than 1 year',
#    'you get exposed to multiple skillsets',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    4)],
#  [('27 Jun 2022 ',
#    ' Engineer',
#    'Current Employee',
#    nan,
#    'great learning and nice culture',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    5)],
#  [('27 Jun 2022 ',
#    ' Anonymous Employee',
#    'Current Employee',
#    ' more than 8 years',
#    'office culture (subjective to team)',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    6)],
#  [('26 Jun 2022 ',
#    ' Senior Associate',
#    'Current Employee',
#    nan,
#    'good benefits and culture in it',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    7)],
#  [('26 Jun 2022 ',
#    ' Anonymous Employee',
#    'Current Employee',
#    ' more than 3 years',
#    'work culture',
#    'Recommended',
#    'Neutral',
#    'Recommended',
#    8),
#   ('26 Jun 2022 ',
#    ' Anonymous Employee',
#    'Current Employee',
#    ' more than 3 years',
#    '',
#    'Recommended',
#    'Neutral',
#    'Recommended',
#    8),
#   ('26 Jun 2022 ',
#    ' Anonymous Employee',
#    'Current Employee',
#    ' more than 3 years',
#    'pay packages.',
#    'Recommended',
#    'Neutral',
#    'Recommended',
#    8),
#   ('26 Jun 2022 ',
#    ' Anonymous Employee',
#    'Current Employee',
#    ' more than 3 years',
#    'annual leaves.',
#    'Recommended',
#    'Neutral',
#    'Recommended',
#    8),
#   ('26 Jun 2022 ',
#    ' Anonymous Employee',
#    'Current Employee',
#    ' more than 3 years',
#    'career opportunities.',
#    'Recommended',
#    'Neutral',
#    'Recommended',
#    8)],
#  [('26 Jun 2022 ',
#    ' AVP-Java Developer',
#    'Former Employee',
#    ' more than 3 years',
#    'good technology stack and high visibility',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    9)],
#  [('26 Jun 2022 ',
#    ' Relationship Manager',
#    'Former Employee',
#    ' more than 1 year',
#    'able to express creativity freely and gain recognition',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    10)],
#  [('25 Jun 2022 ',
#    ' Vice President - Technology',
#    'Current Employee',
#    nan,
#    'good place to work here',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    11)],
#  [('25 Jun 2022 ',
#    ' Senior Associate',
#    'Current Employee',
#    nan,
#    'collaborative team members which makes it bearable with work',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    12)],
#  [('25 Jun 2022 ',
#    ' Senior Associate',
#    'Current Employee',
#    ' more than 10 years',
#    'excellent, scope for learning, etc',
#    'Recommended',
#    'Recommended',
#    'Neutral',
#    13)],
#  [('24 Jun 2022 ',
#    ' Anonymous Employee',
#    'Current Employee',
#    ' more than 5 years',
#    'work life balance',
#    'Not Recommended',
#    'Recommended',
#    'Not Recommended',
#    14),
#   ('24 Jun 2022 ',
#    ' Anonymous Employee',
#    'Current Employee',
#    ' more than 5 years',
#    'salary is not too bad',
#    'Not Recommended',
#    'Recommended',
#    'Not Recommended',
#    14),
#   ('24 Jun 2022 ',
#    ' Anonymous Employee',
#    'Current Employee',
#    ' more than 5 years',
#    '',
#    'Not Recommended',
#    'Recommended',
#    'Not Recommended',
#    14),
#   ('24 Jun 2022 ',
#    ' Anonymous Employee',
#    'Current Employee',
#    ' more than 5 years',
#    "that's all",
#    'Not Recommended',
#    'Recommended',
#    'Not Recommended',
#    14)],
#  [('24 Jun 2022 ',
#    ' Credit Analyst',
#    'Current Employee',
#    ' less than 1 year',
#    'usually no need to ot',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    15)],
#  [('23 Jun 2022 ',
#    ' Human Resources Generalist',
#    'Former Employee',
#    nan,
#    'very good work culture and motivating seniors.',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    16),
#   ('23 Jun 2022 ',
#    ' Human Resources Generalist',
#    'Former Employee',
#    nan,
#    'comfortable infrastructure.',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    16),
#   ('23 Jun 2022 ',
#    ' Human Resources Generalist',
#    'Former Employee',
#    nan,
#    'overall, a nice working experience.',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    16)],
#  [('23 Jun 2022 ',
#    ' WPM',
#    'Former Employee',
#    ' less than 1 year',
#    'good pay with allowance_x000d_',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    17),
#   ('23 Jun 2022 ',
#    ' WPM',
#    'Former Employee',
#    ' less than 1 year',
#    '21 days leave',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    17)],
#  [('23 Jun 2022 ',
#    ' Senior Executive',
#    'Former Contractor',
#    ' more than 1 year',
#    'work life balance and caring manager',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    18)],
#  [('23 Jun 2022 ',
#    ' Relationship Manager',
#    'Current Employee',
#    nan,
#    '-staff benefits ',
#    'Neutral',
#    'Recommended',
#    'Neutral',
#    19),
#   ('23 Jun 2022 ',
#    ' Relationship Manager',
#    'Current Employee',
#    nan,
#    '- colleagues ',
#    'Neutral',
#    'Recommended',
#    'Neutral',
#    19),
#   ('23 Jun 2022 ',
#    ' Relationship Manager',
#    'Current Employee',
#    nan,
#    '- flexible working hours',
#    'Neutral',
#    'Recommended',
#    'Neutral',
#    19)],
#  [('22 Jun 2022 ',
#    ' ',
#    'Current Employee',
#    ' less than 1 year',
#    "no pros to this company...i didn't like the work culture.management is svery strict to come to the office eve if you are nor feeling well for 3 days",
#    'Neutral',
#    'Not Recommended',
#    'Neutral',
#    20),
#   ('22 Jun 2022 ',
#    ' ',
#    'Current Employee',
#    ' less than 1 year',
#    'one of the worst management i have seen',
#    'Neutral',
#    'Not Recommended',
#    'Neutral',
#    20)],
#  [('22 Jun 2022 ',
#    ' Technical Developer',
#    'Former Employee',
#    ' less than 1 year',
#    'stress free work in my team',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    21)],
#  [('20 Jun 2022 ',
#    ' Banker',
#    'Current Employee',
#    ' more than 1 year',
#    'employee benefits, it solving efficiency',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    22)],
#  [('20 Jun 2022 ',
#    ' Wealth Manager',
#    'Current Employee',
#    ' more than 1 year',
#    'great learning experience and healthy environment',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    23)],
#  [('20 Jun 2022 ',
#    ' Customer Service Officer',
#    'Current Contractor',
#    ' less than 1 year',
#    'friendly colleagues',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    24),
#   ('20 Jun 2022 ',
#    ' Customer Service Officer',
#    'Current Contractor',
#    ' less than 1 year',
#    'decent welfare and working hours',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    24)],
#  [('20 Jun 2022 ',
#    ' Bank Teller',
#    'Former Employee',
#    nan,
#    'nothing special',
#    'Not Recommended',
#    'Neutral',
#    'Not Recommended',
#    25),
#   ('20 Jun 2022 ',
#    ' Bank Teller',
#    'Former Employee',
#    nan,
#    'no different than any other banks',
#    'Not Recommended',
#    'Neutral',
#    'Not Recommended',
#    25)],
#  [('20 Jun 2022 ',
#    ' Anonymous Employee',
#    'Current Employee',
#    ' more than 1 year',
#    'good work life balance_x000d_',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    26),
#   ('20 Jun 2022 ',
#    ' Anonymous Employee',
#    'Current Employee',
#    ' more than 1 year',
#    'good benefits',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    26)],
#  [('19 Jun 2022 ',
#    ' Project Management Office (PMO)',
#    'Former Contractor',
#    ' less than 1 year',
#    'hard to say, didnt have an enjoyable time there',
#    'Not Recommended',
#    'Not Recommended',
#    'Neutral',
#    27)],
#  [('18 Jun 2022 ',
#    ' Associate',
#    'Current Employee',
#    nan,
#    'friendly environment and attractive package',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    28)],
#  [('18 Jun 2022 ',
#    ' Senior Associate',
#    'Current Employee',
#    ' more than 5 years',
#    'employee growth_x000d_',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    29),
#   ('18 Jun 2022 ',
#    ' Senior Associate',
#    'Current Employee',
#    ' more than 5 years',
#    'end to end management_x000d_',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    29),
#   ('18 Jun 2022 ',
#    ' Senior Associate',
#    'Current Employee',
#    ' more than 5 years',
#    'good hikes_x000d_',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    29),
#   ('18 Jun 2022 ',
#    ' Senior Associate',
#    'Current Employee',
#    ' more than 5 years',
#    'work life balance as well_x000d_',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    29),
#   ('18 Jun 2022 ',
#    ' Senior Associate',
#    'Current Employee',
#    ' more than 5 years',
#    'good management',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    29)],
#  [('18 Jun 2022 ',
#    ' Anonymous Employee',
#    'Current Employee',
#    nan,
#    'good company, and good benefit',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    30)],
#  [('18 Jun 2022 ',
#    ' Customer Service Associate',
#    'Former Contractor',
#    ' less than 1 year',
#    'high salary',
#    'Not Recommended',
#    'Neutral',
#    'Not Recommended',
#    31),
#   ('18 Jun 2022 ',
#    ' Customer Service Associate',
#    'Former Contractor',
#    ' less than 1 year',
#    'regular working hours',
#    'Not Recommended',
#    'Neutral',
#    'Not Recommended',
#    31)],
#  [('17 Jun 2022 ',
#    ' Anonymous Employee',
#    'Current Employee',
#    nan,
#    'good benefits_x000d_',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    32),
#   ('17 Jun 2022 ',
#    ' Anonymous Employee',
#    'Current Employee',
#    nan,
#    'medical leave_x000d_',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    32),
#   ('17 Jun 2022 ',
#    ' Anonymous Employee',
#    'Current Employee',
#    nan,
#    'annual leave _x000d_',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    32),
#   ('17 Jun 2022 ',
#    ' Anonymous Employee',
#    'Current Employee',
#    nan,
#    'na_x000d_',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    32),
#   ('17 Jun 2022 ',
#    ' Anonymous Employee',
#    'Current Employee',
#    nan,
#    'na',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    32)],
#  [('17 Jun 2022 ',
#    ' Associate',
#    'Current Employee',
#    ' more than 3 years',
#    'good staff benefits and work life',
#    'Recommended',
#    'Neutral',
#    'Recommended',
#    33)],
#  [('17 Jun 2022 ',
#    ' Customer Service Officer',
#    'Current Employee',
#    nan,
#    '- competitive salary _x000d_',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    34),
#   ('17 Jun 2022 ',
#    ' Customer Service Officer',
#    'Current Employee',
#    nan,
#    '- good teammates',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    34)],
#  [('17 Jun 2022 ',
#    ' Vice President',
#    'Former Employee',
#    ' more than 3 years',
#    '- manager is good_x000d_',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    35),
#   ('17 Jun 2022 ',
#    ' Vice President',
#    'Former Employee',
#    ' more than 3 years',
#    '- a lot of new things to learn',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    35)],
#  [('16 Jun 2022 ',
#    ' Anonymous Contractor',
#    'Former Contractor',
#    nan,
#    '-recognised employer_x000d_',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    36),
#   ('16 Jun 2022 ',
#    ' Anonymous Contractor',
#    'Former Contractor',
#    nan,
#    '-have budget for employee gatherings',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    36)],
#  [('16 Jun 2022 ',
#    ' Seeder',
#    'Current Employee',
#    ' more than 1 year',
#    '-most people are friendly and willing to help_x000d_',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    37),
#   ('16 Jun 2022 ',
#    ' Seeder',
#    'Current Employee',
#    ' more than 1 year',
#    '-hr for the seeder programme is super helpful and we can always approach them for any issues/ help_x000d_',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    37),
#   ('16 Jun 2022 ',
#    ' Seeder',
#    'Current Employee',
#    ' more than 1 year',
#    '-pretty good support system for the programme',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    37)],
#  [('15 Jun 2022 ',
#    ' Relationship Manager',
#    'Former Employee',
#    nan,
#    'good pay and good benefits',
#    'Not Recommended',
#    'Neutral',
#    'Recommended',
#    38)],
#  [('15 Jun 2022 ',
#    ' Officer',
#    'Former Employee',
#    nan,
#    'have ot pay but can claim 30 hours only',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    39)],
#  [('15 Jun 2022 ',
#    ' Sales Associate',
#    'Current Employee',
#    ' less than 1 year',
#    'good boss',
#    'Recommended',
#    'Not Recommended',
#    'Neutral',
#    40),
#   ('15 Jun 2022 ',
#    ' Sales Associate',
#    'Current Employee',
#    ' less than 1 year',
#    'attractive perks',
#    'Recommended',
#    'Not Recommended',
#    'Neutral',
#    40),
#   ('15 Jun 2022 ',
#    ' Sales Associate',
#    'Current Employee',
#    ' less than 1 year',
#    'everyone is very nice',
#    'Recommended',
#    'Not Recommended',
#    'Neutral',
#    40)],
#  [('15 Jun 2022 ',
#    ' Deputy Manager Sales',
#    'Former Employee',
#    ' more than 3 years',
#    'internal mobility,staff benefits,1 hour early off per week',
#    'Recommended',
#    'Recommended',
#    'Not Recommended',
#    41)],
#  [('15 Jun 2022 ',
#    ' Private Banking Associate',
#    'Current Employee',
#    nan,
#    'good progression if you work hard',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    42)],
#  [('15 Jun 2022 ',
#    ' AVP-Sales',
#    'Former Employee',
#    ' more than 3 years',
#    'stable firm to work for',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    43)],
#  [('15 Jun 2022 ',
#    ' Analyst',
#    'Current Contractor',
#    ' less than 1 year',
#    'good place to learn a lot.',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    44)],
#  [('14 Jun 2022 ',
#    ' Analyst',
#    'Current Employee',
#    ' more than 3 years',
#    'employee benefits are good, bonus are generous too',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    45),
#   ('14 Jun 2022 ',
#    ' Analyst',
#    'Current Employee',
#    ' more than 3 years',
#    'colleagues are helpful and very family oriented environment.',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    45)],
#  [('14 Jun 2022 ',
#    ' Senior Officer',
#    'Current Employee',
#    ' more than 3 years',
#    'work life balance_x000d_',
#    'Not Recommended',
#    'Not Recommended',
#    'Neutral',
#    46),
#   ('14 Jun 2022 ',
#    ' Senior Officer',
#    'Current Employee',
#    ' more than 3 years',
#    'not too much ot',
#    'Not Recommended',
#    'Not Recommended',
#    'Neutral',
#    46)],
#  [('14 Jun 2022 ',
#    ' Digital Marketing Executive',
#    'Current Employee',
#    ' more than 1 year',
#    '- high growth_x000d_',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    47),
#   ('14 Jun 2022 ',
#    ' Digital Marketing Executive',
#    'Current Employee',
#    ' more than 1 year',
#    '- attractive to tech leaders_x000d_',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    47),
#   ('14 Jun 2022 ',
#    ' Digital Marketing Executive',
#    'Current Employee',
#    ' more than 1 year',
#    '- agile',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    47)],
#  [('14 Jun 2022 ',
#    ' Operations Analyst',
#    'Current Employee',
#    ' more than 1 year',
#    'some staffs are actually kind.',
#    'Not Recommended',
#    'Recommended',
#    'Neutral',
#    48)],
#  [('13 Jun 2022 ',
#    ' Software Engineer',
#    'Former Employee',
#    ' more than 1 year',
#    'great learning opportunities and a good place to start your first career.',
#    'Not Recommended',
#    'Not Recommended',
#    'Neutral',
#    49)],
#  [('13 Jun 2022 ',
#    ' Finance Intern',
#    'Former Employee',
#    ' less than 1 year',
#    'the colleagues are very professional, and the workplace is comfortable.',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    50)],
#  [('13 Jun 2022 ',
#    ' Vice President',
#    'Current Employee',
#    ' more than 1 year',
#    'flexible working style, encourage employees to keep learning and grow',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    51)],
#  [('13 Jun 2022 ',
#    ' Account Officer',
#    'Current Contractor',
#    nan,
#    'balanced worklife balance',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    52),
#   ('13 Jun 2022 ',
#    ' Account Officer',
#    'Current Contractor',
#    nan,
#    'manager shows trust in employees',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    52)],
#  [('13 Jun 2022 ',
#    ' Anonymous Employee',
#    'Former Employee',
#    ' more than 1 year',
#    'learned a lot from the boss',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    53)],
#  [('13 Jun 2022 ',
#    ' Agile Scrum Master',
#    'Former Contractor',
#    ' more than 1 year',
#    'flexible but strong control',
#    'Not Recommended',
#    'Recommended',
#    'Not Recommended',
#    54),
#   ('13 Jun 2022 ',
#    ' Agile Scrum Master',
#    'Former Contractor',
#    ' more than 1 year',
#    'support by tools',
#    'Not Recommended',
#    'Recommended',
#    'Not Recommended',
#    54)],
#  [('12 Jun 2022 ',
#    ' Software Developer',
#    'Current Employee',
#    nan,
#    'great place to work and good learning',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    55)],
#  [('12 Jun 2022 ',
#    ' Analyst',
#    'Current Employee',
#    ' more than 1 year',
#    'good and supportive culture',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    56),
#   ('12 Jun 2022 ',
#    ' Analyst',
#    'Current Employee',
#    ' more than 1 year',
#    'good staff benefits depending on life circumstances',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    56),
#   ('12 Jun 2022 ',
#    ' Analyst',
#    'Current Employee',
#    ' more than 1 year',
#    'opportunities to move horizontally within the bank',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    56),
#   ('12 Jun 2022 ',
#    ' Analyst',
#    'Current Employee',
#    ' more than 1 year',
#    'great culture within the bank',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    56)],
#  [('12 Jun 2022 ',
#    ' Product Manager',
#    'Current Contractor',
#    nan,
#    'reputable bank, steep learning curve.',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    57)],
#  [('12 Jun 2022 ',
#    ' Audit Senior Associate',
#    'Current Employee',
#    ' more than 8 years',
#    'stable ok less politics nice',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    58)],
#  [('12 Jun 2022 ',
#    ' VP- Operations',
#    'Current Employee',
#    ' more than 10 years',
#    '1',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    59),
#   ('12 Jun 2022 ',
#    ' VP- Operations',
#    'Current Employee',
#    ' more than 10 years',
#    'performance-driven career progression_x000d_',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    59),
#   ('12 Jun 2022 ',
#    ' VP- Operations',
#    'Current Employee',
#    ' more than 10 years',
#    '2',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    59),
#   ('12 Jun 2022 ',
#    ' VP- Operations',
#    'Current Employee',
#    ' more than 10 years',
#    'annual leave above the market _x000d_',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    59),
#   ('12 Jun 2022 ',
#    ' VP- Operations',
#    'Current Employee',
#    ' more than 10 years',
#    '3',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    59),
#   ('12 Jun 2022 ',
#    ' VP- Operations',
#    'Current Employee',
#    ' more than 10 years',
#    'open for innovative ideas_x000d_',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    59),
#   ('12 Jun 2022 ',
#    ' VP- Operations',
#    'Current Employee',
#    ' more than 10 years',
#    '4',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    59),
#   ('12 Jun 2022 ',
#    ' VP- Operations',
#    'Current Employee',
#    ' more than 10 years',
#    'very supportive senior management_x000d_',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    59),
#   ('12 Jun 2022 ',
#    ' VP- Operations',
#    'Current Employee',
#    ' more than 10 years',
#    '5',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    59),
#   ('12 Jun 2022 ',
#    ' VP- Operations',
#    'Current Employee',
#    ' more than 10 years',
#    'awesome work and culture',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    59)],
#  [('11 Jun 2022 ',
#    ' Anonymous Employee',
#    'Current Employee',
#    ' more than 3 years',
#    'benefits are good._x000d_',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    60),
#   ('11 Jun 2022 ',
#    ' Anonymous Employee',
#    'Current Employee',
#    ' more than 3 years',
#    'leaves are one of the highest in the industry.',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    60)],
#  [('11 Jun 2022 ',
#    ' Assistant Vice President',
#    'Current Employee',
#    nan,
#    'good working culture in the organization',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    61)],
#  [('10 Jun 2022 ',
#    ' Anonymous Employee',
#    'Current Employee',
#    ' more than 1 year',
#    'big company with nice office location',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    62)],
#  [('9 Jun 2022 ',
#    ' Anonymous Contractor',
#    'Current Contractor',
#    ' less than 1 year',
#    'many meetings as expected, but also learnings to be gained from these alignments.',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    63)],
#  [('9 Jun 2022 ',
#    ' Database Administrator (DBA)',
#    'Current Employee',
#    nan,
#    'lot of work and learning opportunity',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    64)],
#  [('9 Jun 2022 ',
#    ' AVP-Operations',
#    'Current Employee',
#    ' less than 1 year',
#    'concerned about sales and target',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    65)],
#  [('9 Jun 2022 ',
#    ' IT Engineer',
#    'Former Employee',
#    ' more than 5 years',
#    'innovation company',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    66),
#   ('9 Jun 2022 ',
#    ' IT Engineer',
#    'Former Employee',
#    ' more than 5 years',
#    'always provide the excellent service to customers.',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    66)],
#  [('9 Jun 2022 ',
#    ' Anonymous Employee',
#    'Current Employee',
#    nan,
#    'nice colleague in work place',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    67)],
#  [('9 Jun 2022 ',
#    ' Relationship Manager',
#    'Former Employee',
#    ' more than 3 years',
#    'fast to adopt new technology_x000d_',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    68),
#   ('9 Jun 2022 ',
#    ' Relationship Manager',
#    'Former Employee',
#    ' more than 3 years',
#    'fast promotion if you have good sales',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    68)],
#  [('9 Jun 2022 ',
#    ' Assistant Officer',
#    'Current Employee',
#    ' more than 3 years',
#    'leaves are ample enough leaves are there',
#    'Not Recommended',
#    'Neutral',
#    'Not Recommended',
#    69)],
#  [('9 Jun 2022 ',
#    ' Software Engineer',
#    'Current Employee',
#    ' less than 1 year',
#    'free environment and good employee benifit',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    70)],
#  [('9 Jun 2022 ',
#    ' Senior Associate',
#    'Former Employee',
#    ' more than 3 years',
#    'good salary bonus benefits and awards',
#    'Not Recommended',
#    'Recommended',
#    'Recommended',
#    71)],
#  [('8 Jun 2022 ',
#    ' Senior Security Engineer',
#    'Current Employee',
#    ' more than 3 years',
#    'autonomy as ic is amazing',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    72)],
#  [('8 Jun 2022 ',
#    ' Senior Associate',
#    'Former Employee',
#    ' more than 5 years',
#    'great ceo, progressive company too',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    73)],
#  [('8 Jun 2022 ',
#    ' Senior Associate',
#    'Current Employee',
#    nan,
#    '2 days wfh per week',
#    'Recommended',
#    'Not Recommended',
#    'Neutral',
#    74),
#   ('8 Jun 2022 ',
#    ' Senior Associate',
#    'Current Employee',
#    nan,
#    'good working culture',
#    'Recommended',
#    'Not Recommended',
#    'Neutral',
#    74)],
#  [('7 Jun 2022 ',
#    ' AVP-Project Manager',
#    'Former Employee',
#    ' more than 5 years',
#    'ceo and top management do a lot to work with hr to drive work life balance and give competitive salary and other benefits',
#    'Recommended',
#    'Recommended',
#    'Not Recommended',
#    75),
#   ('7 Jun 2022 ',
#    ' AVP-Project Manager',
#    'Former Employee',
#    ' more than 5 years',
#    'honestly it’s a good place to work for with union backing as well.',
#    'Recommended',
#    'Recommended',
#    'Not Recommended',
#    75)],
#  [('7 Jun 2022 ',
#    ' Seeder',
#    'Current Employee',
#    ' less than 1 year',
#    'friendly colleagues and nice mentors',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    76)],
#  [('7 Jun 2022 ',
#    ' Senior Assocaiate',
#    'Former Employee',
#    ' more than 3 years',
#    'colleagues are helpful_x000d_',
#    'Recommended',
#    'Not Recommended',
#    'Recommended',
#    77),
#   ('7 Jun 2022 ',
#    ' Senior Assocaiate',
#    'Former Employee',
#    ' more than 3 years',
#    'focus on work rather than company politics',
#    'Recommended',
#    'Not Recommended',
#    'Recommended',
#    77)],
#  [('7 Jun 2022 ',
#    ' Anonymous Employee',
#    'Former Employee',
#    ' more than 1 year',
#    'working with colleagues can be very casual as everyone is friendly and helpful',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    78),
#   ('7 Jun 2022 ',
#    ' Anonymous Employee',
#    'Former Employee',
#    ' more than 1 year',
#    'great employer branding which helps to make your resume more attractive.',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    78)],
#  [('6 Jun 2022 ',
#    ' Sales Representative',
#    'Former Employee',
#    nan,
#    'company benefits are good',
#    'Neutral',
#    'Recommended',
#    'Not Recommended',
#    79),
#   ('6 Jun 2022 ',
#    ' Sales Representative',
#    'Former Employee',
#    nan,
#    'you have an option to branch out to other departments after if sales is not working out for you.',
#    'Neutral',
#    'Recommended',
#    'Not Recommended',
#    79)],
#  [('6 Jun 2022 ',
#    ' Software Engineer',
#    'Current Employee',
#    nan,
#    'employee friendly and ample changes for growth',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    80)],
#  [('6 Jun 2022 ',
#    ' SVP-Service Delivery Executive',
#    'Current Employee',
#    ' more than 8 years',
#    'good pay and good bonus.',
#    'Not Recommended',
#    'Recommended',
#    'Recommended',
#    81)],
#  [('5 Jun 2022 ',
#    ' Relationship Manager',
#    'Current Employee',
#    ' more than 1 year',
#    'nothing much in particular',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    82),
#   ('5 Jun 2022 ',
#    ' Relationship Manager',
#    'Current Employee',
#    ' more than 1 year',
#    'just do ur best',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    82)],
#  [('5 Jun 2022 ',
#    ' Assistant Manager',
#    'Current Employee',
#    ' more than 5 years',
#    'good career progress so far',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    83)],
#  [('5 Jun 2022 ',
#    ' Sales',
#    'Current Employee',
#    nan,
#    'great place to build experience',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    84)],
#  [('4 Jun 2022 ',
#    ' Investment Advisor',
#    'Former Employee',
#    nan,
#    'very very very very good',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    85)],
#  [('3 Jun 2022 ',
#    ' Technical Lead',
#    'Current Employee',
#    nan,
#    'great marketing on gandalf, transformation, cloud and being the best bank in the world',
#    'Neutral',
#    'Neutral',
#    'Not Recommended',
#    86)],
#  [('3 Jun 2022 ',
#    ' Vice President',
#    'Current Employee',
#    nan,
#    'less political tension',
#    'Recommended',
#    'Not Recommended',
#    'Recommended',
#    87),
#   ('3 Jun 2022 ',
#    ' Vice President',
#    'Current Employee',
#    nan,
#    'most staff are awesome ',
#    'Recommended',
#    'Not Recommended',
#    'Recommended',
#    87),
#   ('3 Jun 2022 ',
#    ' Vice President',
#    'Current Employee',
#    nan,
#    'not too much redundant staff',
#    'Recommended',
#    'Not Recommended',
#    'Recommended',
#    87)],
#  [('2 Jun 2022 ',
#    ' Associate',
#    'Current Employee',
#    nan,
#    'good environment to work for fresh graduate',
#    'Neutral',
#    'Recommended',
#    'Recommended',
#    88)],
#  [('2 Jun 2022 ',
#    ' Anonymous Contractor',
#    'Current Contractor',
#    ' less than 1 year',
#    'it is a good working environment',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    89)],
#  [('2 Jun 2022 ',
#    ' Senior Associate',
#    'Current Employee',
#    ' more than 5 years',
#    'good ambience and working culture',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    90),
#   ('2 Jun 2022 ',
#    ' Senior Associate',
#    'Current Employee',
#    ' more than 5 years',
#    'under singapore control.',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    90)],
#  [('2 Jun 2022 ',
#    ' Applications Support Analyst',
#    'Former Contractor',
#    ' more than 1 year',
#    'stable income, pre-defined job scope',
#    'Recommended',
#    'Not Recommended',
#    'Recommended',
#    91)],
#  [('2 Jun 2022 ',
#    ' Employee Relations Specialist',
#    'Current Contractor',
#    ' more than 1 year',
#    'good learning experience and good people',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    92)],
#  [('2 Jun 2022 ',
#    ' Software Developer',
#    'Current Employee',
#    nan,
#    'great boss colleagues_x000d_',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    93),
#   ('2 Jun 2022 ',
#    ' Software Developer',
#    'Current Employee',
#    nan,
#    'lots of tech tools to learn',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    93)],
#  [('2 Jun 2022 ',
#    ' Senior Manager',
#    'Current Employee',
#    ' more than 10 years',
#    'good place to learn ',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    94),
#   ('2 Jun 2022 ',
#    ' Senior Manager',
#    'Current Employee',
#    ' more than 10 years',
#    'reasonable work life balance',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    94)],
#  [('1 Jun 2022 ',
#    ' KYC Officer',
#    'Current Employee',
#    nan,
#    'good place to work in.',
#    'Recommended',
#    'Recommended',
#    'Neutral',
#    95)],
#  [('1 Jun 2022 ',
#    ' Financial Planner',
#    'Former Employee',
#    ' less than 1 year',
#    'branding is there for you',
#    'Not Recommended',
#    'Recommended',
#    'Not Recommended',
#    96)],
#  [('1 Jun 2022 ',
#    ' Executive Director',
#    'Current Employee',
#    ' more than 1 year',
#    'i’m working for some of the best leaders in my entire career! i’ve been able to work on what i’m passionate and good at!',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    97)],
#  [('1 Jun 2022 ',
#    ' Senior Project Associate',
#    'Current Employee',
#    ' more than 3 years',
#    'good work life balance._x000d_',
#    'Recommended',
#    'Recommended',
#    'Neutral',
#    98),
#   ('1 Jun 2022 ',
#    ' Senior Project Associate',
#    'Current Employee',
#    ' more than 3 years',
#    'good perks like iflex',
#    'Recommended',
#    'Recommended',
#    'Neutral',
#    98)],
#  [('31 May 2022 ',
#    ' Anonymous Contractor',
#    'Current Contractor',
#    nan,
#    'very inclusive culture, blameless work attitude generally a great place to work at.',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    99)],
#  [('31 May 2022 ',
#    ' Anonymous Employee',
#    'Current Employee',
#    ' more than 3 years',
#    'dbs is a people-oriented organisation which put employees in the first place.',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    100)],
#  [('31 May 2022 ',
#    ' Senior Relationship Manager',
#    'Current Employee',
#    ' more than 5 years',
#    'everything on the forefront',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    101),
#   ('31 May 2022 ',
#    ' Senior Relationship Manager',
#    'Current Employee',
#    ' more than 5 years',
#    'it is essentially trying all kinds of projects to automate job processes.',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    101)],
#  [('31 May 2022 ',
#    ' IT Contractor',
#    'Current Employee',
#    nan,
#    'good to work with the company',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    102)],
#  [('31 May 2022 ',
#    ' Officer',
#    'Current Employee',
#    ' less than 1 year',
#    'fair management system, good colleagues',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    103)],
#  [('30 May 2022 ',
#    ' Anonymous Contractor',
#    'Former Contractor',
#    ' more than 1 year',
#    'good benefits and good opportunity',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    104)],
#  [('30 May 2022 ',
#    ' Operational Risk Specialist',
#    'Former Employee',
#    ' more than 3 years',
#    'senior management really listens to employees and introduce changes through policies.',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    105)],
#  [('29 May 2022 ',
#    ' Relationship Manager',
#    'Former Employee',
#    nan,
#    'great compensation and branch culture',
#    'Neutral',
#    'Recommended',
#    'Neutral',
#    106)],
#  [('29 May 2022 ',
#    ' Wealth Manager',
#    'Current Employee',
#    nan,
#    'friendly environment and great staff benefit',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    107)],
#  [('28 May 2022 ',
#    ' Customer Service Representative',
#    'Former Employee',
#    ' more than 1 year',
#    'wfh rotation_x000d_',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    108),
#   ('28 May 2022 ',
#    ' Customer Service Representative',
#    'Former Employee',
#    ' more than 1 year',
#    'contractor no need to work in wfh session due to no access',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    108)],
#  [('28 May 2022 ',
#    ' Assistant Relationship Manager Private Banking',
#    'Former Employee',
#    ' more than 3 years',
#    'resourceful and able to learn many things.',
#    'Neutral',
#    'Recommended',
#    'Neutral',
#    109)],
#  [('27 May 2022 ',
#    ' Assistant Relationship Manager',
#    'Current Employee',
#    ' more than 1 year',
#    'good working exposure and great colleagues',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    110)],
#  [('26 May 2022 ',
#    ' AVP-Project Manager',
#    'Former Employee',
#    ' more than 8 years',
#    'great work culture',
#    'Recommended',
#    'Recommended',
#    'Neutral',
#    111),
#   ('26 May 2022 ',
#    ' AVP-Project Manager',
#    'Former Employee',
#    ' more than 8 years',
#    '_x000d_',
#    'Recommended',
#    'Recommended',
#    'Neutral',
#    111),
#   ('26 May 2022 ',
#    ' AVP-Project Manager',
#    'Former Employee',
#    ' more than 8 years',
#    'competitive salary & benefits package',
#    'Recommended',
#    'Recommended',
#    'Neutral',
#    111)],
#  [('26 May 2022 ',
#    ' Senior Wealth Planning Manager',
#    'Current Employee',
#    nan,
#    'i was lucky to have friendly colleagues and an awesome manager.',
#    'Recommended',
#    'Recommended',
#    'Neutral',
#    112)],
#  [('26 May 2022 ',
#    ' Software Engineer',
#    'Current Employee',
#    ' more than 1 year',
#    'working in dbs is still very much better than being exploit in singapore smes._x000d_',
#    'Recommended',
#    'Not Recommended',
#    'Recommended',
#    113),
#   ('26 May 2022 ',
#    ' Software Engineer',
#    'Current Employee',
#    ' more than 1 year',
#    'depends on your role and attitude in job nature',
#    'Recommended',
#    'Not Recommended',
#    'Recommended',
#    113),
#   ('26 May 2022 ',
#    ' Software Engineer',
#    'Current Employee',
#    ' more than 1 year',
#    'it will significantly put you to be center of attention to provide solutions to business technologies and recognition from peers._x000d_',
#    'Recommended',
#    'Not Recommended',
#    'Recommended',
#    113),
#   ('26 May 2022 ',
#    ' Software Engineer',
#    'Current Employee',
#    ' more than 1 year',
#    'probably one of the best employee benefits in general that enable to you to get lowest interest rate in home loan and higher rates in savings and also shares allocation at 25% more base on your monthly contribution.',
#    'Recommended',
#    'Not Recommended',
#    'Recommended',
#    113)],
#  [('26 May 2022 ',
#    ' Anonymous Employee',
#    'Current Employee',
#    ' more than 5 years',
#    'good compensation and benefits package',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    114)],
#  [('25 May 2022 ',
#    ' Software Engineer',
#    'Current Employee',
#    ' more than 1 year',
#    'good working environment, good for junior software enginners',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    115)],
#  [('25 May 2022 ',
#    ' Data Analyst',
#    'Former Contractor',
#    ' more than 5 years',
#    'fully digital and you can actually wfh.',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    116)],
#  [('25 May 2022 ',
#    ' Associate',
#    'Current Employee',
#    ' less than 1 year',
#    'nothing much, just lot of work',
#    'Not Recommended',
#    'Neutral',
#    'Neutral',
#    117)],
#  [('25 May 2022 ',
#    ' Corporate Loans Analyst',
#    'Former Contractor',
#    ' more than 1 year',
#    'people there are friendly and easy to work with',
#    'Recommended',
#    'Not Recommended',
#    'Neutral',
#    118)],
#  [('24 May 2022 ',
#    ' Analyst',
#    'Current Employee',
#    nan,
#    'all good in this company',
#    'Neutral',
#    'Recommended',
#    'Neutral',
#    119)],
#  [('24 May 2022 ',
#    ' Vice President',
#    'Current Employee',
#    ' more than 3 years',
#    'great supportive team and hardworking culture.',
#    'Not Recommended',
#    'Not Recommended',
#    'Recommended',
#    120)],
#  [('24 May 2022 ',
#    ' Associate',
#    'Current Employee',
#    ' more than 8 years',
#    'good leave benefits and fast paced environment.',
#    'Recommended',
#    'Not Recommended',
#    'Neutral',
#    121)],
#  [('24 May 2022 ',
#    ' Project Manager',
#    'Current Employee',
#    nan,
#    '- things move fast',
#    'Neutral',
#    'Not Recommended',
#    'Neutral',
#    122),
#   ('24 May 2022 ',
#    ' Project Manager',
#    'Current Employee',
#    nan,
#    '- able to achieve something',
#    'Neutral',
#    'Not Recommended',
#    'Neutral',
#    122)],
#  [('24 May 2022 ',
#    ' Dealer',
#    'Former Contractor',
#    ' more than 1 year',
#    'bank has good professional with good ethical background',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    123)],
#  [('23 May 2022 ',
#    ' Anonymous Employee',
#    'Current Employee',
#    nan,
#    'good benefits and salary .',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    124)],
#  [('23 May 2022 ',
#    ' Anonymous Employee',
#    'Former Employee',
#    nan,
#    'nice colleagues but depends on branch',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    125)],
#  [('23 May 2022 ',
#    ' Internship',
#    'Current Employee',
#    ' less than 1 year',
#    'great team, bearable workload, learned a lot',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    126)],
#  [('23 May 2022 ',
#    ' Manager',
#    'Former Contractor',
#    nan,
#    'good work culture ',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    127),
#   ('23 May 2022 ',
#    ' Manager',
#    'Former Contractor',
#    nan,
#    'excellent benefits ',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    127),
#   ('23 May 2022 ',
#    ' Manager',
#    'Former Contractor',
#    nan,
#    'diversity is good',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    127)],
#  [('23 May 2022 ',
#    ' SVP Product',
#    'Current Employee',
#    nan,
#    'good pay and bonus.',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    128),
#   ('23 May 2022 ',
#    ' SVP Product',
#    'Current Employee',
#    nan,
#    'generous number of leave.',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    128),
#   ('23 May 2022 ',
#    ' SVP Product',
#    'Current Employee',
#    nan,
#    'senior mgmt speaks alot on work life balance and mental wellness.',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    128)],
#  [('23 May 2022 ',
#    ' Assistant Vice President',
#    'Current Employee',
#    ' more than 3 years',
#    'career growth ,employee benefits in india_x000d_',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    129),
#   ('23 May 2022 ',
#    ' Assistant Vice President',
#    'Current Employee',
#    ' more than 3 years',
#    "new technology's and supporting leader ship",
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    129)],
#  [('23 May 2022 ',
#    ' Associate',
#    'Current Employee',
#    ' more than 3 years',
#    'good culture, benefits, based on project your work life balance depends',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    130)],
#  [('23 May 2022 ',
#    ' Associate',
#    'Current Employee',
#    ' more than 3 years',
#    'good employee benefits and work life balance',
#    'Recommended',
#    'Neutral',
#    'Neutral',
#    131)],
#  [('23 May 2022 ',
#    ' Human Resources Generalist',
#    'Current Employee',
#    nan,
#    'benefits quite good_x000d_',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    132),
#   ('23 May 2022 ',
#    ' Human Resources Generalist',
#    'Current Employee',
#    nan,
#    'bonus quite good_x000d_',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    132),
#   ('23 May 2022 ',
#    ' Human Resources Generalist',
#    'Current Employee',
#    nan,
#    'nice colleagues_x000d_',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    132),
#   ('23 May 2022 ',
#    ' Human Resources Generalist',
#    'Current Employee',
#    nan,
#    'fun at times',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    132)],
#  [('23 May 2022 ',
#    ' Anonymous Employee',
#    'Current Employee',
#    nan,
#    'good career structure designed to succeed',
#    'Not Recommended',
#    'Recommended',
#    'Recommended',
#    133)],
#  [('22 May 2022 ',
#    ' Trade Ops Analyst',
#    'Current Employee',
#    ' more than 3 years',
#    'good colleagues_x000d_',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    134),
#   ('22 May 2022 ',
#    ' Trade Ops Analyst',
#    'Current Employee',
#    ' more than 3 years',
#    'good perks once in awhile',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    134)],
#  [('22 May 2022 ',
#    ' Senior Associate',
#    'Current Employee',
#    ' more than 3 years',
#    'greater emphasis on work life balance, constant dialogues with senior management, hybrid work arrangements',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    135)],
#  [('22 May 2022 ',
#    ' Analyst',
#    'Current Employee',
#    nan,
#    'nice work culture very nice place to learn',
#    'Neutral',
#    'Not Recommended',
#    'Neutral',
#    136),
#   ('22 May 2022 ',
#    ' Analyst',
#    'Current Employee',
#    nan,
#    'we get goodies and vouchers almost once in two months',
#    'Neutral',
#    'Not Recommended',
#    'Neutral',
#    136)],
#  [('21 May 2022 ',
#    ' Associate',
#    'Current Employee',
#    nan,
#    'good opportunities , appreciated and good benefits',
#    'Recommended',
#    'Not Recommended',
#    'Recommended',
#    137)],
#  [('21 May 2022 ',
#    ' Software Engineer',
#    'Current Employee',
#    ' more than 1 year',
#    'no thing to say about pros',
#    'Not Recommended',
#    'Neutral',
#    'Not Recommended',
#    138)],
#  [('20 May 2022 ',
#    ' Associate',
#    'Current Employee',
#    ' less than 1 year',
#    'no pros as so far….',
#    'Not Recommended',
#    'Neutral',
#    'Not Recommended',
#    139)],
#  [('20 May 2022 ',
#    ' Analyst',
#    'Current Employee',
#    ' more than 3 years',
#    'decent employee benefits_x000d_',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    140),
#   ('20 May 2022 ',
#    ' Analyst',
#    'Current Employee',
#    ' more than 3 years',
#    'good amount of annual leave',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    140)],
#  [('20 May 2022 ',
#    ' Senior Vice President',
#    'Current Employee',
#    ' more than 1 year',
#    'good strategy and profit earning',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    141)],
#  [('20 May 2022 ',
#    ' Mac Administrator',
#    'Current Employee',
#    ' more than 3 years',
#    'wfh gives me more time on doing my work and rest',
#    'Recommended',
#    'Recommended',
#    'Neutral',
#    142),
#   ('20 May 2022 ',
#    ' Mac Administrator',
#    'Current Employee',
#    ' more than 3 years',
#    'the freedom which allows me to delivery',
#    'Recommended',
#    'Recommended',
#    'Neutral',
#    142)],
#  [('20 May 2022 ',
#    ' Anonymous Employee',
#    'Current Employee',
#    ' more than 5 years',
#    'very good culture and environment',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    143)],
#  [('20 May 2022 ',
#    ' Assistant Relationship Manager Private Banking',
#    'Current Employee',
#    nan,
#    'good place to learn and develop your skills and knowledge',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    144)],
#  [('20 May 2022 ',
#    ' Analyst',
#    'Current Employee',
#    ' more than 1 year',
#    'perks and work life balance',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    145)],
#  [('20 May 2022 ',
#    ' Senior RM',
#    'Current Employee',
#    ' more than 1 year',
#    'the bank has fabulous hr policies and take very good care of their employees',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    146),
#   ('20 May 2022 ',
#    ' Senior RM',
#    'Current Employee',
#    ' more than 1 year',
#    'everyone in the organisation is highly approachable',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    146),
#   ('20 May 2022 ',
#    ' Senior RM',
#    'Current Employee',
#    ' more than 1 year',
#    'just loved working here.',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    146)],
#  [('19 May 2022 ',
#    ' Analyst',
#    'Current Employee',
#    ' more than 1 year',
#    'good benefits (leaves, flexi, etc)',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    147)],
#  [('19 May 2022 ',
#    ' Corporate Action Specialist',
#    'Current Employee',
#    ' more than 5 years',
#    'leave benefits_x000d_',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    148),
#   ('19 May 2022 ',
#    ' Corporate Action Specialist',
#    'Current Employee',
#    ' more than 5 years',
#    'management not bad_x000d_',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    148),
#   ('19 May 2022 ',
#    ' Corporate Action Specialist',
#    'Current Employee',
#    ' more than 5 years',
#    'colleagues are helpful',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    148)],
#  [('19 May 2022 ',
#    ' Analyst',
#    'Current Employee',
#    ' less than 1 year',
#    'good chance to learn new technologies._x000d_',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    149),
#   ('19 May 2022 ',
#    ' Analyst',
#    'Current Employee',
#    ' less than 1 year',
#    'good leadership',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    149)],
#  [('18 May 2022 ',
#    ' Engineer',
#    'Former Employee',
#    ' more than 1 year',
#    'good benefits, structured jd, digital banking.',
#    'Recommended',
#    'Recommended',
#    'Not Recommended',
#    150)],
#  [('18 May 2022 ',
#    ' Analyst',
#    'Former Employee',
#    nan,
#    'good work place and good people',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    151)],
#  [('18 May 2022 ',
#    ' Anonymous Employee',
#    'Former Employee',
#    ' more than 3 years',
#    'if you don’t want to have to work very hard or deliver any impact._x000d_',
#    'Not Recommended',
#    'Recommended',
#    'Not Recommended',
#    152),
#   ('18 May 2022 ',
#    ' Anonymous Employee',
#    'Former Employee',
#    ' more than 3 years',
#    '_x000d_',
#    'Not Recommended',
#    'Recommended',
#    'Not Recommended',
#    152),
#   ('18 May 2022 ',
#    ' Anonymous Employee',
#    'Former Employee',
#    ' more than 3 years',
#    'ceo is good',
#    'Not Recommended',
#    'Recommended',
#    'Not Recommended',
#    152)],
#  [('18 May 2022 ',
#    ' Managing Director',
#    'Current Employee',
#    ' more than 8 years',
#    'flexible work arrangements, future oriented, customer oriented',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    153)],
#  [('18 May 2022 ',
#    ' Assistant Manager',
#    'Current Employee',
#    ' more than 5 years',
#    'best office timings and culture',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    154)],
#  [('18 May 2022 ',
#    ' Business Analyst',
#    'Current Contractor',
#    ' more than 1 year',
#    'seniors and managers in the dept very helpful and manage their expectations_x000d_',
#    'Recommended',
#    'Not Recommended',
#    'Recommended',
#    155),
#   ('18 May 2022 ',
#    ' Business Analyst',
#    'Current Contractor',
#    ' more than 1 year',
#    'great team with the learning process_x000d_',
#    'Recommended',
#    'Not Recommended',
#    'Recommended',
#    155),
#   ('18 May 2022 ',
#    ' Business Analyst',
#    'Current Contractor',
#    ' more than 1 year',
#    'overtime happens only once a while (ie development and testing phases)',
#    'Recommended',
#    'Not Recommended',
#    'Recommended',
#    155)],
#  [('18 May 2022 ',
#    ' Vice President',
#    'Former Employee',
#    nan,
#    'trying to grow and trying to incorporate more minor benefits for employees to feel engaged.',
#    'Neutral',
#    'Not Recommended',
#    'Neutral',
#    156)],
#  [('17 May 2022 ',
#    ' Project Manager',
#    'Current Employee',
#    nan,
#    'good annual pay and increment',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    157)],
#  [('17 May 2022 ',
#    ' Product Manager',
# ...
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    942),
#   ('2 Nov 2021 ',
#    ' Wealth Planning Manager',
#    'Current Employee',
#    nan,
#    'they will literally hire anyone',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    942),
#   ('2 Nov 2021 ',
#    ' Wealth Planning Manager',
#    'Current Employee',
#    nan,
#    'but not easy to stay',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    942)],
#  [('2 Nov 2021 ',
#    ' Customer Service Officer',
#    'Former Employee',
#    ' more than 1 year',
#    'good colleagues and environment.for those who want to start out their careers in the banking industry should start there',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    943)],
#  [('2 Nov 2021 ',
#    ' Manager',
#    'Current Employee',
#    ' more than 3 years',
#    'people, culture, learning and brand',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    944)],
#  [('1 Nov 2021 ',
#    ' AVP-Operations',
#    'Current Employee',
#    nan,
#    'tons of internal mobility opportunities',
#    'Recommended',
#    'Recommended',
#    'Neutral',
#    945)],
#  [('1 Nov 2021 ',
#    ' Anonymous Employee',
#    'Current Employee',
#    nan,
#    'good for start of career',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    946)],
#  [('1 Nov 2021 ',
#    ' Wealth Planning Manager',
#    'Current Employee',
#    ' more than 1 year',
#    'overall employee benefits are decent',
#    'Not Recommended',
#    'Neutral',
#    'Neutral',
#    947)],
#  [('1 Nov 2021 ',
#    ' Senior Associate',
#    'Current Employee',
#    ' more than 3 years',
#    'good pay',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    948),
#   ('1 Nov 2021 ',
#    ' Senior Associate',
#    'Current Employee',
#    ' more than 3 years',
#    'good tech used',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    948),
#   ('1 Nov 2021 ',
#    ' Senior Associate',
#    'Current Employee',
#    ' more than 3 years',
#    'nice work place environment',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    948)],
#  [('1 Nov 2021 ',
#    ' Branch Manager',
#    'Former Employee',
#    ' more than 3 years',
#    'good culture and fair pay packages',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    949)],
#  [('31 Oct 2021 ',
#    ' Senior Associate',
#    'Former Employee',
#    nan,
#    'bread and butter, can sustain living',
#    'Not Recommended',
#    'Recommended',
#    'Recommended',
#    950)],
#  [('31 Oct 2021 ',
#    ' Relationship Manager',
#    'Current Employee',
#    nan,
#    'best bank in the world',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    951)],
#  [('31 Oct 2021 ',
#    ' Assistant Vice President',
#    'Current Employee',
#    ' more than 1 year',
#    'great leadership with growth potential focus on internal talent.',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    952)],
#  [('31 Oct 2021 ',
#    ' IT Support Specialist',
#    'Current Employee',
#    nan,
#    'good remuneration & welfare benefits',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    953)],
#  [('30 Oct 2021 ',
#    ' Software Engineer',
#    'Current Employee',
#    nan,
#    'verily good company in the world!',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    954)],
#  [('30 Oct 2021 ',
#    ' Assistant Vice President',
#    'Current Employee',
#    ' more than 3 years',
#    'salary is reasonable and culture is acceptable',
#    'Not Recommended',
#    'Neutral',
#    'Not Recommended',
#    955)],
#  [('29 Oct 2021 ',
#    ' Bank Executive',
#    'Former Contractor',
#    nan,
#    'generally a good culture there',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    956)],
#  [('29 Oct 2021 ',
#    ' Senior Credit Analyst',
#    'Current Employee',
#    nan,
#    'local bank, good growth, give us opportunities to go for courses and promote staff internally',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    957)],
#  [('29 Oct 2021 ',
#    ' Associate',
#    'Current Employee',
#    ' more than 5 years',
#    'remuneration is good because that’s the only way people will stay.',
#    'Not Recommended',
#    'Neutral',
#    'Recommended',
#    958)],
#  [('29 Oct 2021 ',
#    ' Risk Manager',
#    'Former Employee',
#    ' more than 5 years',
#    'they are all immaterial',
#    'Not Recommended',
#    'Not Recommended',
#    'Not Recommended',
#    959),
#   ('29 Oct 2021 ',
#    ' Risk Manager',
#    'Former Employee',
#    ' more than 5 years',
#    'no good',
#    'Not Recommended',
#    'Not Recommended',
#    'Not Recommended',
#    959)],
#  [('29 Oct 2021 ',
#    ' Analyst',
#    'Current Employee',
#    ' more than 3 years',
#    'plenty of leave days and preferential interest rates',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    960)],
#  [('28 Oct 2021 ',
#    ' Wealth Planning Manager',
#    'Current Employee',
#    ' more than 1 year',
#    'comprehensive training provided, as well as good remuneration',
#    'Recommended',
#    'Recommended',
#    'Not Recommended',
#    961)],
#  [('28 Oct 2021 ',
#    ' Project Support Trainee',
#    'Former Contractor',
#    ' less than 1 year',
#    'good mentors, good project attachments.',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    962)],
#  [('28 Oct 2021 ',
#    ' Compensation and Benefits Specialist',
#    'Former Employee',
#    ' more than 3 years',
#    '1',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    963),
#   ('28 Oct 2021 ',
#    ' Compensation and Benefits Specialist',
#    'Former Employee',
#    ' more than 3 years',
#    'employee centricity and priority towards employees is one of the key pillars for management',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    963),
#   ('28 Oct 2021 ',
#    ' Compensation and Benefits Specialist',
#    'Former Employee',
#    ' more than 3 years',
#    '2',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    963),
#   ('28 Oct 2021 ',
#    ' Compensation and Benefits Specialist',
#    'Former Employee',
#    ' more than 3 years',
#    'compensation is towards the top quartile in the industry',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    963),
#   ('28 Oct 2021 ',
#    ' Compensation and Benefits Specialist',
#    'Former Employee',
#    ' more than 3 years',
#    '3',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    963),
#   ('28 Oct 2021 ',
#    ' Compensation and Benefits Specialist',
#    'Former Employee',
#    ' more than 3 years',
#    'very high focus on your career growth and self development',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    963),
#   ('28 Oct 2021 ',
#    ' Compensation and Benefits Specialist',
#    'Former Employee',
#    ' more than 3 years',
#    'empathy levels are high in management with greater focus on your work life balance and mental wellbeing',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    963),
#   ('28 Oct 2021 ',
#    ' Compensation and Benefits Specialist',
#    'Former Employee',
#    ' more than 3 years',
#    '4',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    963),
#   ('28 Oct 2021 ',
#    ' Compensation and Benefits Specialist',
#    'Former Employee',
#    ' more than 3 years',
#    'excellent engagement practices and bullish on india market',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    963)],
#  [('28 Oct 2021 ',
#    ' Vice President',
#    'Current Employee',
#    ' more than 10 years',
#    'lots of opportunities and initiatives',
#    'Recommended',
#    'Neutral',
#    'Recommended',
#    964)],
#  [('27 Oct 2021 ',
#    ' Anonymous Contractor',
#    'Former Contractor',
#    ' less than 1 year',
#    'great employee benefits',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    965),
#   ('27 Oct 2021 ',
#    ' Anonymous Contractor',
#    'Former Contractor',
#    ' less than 1 year',
#    'great teammates',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    965),
#   ('27 Oct 2021 ',
#    ' Anonymous Contractor',
#    'Former Contractor',
#    ' less than 1 year',
#    'transparent',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    965)],
#  [('27 Oct 2021 ',
#    ' Relationship Manager',
#    'Current Employee',
#    nan,
#    'good forward looking company with great benefits',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    966)],
#  [('27 Oct 2021 ',
#    ' CSO/CISO',
#    'Former Contractor',
#    ' less than 1 year',
#    'great high pay even for entry level._x000d_',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    967),
#   ('27 Oct 2021 ',
#    ' CSO/CISO',
#    'Former Contractor',
#    ' less than 1 year',
#    'great benefits with 28days leave',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    967)],
#  [('27 Oct 2021 ',
#    ' Analyst',
#    'Current Employee',
#    ' more than 1 year',
#    'supportive colleagues and bosses',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    968),
#   ('27 Oct 2021 ',
#    ' Analyst',
#    'Current Employee',
#    ' more than 1 year',
#    'family culture',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    968)],
#  [('26 Oct 2021 ',
#    ' Anonymous Employee',
#    'Current Employee',
#    ' more than 1 year',
#    'great employees work life balance.',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    969)],
#  [('25 Oct 2021 ',
#    ' Business Analyst',
#    'Current Employee',
#    ' more than 1 year',
#    'opportunities in various business units.',
#    'Recommended',
#    'Neutral',
#    'Recommended',
#    970)],
#  [('25 Oct 2021 ',
#    ' Anonymous Contractor',
#    'Current Contractor',
#    ' less than 1 year',
#    'good pay for new tech learners',
#    'Not Recommended',
#    'Neutral',
#    'Recommended',
#    971)],
#  [('25 Oct 2021 ',
#    ' Associate',
#    'Current Employee',
#    ' more than 3 years',
#    'the people and culture is great',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    972)],
#  [('24 Oct 2021 ',
#    ' Assistant Manager',
#    'Current Employee',
#    nan,
#    'less demand, able to im',
#    'Not Recommended',
#    'Neutral',
#    'Neutral',
#    973)],
#  [('24 Oct 2021 ',
#    ' Senior Relationship Manager',
#    'Current Employee',
#    nan,
#    'most of the colleague here are nice and helpful',
#    'Recommended',
#    'Neutral',
#    'Neutral',
#    974),
#   ('24 Oct 2021 ',
#    ' Senior Relationship Manager',
#    'Current Employee',
#    nan,
#    'job security is high.',
#    'Recommended',
#    'Neutral',
#    'Neutral',
#    974)],
#  [('24 Oct 2021 ',
#    ' Analyst',
#    'Current Employee',
#    nan,
#    '- decent employee benefits_x000d_',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    975),
#   ('24 Oct 2021 ',
#    ' Analyst',
#    'Current Employee',
#    nan,
#    '- stable job',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    975)],
#  [('24 Oct 2021 ',
#    ' Software Developer',
#    'Current Employee',
#    nan,
#    'place with growth opportunities and relatively nice people',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    976)],
#  [('24 Oct 2021 ',
#    ' Executive Director',
#    'Current Employee',
#    ' more than 10 years',
#    'great work environment',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    977),
#   ('24 Oct 2021 ',
#    ' Executive Director',
#    'Current Employee',
#    ' more than 10 years',
#    'and clearly focussed on digital banking and leading the world charge',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    977)],
#  [('23 Oct 2021 ',
#    ' Assistant Officer',
#    'Current Employee',
#    nan,
#    'everything what employee need...all the facilities to grow more',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    978)],
#  [('23 Oct 2021 ',
#    ' Relationship Manager',
#    'Current Employee',
#    nan,
#    'friendly_x000d_',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    979),
#   ('23 Oct 2021 ',
#    ' Relationship Manager',
#    'Current Employee',
#    nan,
#    'family oriented_x000d_',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    979),
#   ('23 Oct 2021 ',
#    ' Relationship Manager',
#    'Current Employee',
#    nan,
#    'at the forefront of digital evolution',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    979)],
#  [('23 Oct 2021 ',
#    ' Relationship Manager',
#    'Current Employee',
#    ' less than 1 year',
#    'good pay and lot of things to learn',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    980)],
#  [('23 Oct 2021 ',
#    ' Bank Teller',
#    'Former Contractor',
#    ' more than 1 year',
#    'big name recognition',
#    'Not Recommended',
#    'Not Recommended',
#    'Neutral',
#    981),
#   ('23 Oct 2021 ',
#    ' Bank Teller',
#    'Former Contractor',
#    ' more than 1 year',
#    'somehow updated internal and external systems',
#    'Not Recommended',
#    'Not Recommended',
#    'Neutral',
#    981)],
#  [('21 Oct 2021 ',
#    ' Associate',
#    'Current Employee',
#    ' less than 1 year',
#    'very competitive package and benefits',
#    'Not Recommended',
#    'Neutral',
#    'Recommended',
#    982)],
#  [('21 Oct 2021 ',
#    ' Investment Counselor',
#    'Current Employee',
#    ' more than 8 years',
#    'management constantly takes in feedback to improve',
#    'Recommended',
#    'Neutral',
#    'Recommended',
#    983)],
#  [('21 Oct 2021 ',
#    ' Bank Officer',
#    'Former Employee',
#    ' more than 1 year',
#    'good working environment and good staffs benefits',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    984)],
#  [('21 Oct 2021 ',
#    ' Assistant Vice President',
#    'Current Employee',
#    ' more than 10 years',
#    'everything is good except the salary part',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    985)],
#  [('21 Oct 2021 ',
#    ' Vice President',
#    'Current Employee',
#    nan,
#    'reputed employer of choice in singapore',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    986)],
#  [('21 Oct 2021 ',
#    ' Senior Associate',
#    'Current Employee',
#    ' more than 3 years',
#    'work life balance is good.',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    987)],
#  [('21 Oct 2021 ',
#    ' Analyst',
#    'Current Employee',
#    ' more than 1 year',
#    'nice people,good work environment,good benefits',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    988)],
#  [('21 Oct 2021 ',
#    ' Analyst',
#    'Current Employee',
#    ' more than 1 year',
#    'many leaves to use and also allow to wfh during pandemic',
#    'Not Recommended',
#    'Recommended',
#    'Not Recommended',
#    989)],
#  [('21 Oct 2021 ',
#    ' Relationship Banker',
#    'Current Employee',
#    nan,
#    'digital bank, good digital processes',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    990)],
#  [('20 Oct 2021 ',
#    ' Analyst',
#    'Current Employee',
#    nan,
#    'bank provide plenty of reskill course to then employee to enhance themselves',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    991)],
#  [('20 Oct 2021 ',
#    ' Business Analyst Entry Level',
#    'Current Employee',
#    nan,
#    'benefits are not too bad',
#    'Recommended',
#    'Recommended',
#    'Neutral',
#    992)],
#  [('20 Oct 2021 ',
#    ' Sales Associate',
#    'Current Employee',
#    nan,
#    'they have a good digital transformative culture',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    993)],
#  [('19 Oct 2021 ',
#    ' Customer Service Operator (CSO)',
#    'Former Contractor',
#    ' more than 1 year',
#    'good salary and benefits provided',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    994)],
#  [('18 Oct 2021 ',
#    ' Analyst',
#    'Current Employee',
#    ' less than 1 year',
#    'good benefits_x000d_',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    995),
#   ('18 Oct 2021 ',
#    ' Analyst',
#    'Current Employee',
#    ' less than 1 year',
#    'boss take good care of your well beings',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    995)],
#  [('18 Oct 2021 ',
#    ' Assistant Relationship Manager',
#    'Current Employee',
#    nan,
#    'good local bank with stability.',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    996)],
#  [('18 Oct 2021 ',
#    ' Customer Service Ambassador',
#    'Former Employee',
#    ' more than 1 year',
#    'encourage customers to more use of online banking services, while continuously improving online personalization and humanization services to customers',
#    'Recommended',
#    'Neutral',
#    'Neutral',
#    997),
#   ('18 Oct 2021 ',
#    ' Customer Service Ambassador',
#    'Former Employee',
#    ' more than 1 year',
#    'it can reduce the workload of branch staff and save the time for customer to deal with transaction.',
#    'Recommended',
#    'Neutral',
#    'Neutral',
#    997)],
#  [('18 Oct 2021 ',
#    ' Operations',
#    'Current Employee',
#    nan,
#    'many internal event makes employee joyful',
#    'Not Recommended',
#    'Neutral',
#    'Not Recommended',
#    998)],
#  [('18 Oct 2021 ',
#    ' Data Analyst',
#    'Former Contractor',
#    ' more than 3 years',
#    'stable job, stable source of income, very good benefits',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    999)],
#  ...]

# %%
cons_and_idx_lis
# Out:
# [[('27 Jun 2022 ',
#    ' Software Engineer',
#    'Current Employee',
#    ' more than 5 years',
#    'hierarchical, does not listen to feedback from junior staff',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    0)],
#  [('27 Jun 2022 ',
#    ' Senior Associate',
#    'Current Employee',
#    nan,
#    'number of carry forward leave allow is too little',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    1)],
#  [('27 Jun 2022 ',
#    ' Senior Associate',
#    'Current Employee',
#    nan,
#    'no work life balance.',
#    'Not Recommended',
#    'Neutral',
#    'Neutral',
#    2),
#   ('27 Jun 2022 ',
#    ' Senior Associate',
#    'Current Employee',
#    nan,
#    'managers force to work from office..they say sez rules and all 5days should work only in office and even on weekends if needed u need to travel to office.🙏🙏_x000d_',
#    'Not Recommended',
#    'Neutral',
#    'Neutral',
#    2),
#   ('27 Jun 2022 ',
#    ' Senior Associate',
#    'Current Employee',
#    nan,
#    'no desks/cabin for seating..feels like call centre job_x000d_',
#    'Not Recommended',
#    'Neutral',
#    'Neutral',
#    2),
#   ('27 Jun 2022 ',
#    ' Senior Associate',
#    'Current Employee',
#    nan,
#    '_x000d_',
#    'Not Recommended',
#    'Neutral',
#    'Neutral',
#    2),
#   ('27 Jun 2022 ',
#    ' Senior Associate',
#    'Current Employee',
#    nan,
#    'bad chairs.',
#    'Not Recommended',
#    'Neutral',
#    'Neutral',
#    2),
#   ('27 Jun 2022 ',
#    ' Senior Associate',
#    'Current Employee',
#    nan,
#    'surely will get back pain_x000d_',
#    'Not Recommended',
#    'Neutral',
#    'Neutral',
#    2),
#   ('27 Jun 2022 ',
#    ' Senior Associate',
#    'Current Employee',
#    nan,
#    'no cafeteria not even coffee/tea except those waste vending machines.._x000d_',
#    'Not Recommended',
#    'Neutral',
#    'Neutral',
#    2),
#   ('27 Jun 2022 ',
#    ' Senior Associate',
#    'Current Employee',
#    nan,
#    "overall it's good not to join if u r a hybrid person and love family.",
#    'Not Recommended',
#    'Neutral',
#    'Neutral',
#    2)],
#  [('27 Jun 2022 ',
#    ' Senior Data Analyst',
#    'Former Contractor',
#    ' more than 1 year',
#    'some politics, heavy workload on some projects',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    3)],
#  [('27 Jun 2022 ',
#    ' Graduate Associate',
#    'Current Employee',
#    ' more than 1 year',
#    'you need to get exposed to multiple skillsets',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    4)],
#  [('27 Jun 2022 ',
#    ' Engineer',
#    'Current Employee',
#    nan,
#    'there is no special factor except the work life',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    5)],
#  [('27 Jun 2022 ',
#    ' Anonymous Employee',
#    'Current Employee',
#    ' more than 8 years',
#    'work - life balance, management decisions',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    6)],
#  [('26 Jun 2022 ',
#    ' Senior Associate',
#    'Current Employee',
#    nan,
#    'bonus rather lesser than other banks',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    7)],
#  [('26 Jun 2022 ',
#    ' Anonymous Employee',
#    'Current Employee',
#    ' more than 3 years',
#    'no cons that stand out explicitly',
#    'Recommended',
#    'Neutral',
#    'Recommended',
#    8)],
#  [('26 Jun 2022 ',
#    ' AVP-Java Developer',
#    'Former Employee',
#    ' more than 3 years',
#    'work life balance and low compensation',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    9)],
#  [('26 Jun 2022 ',
#    ' Relationship Manager',
#    'Former Employee',
#    ' more than 1 year',
#    'targets always increasing which can be challenging',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    10)],
#  [('25 Jun 2022 ',
#    ' Vice President - Technology',
#    'Current Employee',
#    nan,
#    'hard to leave the company',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    11)],
#  [('25 Jun 2022 ',
#    ' Senior Associate',
#    'Current Employee',
#    nan,
#    'long working hours due to the demand of the job',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    12)],
#  [('25 Jun 2022 ',
#    ' Senior Associate',
#    'Current Employee',
#    ' more than 10 years',
#    'there is no cons and -',
#    'Recommended',
#    'Recommended',
#    'Neutral',
#    13)],
#  [('24 Jun 2022 ',
#    ' Anonymous Employee',
#    'Current Employee',
#    ' more than 5 years',
#    'broken and siloed divisions across the company, making collaboration difficult',
#    'Not Recommended',
#    'Recommended',
#    'Not Recommended',
#    14),
#   ('24 Jun 2022 ',
#    ' Anonymous Employee',
#    'Current Employee',
#    ' more than 5 years',
#    "project communication don't cascade well within the project team, sometimes even kept hidden and as a secret",
#    'Not Recommended',
#    'Recommended',
#    'Not Recommended',
#    14),
#   ('24 Jun 2022 ',
#    ' Anonymous Employee',
#    'Current Employee',
#    ' more than 5 years',
#    "many middle and senior management will to shoot you down if you have any feedback that goes against their wishes, but they will claim credit if you're right.",
#    'Not Recommended',
#    'Recommended',
#    'Not Recommended',
#    14)],
#  [('24 Jun 2022 ',
#    ' Credit Analyst',
#    'Current Employee',
#    ' less than 1 year',
#    'the system is very slow, it team are inefficient',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    15)],
#  [('23 Jun 2022 ',
#    ' Human Resources Generalist',
#    'Former Employee',
#    nan,
#    'nothing much, everything was perfect as per singapore working standard.',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    16)],
#  [('23 Jun 2022 ',
#    ' WPM',
#    'Former Employee',
#    ' less than 1 year',
#    'really depends on your luck with your team lead',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    17),
#   ('23 Jun 2022 ',
#    ' WPM',
#    'Former Employee',
#    ' less than 1 year',
#    'if you get a good one, everything will go very well for you, but if you get a lousy one, you can start counting the time left with your fingers',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    17)],
#  [('23 Jun 2022 ',
#    ' Senior Executive',
#    'Former Contractor',
#    ' more than 1 year',
#    'low pay and insufficient health benefits',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    18)],
#  [('23 Jun 2022 ',
#    ' Relationship Manager',
#    'Current Employee',
#    nan,
#    'micro-management from team leads and career progression',
#    'Neutral',
#    'Recommended',
#    'Neutral',
#    19)],
#  [('22 Jun 2022 ',
#    ' ',
#    'Current Employee',
#    ' less than 1 year',
#    'no work life balance,',
#    'Neutral',
#    'Not Recommended',
#    'Neutral',
#    20),
#   ('22 Jun 2022 ',
#    ' ',
#    'Current Employee',
#    ' less than 1 year',
#    'worst management',
#    'Neutral',
#    'Not Recommended',
#    'Neutral',
#    20),
#   ('22 Jun 2022 ',
#    ' ',
#    'Current Employee',
#    ' less than 1 year',
#    'no transportation for contract employees',
#    'Neutral',
#    'Not Recommended',
#    'Neutral',
#    20),
#   ('22 Jun 2022 ',
#    ' ',
#    'Current Employee',
#    ' less than 1 year',
#    'they will ask to come to office even if you are not feeling well.',
#    'Neutral',
#    'Not Recommended',
#    'Neutral',
#    20)],
#  [('22 Jun 2022 ',
#    ' Technical Developer',
#    'Former Employee',
#    ' less than 1 year',
#    'sometimes time extenda based on the project closure date',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    21)],
#  [('20 Jun 2022 ',
#    ' Banker',
#    'Current Employee',
#    ' more than 1 year',
#    'worklife',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    22),
#   ('20 Jun 2022 ',
#    ' Banker',
#    'Current Employee',
#    ' more than 1 year',
#    'balance and internal management',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    22)],
#  [('20 Jun 2022 ',
#    ' Wealth Manager',
#    'Current Employee',
#    ' more than 1 year',
#    'high expectations and fast pace',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    23)],
#  [('20 Jun 2022 ',
#    ' Customer Service Officer',
#    'Current Contractor',
#    ' less than 1 year',
#    'overworked for the pay ',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    24),
#   ('20 Jun 2022 ',
#    ' Customer Service Officer',
#    'Current Contractor',
#    ' less than 1 year',
#    'need to be super thick skin and resilient',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    24)],
#  [('20 Jun 2022 ',
#    ' Bank Teller',
#    'Former Employee',
#    nan,
#    'pay and benefit not the greatest',
#    'Not Recommended',
#    'Neutral',
#    'Not Recommended',
#    25)],
#  [('20 Jun 2022 ',
#    ' Anonymous Employee',
#    'Current Employee',
#    ' more than 1 year',
#    'pay not as high as other places',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    26)],
#  [('19 Jun 2022 ',
#    ' Project Management Office (PMO)',
#    'Former Contractor',
#    ' less than 1 year',
#    'came to work on monday and computer only ready on thursday',
#    'Not Recommended',
#    'Not Recommended',
#    'Neutral',
#    27),
#   ('19 Jun 2022 ',
#    ' Project Management Office (PMO)',
#    'Former Contractor',
#    ' less than 1 year',
#    'literally couldnt do anything for 4 straight days.',
#    'Not Recommended',
#    'Not Recommended',
#    'Neutral',
#    27)],
#  [('18 Jun 2022 ',
#    ' Associate',
#    'Current Employee',
#    nan,
#    'long working hour, system issue',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    28)],
#  [('18 Jun 2022 ',
#    ' Senior Associate',
#    'Current Employee',
#    ' more than 5 years',
#    'i did not find any',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    29)],
#  [('18 Jun 2022 ',
#    ' Anonymous Employee',
#    'Current Employee',
#    nan,
#    'n/a, no cons.',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    30),
#   ('18 Jun 2022 ',
#    ' Anonymous Employee',
#    'Current Employee',
#    nan,
#    'no cons',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    30)],
#  [('18 Jun 2022 ',
#    ' Customer Service Associate',
#    'Former Contractor',
#    ' less than 1 year',
#    'will need to shorten lunch to bring up sla._x000d_',
#    'Not Recommended',
#    'Neutral',
#    'Not Recommended',
#    31),
#   ('18 Jun 2022 ',
#    ' Customer Service Associate',
#    'Former Contractor',
#    ' less than 1 year',
#    'even though they compensate for off time but it might not be approved again due to sla',
#    'Not Recommended',
#    'Neutral',
#    'Not Recommended',
#    31),
#   ('18 Jun 2022 ',
#    ' Customer Service Associate',
#    'Former Contractor',
#    ' less than 1 year',
#    '_x000d_',
#    'Not Recommended',
#    'Neutral',
#    'Not Recommended',
#    31),
#   ('18 Jun 2022 ',
#    ' Customer Service Associate',
#    'Former Contractor',
#    ' less than 1 year',
#    '_x000d_',
#    'Not Recommended',
#    'Neutral',
#    'Not Recommended',
#    31),
#   ('18 Jun 2022 ',
#    ' Customer Service Associate',
#    'Former Contractor',
#    ' less than 1 year',
#    'seem like benefits between contracts staffs and perm staffs have a huge gap differences',
#    'Not Recommended',
#    'Neutral',
#    'Not Recommended',
#    31),
#   ('18 Jun 2022 ',
#    ' Customer Service Associate',
#    'Former Contractor',
#    ' less than 1 year',
#    '_x000d_',
#    'Not Recommended',
#    'Neutral',
#    'Not Recommended',
#    31),
#   ('18 Jun 2022 ',
#    ' Customer Service Associate',
#    'Former Contractor',
#    ' less than 1 year',
#    '_x000d_',
#    'Not Recommended',
#    'Neutral',
#    'Not Recommended',
#    31),
#   ('18 Jun 2022 ',
#    ' Customer Service Associate',
#    'Former Contractor',
#    ' less than 1 year',
#    'look good on the outside but not inside',
#    'Not Recommended',
#    'Neutral',
#    'Not Recommended',
#    31),
#   ('18 Jun 2022 ',
#    ' Customer Service Associate',
#    'Former Contractor',
#    ' less than 1 year',
#    'team leaders do not really offer help to contract staffs.',
#    'Not Recommended',
#    'Neutral',
#    'Not Recommended',
#    31)],
#  [('17 Jun 2022 ',
#    ' Anonymous Employee',
#    'Current Employee',
#    nan,
#    'so far no downside yet',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    32)],
#  [('17 Jun 2022 ',
#    ' Associate',
#    'Current Employee',
#    ' more than 3 years',
#    'slow progression for most ppl',
#    'Recommended',
#    'Neutral',
#    'Recommended',
#    33)],
#  [('17 Jun 2022 ',
#    ' Customer Service Officer',
#    'Current Employee',
#    nan,
#    'very high volume of calls',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    34)],
#  [('17 Jun 2022 ',
#    ' Vice President',
#    'Former Employee',
#    ' more than 3 years',
#    'work life balance can be challenging',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    35)],
#  [('16 Jun 2022 ',
#    ' Anonymous Contractor',
#    'Former Contractor',
#    nan,
#    '-rigid and not much career development opportunities despite being a big bank',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    36)],
#  [('16 Jun 2022 ',
#    ' Seeder',
#    'Current Employee',
#    ' more than 1 year',
#    '-some team culture might be toxic _x000d_',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    37),
#   ('16 Jun 2022 ',
#    ' Seeder',
#    'Current Employee',
#    ' more than 1 year',
#    '-cant really get to choose what you wanna doing coming in(but there would be a rotation where you can choose where you wanna go)',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    37)],
#  [('15 Jun 2022 ',
#    ' Relationship Manager',
#    'Former Employee',
#    nan,
#    'bad environment and bad hours',
#    'Not Recommended',
#    'Neutral',
#    'Recommended',
#    38)],
#  [('15 Jun 2022 ',
#    ' Officer',
#    'Former Employee',
#    nan,
#    'heavy workload_x000d_',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    39),
#   ('15 Jun 2022 ',
#    ' Officer',
#    'Former Employee',
#    nan,
#    'harsh expectations from managers',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    39)],
#  [('15 Jun 2022 ',
#    ' Sales Associate',
#    'Current Employee',
#    ' less than 1 year',
#    'long working hours',
#    'Recommended',
#    'Not Recommended',
#    'Neutral',
#    40),
#   ('15 Jun 2022 ',
#    ' Sales Associate',
#    'Current Employee',
#    ' less than 1 year',
#    'may need to ot',
#    'Recommended',
#    'Not Recommended',
#    'Neutral',
#    40)],
#  [('15 Jun 2022 ',
#    ' Deputy Manager Sales',
#    'Former Employee',
#    ' more than 3 years',
#    'workload overwhelm,no work life balance',
#    'Recommended',
#    'Recommended',
#    'Not Recommended',
#    41)],
#  [('15 Jun 2022 ',
#    ' Private Banking Associate',
#    'Current Employee',
#    nan,
#    'bad hr and top-down approach at some teams',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    42)],
#  [('15 Jun 2022 ',
#    ' AVP-Sales',
#    'Former Employee',
#    ' more than 3 years',
#    'overwork, managers are localise and practice biasness',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    43)],
#  [('15 Jun 2022 ',
#    ' Analyst',
#    'Current Contractor',
#    ' less than 1 year',
#    'nil nil nil nil nil',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    44)],
#  [('14 Jun 2022 ',
#    ' Analyst',
#    'Current Employee',
#    ' more than 3 years',
#    'might not have work life balance and promotions are slower',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    45),
#   ('14 Jun 2022 ',
#    ' Analyst',
#    'Current Employee',
#    ' more than 3 years',
#    'even if you worked hard, might not received the recognition as expected.',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    45)],
#  [('14 Jun 2022 ',
#    ' Senior Officer',
#    'Current Employee',
#    ' more than 3 years',
#    'low salary increment_x000d_',
#    'Not Recommended',
#    'Not Recommended',
#    'Neutral',
#    46),
#   ('14 Jun 2022 ',
#    ' Senior Officer',
#    'Current Employee',
#    ' more than 3 years',
#    'slow promotion_x000d_',
#    'Not Recommended',
#    'Not Recommended',
#    'Neutral',
#    46),
#   ('14 Jun 2022 ',
#    ' Senior Officer',
#    'Current Employee',
#    ' more than 3 years',
#    'bad insurance plan',
#    'Not Recommended',
#    'Not Recommended',
#    'Neutral',
#    46)],
#  [('14 Jun 2022 ',
#    ' Digital Marketing Executive',
#    'Current Employee',
#    ' more than 1 year',
#    '- stressful, long hours_x000d_',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    47),
#   ('14 Jun 2022 ',
#    ' Digital Marketing Executive',
#    'Current Employee',
#    ' more than 1 year',
#    '- disjointed management is the norm_x000d_',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    47),
#   ('14 Jun 2022 ',
#    ' Digital Marketing Executive',
#    'Current Employee',
#    ' more than 1 year',
#    '- progress takes very long_x000d_',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    47),
#   ('14 Jun 2022 ',
#    ' Digital Marketing Executive',
#    'Current Employee',
#    ' more than 1 year',
#    '- no diversity',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    47)],
#  [('14 Jun 2022 ',
#    ' Operations Analyst',
#    'Current Employee',
#    ' more than 1 year',
#    'the elder staffs expect you to do everything',
#    'Not Recommended',
#    'Recommended',
#    'Neutral',
#    48),
#   ('14 Jun 2022 ',
#    ' Operations Analyst',
#    'Current Employee',
#    ' more than 1 year',
#    'including their share of work._x000d_',
#    'Not Recommended',
#    'Recommended',
#    'Neutral',
#    48),
#   ('14 Jun 2022 ',
#    ' Operations Analyst',
#    'Current Employee',
#    ' more than 1 year',
#    "be prepared to stay for ot to complete other's workload.",
#    'Not Recommended',
#    'Recommended',
#    'Neutral',
#    48)],
#  [('13 Jun 2022 ',
#    ' Software Engineer',
#    'Former Employee',
#    ' more than 1 year',
#    'due to the internal transfer practice, it is a common sight that it produces weak middle management who aren\'t trained in the role that they transferred to, but their ego is too high to listen to feedback from "inexperience" fresh graduates and developers who "don\'t know anything" about the "business"._x000d_',
#    'Not Recommended',
#    'Not Recommended',
#    'Neutral',
#    49),
#   ('13 Jun 2022 ',
#    ' Software Engineer',
#    'Former Employee',
#    ' more than 1 year',
#    '_x000d_',
#    'Not Recommended',
#    'Not Recommended',
#    'Neutral',
#    49),
#   ('13 Jun 2022 ',
#    ' Software Engineer',
#    'Former Employee',
#    ' more than 1 year',
#    'many incompetent product owners and project managers resulted in endless and meaningless tech discussions that often go (something) like this..._x000d_',
#    'Not Recommended',
#    'Not Recommended',
#    'Neutral',
#    49),
#   ('13 Jun 2022 ',
#    ' Software Engineer',
#    'Former Employee',
#    ' more than 1 year',
#    '_x000d_',
#    'Not Recommended',
#    'Not Recommended',
#    'Neutral',
#    49),
#   ('13 Jun 2022 ',
#    ' Software Engineer',
#    'Former Employee',
#    ' more than 1 year',
#    'middle management: "can you draw a pair of lines that are parallel to each other? oh! by the way, make them perpendicular too!"_x000d_',
#    'Not Recommended',
#    'Not Recommended',
#    'Neutral',
#    49),
#   ('13 Jun 2022 ',
#    ' Software Engineer',
#    'Former Employee',
#    ' more than 1 year',
#    '_x000d_',
#    'Not Recommended',
#    'Not Recommended',
#    'Neutral',
#    49),
#   ('13 Jun 2022 ',
#    ' Software Engineer',
#    'Former Employee',
#    ' more than 1 year',
#    'developers: "ermmm..',
#    'Not Recommended',
#    'Not Recommended',
#    'Neutral',
#    49),
#   ('13 Jun 2022 ',
#    ' Software Engineer',
#    'Former Employee',
#    ' more than 1 year',
#    'a pair of lines can\'t be parallel and perpendicular at the same time."_x000d_',
#    'Not Recommended',
#    'Not Recommended',
#    'Neutral',
#    49),
#   ('13 Jun 2022 ',
#    ' Software Engineer',
#    'Former Employee',
#    ' more than 1 year',
#    '_x000d_',
#    'Not Recommended',
#    'Not Recommended',
#    'Neutral',
#    49),
#   ('13 Jun 2022 ',
#    ' Software Engineer',
#    'Former Employee',
#    ' more than 1 year',
#    'middle management: "oh come on! you haven\'t even tried it!"_x000d_',
#    'Not Recommended',
#    'Not Recommended',
#    'Neutral',
#    49),
#   ('13 Jun 2022 ',
#    ' Software Engineer',
#    'Former Employee',
#    ' more than 1 year',
#    '_x000d_',
#    'Not Recommended',
#    'Not Recommended',
#    'Neutral',
#    49),
#   ('13 Jun 2022 ',
#    ' Software Engineer',
#    'Former Employee',
#    ' more than 1 year',
#    'developers: "is just not possible..',
#    'Not Recommended',
#    'Not Recommended',
#    'Neutral',
#    49),
#   ('13 Jun 2022 ',
#    ' Software Engineer',
#    'Former Employee',
#    ' more than 1 year',
#    '🤦\u200d♂️ you know what? i\'ll give it a try and get back to you."',
#    'Not Recommended',
#    'Not Recommended',
#    'Neutral',
#    49)],
#  [('13 Jun 2022 ',
#    ' Finance Intern',
#    'Former Employee',
#    ' less than 1 year',
#    'the hierarchy is very strong.',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    50)],
#  [('13 Jun 2022 ',
#    ' Vice President',
#    'Current Employee',
#    ' more than 1 year',
#    'lack of work life balance, poor internal systems',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    51)],
#  [('13 Jun 2022 ',
#    ' Account Officer',
#    'Current Contractor',
#    nan,
#    'limited headcount',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    52),
#   ('13 Jun 2022 ',
#    ' Account Officer',
#    'Current Contractor',
#    nan,
#    'on a contract',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    52)],
#  [('13 Jun 2022 ',
#    ' Anonymous Employee',
#    'Former Employee',
#    ' more than 1 year',
#    'too much workload and always work overtime',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    53)],
#  [('13 Jun 2022 ',
#    ' Agile Scrum Master',
#    'Former Contractor',
#    ' more than 1 year',
#    'too many standard and meetings for admin works',
#    'Not Recommended',
#    'Recommended',
#    'Not Recommended',
#    54)],
#  [('12 Jun 2022 ',
#    ' Software Developer',
#    'Current Employee',
#    nan,
#    'no cons from end of review',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    55)],
#  [('12 Jun 2022 ',
#    ' Analyst',
#    'Current Employee',
#    ' more than 1 year',
#    'seems like everyone around me is underpaid, but hr always announces that dbs pays above market during townhalls_x000d_',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    56),
#   ('12 Jun 2022 ',
#    ' Analyst',
#    'Current Employee',
#    ' more than 1 year',
#    'relatively large workload _x000d_',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    56),
#   ('12 Jun 2022 ',
#    ' Analyst',
#    'Current Employee',
#    ' more than 1 year',
#    'culture of having a lot of meetings that may not be productive',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    56)],
#  [('12 Jun 2022 ',
#    ' Product Manager',
#    'Current Contractor',
#    nan,
#    'too many contract roles, slow promotion rate.',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    57)],
#  [('12 Jun 2022 ',
#    ' Audit Senior Associate',
#    'Current Employee',
#    ' more than 8 years',
#    'low paid, slow growth, tech suppport poor',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    58)],
#  [('12 Jun 2022 ',
#    ' VP- Operations',
#    'Current Employee',
#    ' more than 10 years',
#    '1',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    59),
#   ('12 Jun 2022 ',
#    ' VP- Operations',
#    'Current Employee',
#    ' more than 10 years',
#    'standard pay increase and bonus_x000d_',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    59),
#   ('12 Jun 2022 ',
#    ' VP- Operations',
#    'Current Employee',
#    ' more than 10 years',
#    '2',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    59),
#   ('12 Jun 2022 ',
#    ' VP- Operations',
#    'Current Employee',
#    ' more than 10 years',
#    'regional driven_x000d_',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    59),
#   ('12 Jun 2022 ',
#    ' VP- Operations',
#    'Current Employee',
#    ' more than 10 years',
#    '3',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    59),
#   ('12 Jun 2022 ',
#    ' VP- Operations',
#    'Current Employee',
#    ' more than 10 years',
#    'fast pace',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    59)],
#  [('11 Jun 2022 ',
#    ' Anonymous Employee',
#    'Current Employee',
#    ' more than 3 years',
#    'salary could be higher as it is still relatively lower as compared to other banks.',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    60)],
#  [('11 Jun 2022 ',
#    ' Assistant Vice President',
#    'Current Employee',
#    nan,
#    'package not good at avp level',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    61)],
#  [('10 Jun 2022 ',
#    ' Anonymous Employee',
#    'Current Employee',
#    ' more than 1 year',
#    'heavy workload _x000d_',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    62),
#   ('10 Jun 2022 ',
#    ' Anonymous Employee',
#    'Current Employee',
#    ' more than 1 year',
#    'always overtime working',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    62)],
#  [('9 Jun 2022 ',
#    ' Anonymous Contractor',
#    'Current Contractor',
#    ' less than 1 year',
#    'unnecessary philosophical debates and lack of pantry.',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    63)],
#  [('9 Jun 2022 ',
#    ' Database Administrator (DBA)',
#    'Current Employee',
#    nan,
#    'no appreciation ',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    64),
#   ('9 Jun 2022 ',
#    ' Database Administrator (DBA)',
#    'Current Employee',
#    nan,
#    'high volume of work',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    64)],
#  [('9 Jun 2022 ',
#    ' AVP-Operations',
#    'Current Employee',
#    ' less than 1 year',
#    'pressure in other product sales',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    65)],
#  [('9 Jun 2022 ',
#    ' IT Engineer',
#    'Former Employee',
#    ' more than 5 years',
#    'quite stress for the daily ad-hoc request',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    66)],
#  [('9 Jun 2022 ',
#    ' Anonymous Employee',
#    'Current Employee',
#    nan,
#    'salary not competitive with other bank',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    67)],
#  [('9 Jun 2022 ',
#    ' Relationship Manager',
#    'Former Employee',
#    ' more than 3 years',
#    'cut throat culture with high turnover rate if your sales is not up to par.',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    68)],
#  [('9 Jun 2022 ',
#    ' Assistant Officer',
#    'Current Employee',
#    ' more than 3 years',
#    'politics runs around, boot lickers are promoted management is shrewd and quite unhealthy for mental piece',
#    'Not Recommended',
#    'Neutral',
#    'Not Recommended',
#    69)],
#  [('9 Jun 2022 ',
#    ' Software Engineer',
#    'Current Employee',
#    ' less than 1 year',
#    'bunch of paperworks and have to deal with people',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    70)],
#  [('9 Jun 2022 ',
#    ' Senior Associate',
#    'Former Employee',
#    ' more than 3 years',
#    'lack of work life balance',
#    'Not Recommended',
#    'Recommended',
#    'Recommended',
#    71)],
#  [('8 Jun 2022 ',
#    ' Senior Security Engineer',
#    'Current Employee',
#    ' more than 3 years',
#    'org structure is ever changing',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    72)],
#  [('8 Jun 2022 ',
#    ' Senior Associate',
#    'Former Employee',
#    ' more than 5 years',
#    'some toxic bosses, high turnover in certain departments, salary is not as competitive',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    73)],
#  [('8 Jun 2022 ',
#    ' Senior Associate',
#    'Current Employee',
#    nan,
#    'need ot all the week in the peak period',
#    'Recommended',
#    'Not Recommended',
#    'Neutral',
#    74)],
#  [('7 Jun 2022 ',
#    ' AVP-Project Manager',
#    'Former Employee',
#    ' more than 5 years',
#    'toxic old timers with unreasonable ask and worse of all is nothing is done even after complaining',
#    'Recommended',
#    'Recommended',
#    'Not Recommended',
#    75),
#   ('7 Jun 2022 ',
#    ' AVP-Project Manager',
#    'Former Employee',
#    ' more than 5 years',
#    'job is good but manager and environment is toxic.',
#    'Recommended',
#    'Recommended',
#    'Not Recommended',
#    75)],
#  [('7 Jun 2022 ',
#    ' Seeder',
#    'Current Employee',
#    ' less than 1 year',
#    'may need to ot sometimes due to time difference with other countries',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    76)],
#  [('7 Jun 2022 ',
#    ' Senior Assocaiate',
#    'Former Employee',
#    ' more than 3 years',
#    'server is not fast enough_x000d_',
#    'Recommended',
#    'Not Recommended',
#    'Recommended',
#    77),
#   ('7 Jun 2022 ',
#    ' Senior Assocaiate',
#    'Former Employee',
#    ' more than 3 years',
#    'lots of transformation / migration to work on',
#    'Recommended',
#    'Not Recommended',
#    'Recommended',
#    77)],
#  [('7 Jun 2022 ',
#    ' Anonymous Employee',
#    'Former Employee',
#    ' more than 1 year',
#    'management try their best to keep manpower lean',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    78)],
#  [('6 Jun 2022 ',
#    ' Sales Representative',
#    'Former Employee',
#    nan,
#    'mirco-management at its all time high with your supervisors tracking every call you are making on a daily basis',
#    'Neutral',
#    'Recommended',
#    'Not Recommended',
#    79),
#   ('6 Jun 2022 ',
#    ' Sales Representative',
#    'Former Employee',
#    nan,
#    'commissions paid out not worth it as you can get a higher pay package from other insurance companies.',
#    'Neutral',
#    'Recommended',
#    'Not Recommended',
#    79)],
#  [('6 Jun 2022 ',
#    ' Software Engineer',
#    'Current Employee',
#    nan,
#    'cant thank of any cons',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    80)],
#  [('6 Jun 2022 ',
#    ' SVP-Service Delivery Executive',
#    'Current Employee',
#    ' more than 8 years',
#    'bad working environment toxic management and politics',
#    'Not Recommended',
#    'Recommended',
#    'Recommended',
#    81)],
#  [('5 Jun 2022 ',
#    ' Relationship Manager',
#    'Current Employee',
#    ' more than 1 year',
#    'salary can be higher',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    82),
#   ('5 Jun 2022 ',
#    ' Relationship Manager',
#    'Current Employee',
#    ' more than 1 year',
#    'that’s all.',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    82)],
#  [('5 Jun 2022 ',
#    ' Assistant Manager',
#    'Current Employee',
#    ' more than 5 years',
#    'none that i can think of',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    83)],
#  [('5 Jun 2022 ',
#    ' Sales',
#    'Current Employee',
#    nan,
#    'very stressful work place !!',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    84)],
#  [('4 Jun 2022 ',
#    ' Investment Advisor',
#    'Former Employee',
#    nan,
#    'nothing bad about this company',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    85)],
#  [('3 Jun 2022 ',
#    ' Technical Lead',
#    'Current Employee',
#    nan,
#    'with over 20 years in tech, i can safely say this is by far the worst technology leadership i have seen in my career',
#    'Neutral',
#    'Neutral',
#    'Not Recommended',
#    86),
#   ('3 Jun 2022 ',
#    ' Technical Lead',
#    'Current Employee',
#    nan,
#    'not just in india but in singapore too.',
#    'Neutral',
#    'Neutral',
#    'Not Recommended',
#    86),
#   ('3 Jun 2022 ',
#    ' Technical Lead',
#    'Current Employee',
#    nan,
#    '',
#    'Neutral',
#    'Neutral',
#    'Not Recommended',
#    86),
#   ('3 Jun 2022 ',
#    ' Technical Lead',
#    'Current Employee',
#    nan,
#    'c2e known to be the best culture is now ruined by the new leadership taking over in singapore and hyderabad',
#    'Neutral',
#    'Neutral',
#    'Not Recommended',
#    86),
#   ('3 Jun 2022 ',
#    ' Technical Lead',
#    'Current Employee',
#    nan,
#    'the 2 men put in these roles as head of c2e in singapore and hyderabad neither have leadership experience nor any knowledge of modern tech stack',
#    'Neutral',
#    'Neutral',
#    'Not Recommended',
#    86),
#   ('3 Jun 2022 ',
#    ' Technical Lead',
#    'Current Employee',
#    nan,
#    'these are dinosaurs been in the bank for decades and bringing the poor culture from their earlier lobt to c2e',
#    'Neutral',
#    'Neutral',
#    'Not Recommended',
#    86),
#   ('3 Jun 2022 ',
#    ' Technical Lead',
#    'Current Employee',
#    nan,
#    'all the good work done by the predecessor is now seen as eroding',
#    'Neutral',
#    'Neutral',
#    'Not Recommended',
#    86),
#   ('3 Jun 2022 ',
#    ' Technical Lead',
#    'Current Employee',
#    nan,
#    'many leaders have quit',
#    'Neutral',
#    'Neutral',
#    'Not Recommended',
#    86),
#   ('3 Jun 2022 ',
#    ' Technical Lead',
#    'Current Employee',
#    nan,
#    '',
#    'Neutral',
#    'Neutral',
#    'Not Recommended',
#    86),
#   ('3 Jun 2022 ',
#    ' Technical Lead',
#    'Current Employee',
#    nan,
#    '',
#    'Neutral',
#    'Neutral',
#    'Not Recommended',
#    86),
#   ('3 Jun 2022 ',
#    ' Technical Lead',
#    'Current Employee',
#    nan,
#    'in all dbs open, t&o open several feedback has been given and yet piyush you have turned a blind eye',
#    'Neutral',
#    'Neutral',
#    'Not Recommended',
#    86),
#   ('3 Jun 2022 ',
#    ' Technical Lead',
#    'Current Employee',
#    nan,
#    'running complex projects does not require a hitler, it requires empathetic leadership',
#    'Neutral',
#    'Neutral',
#    'Not Recommended',
#    86),
#   ('3 Jun 2022 ',
#    ' Technical Lead',
#    'Current Employee',
#    nan,
#    'it requires younger people who bring in new ways of working and running things truly agile.',
#    'Neutral',
#    'Neutral',
#    'Not Recommended',
#    86),
#   ('3 Jun 2022 ',
#    ' Technical Lead',
#    'Current Employee',
#    nan,
#    '',
#    'Neutral',
#    'Neutral',
#    'Not Recommended',
#    86),
#   ('3 Jun 2022 ',
#    ' Technical Lead',
#    'Current Employee',
#    nan,
#    'the new leader of c2e has zero interaction with the team',
#    'Neutral',
#    'Neutral',
#    'Not Recommended',
#    86),
#   ('3 Jun 2022 ',
#    ' Technical Lead',
#    'Current Employee',
#    nan,
#    'he operates in silos and in a manner that would have suited 25 years ago',
#    'Neutral',
#    'Neutral',
#    'Not Recommended',
#    86),
#   ('3 Jun 2022 ',
#    ' Technical Lead',
#    'Current Employee',
#    nan,
#    'no wonder so many people are leaving the bank.',
#    'Neutral',
#    'Neutral',
#    'Not Recommended',
#    86),
#   ('3 Jun 2022 ',
#    ' Technical Lead',
#    'Current Employee',
#    nan,
#    '',
#    'Neutral',
#    'Neutral',
#    'Not Recommended',
#    86),
#   ('3 Jun 2022 ',
#    ' Technical Lead',
#    'Current Employee',
#    nan,
#    'even in hyderabad it is a sweatshop',
#    'Neutral',
#    'Neutral',
#    'Not Recommended',
#    86),
#   ('3 Jun 2022 ',
#    ' Technical Lead',
#    'Current Employee',
#    nan,
#    'unrealistic timelines , agile for the sake of it, being pushed to work weekends',
#    'Neutral',
#    'Neutral',
#    'Not Recommended',
#    86),
#   ('3 Jun 2022 ',
#    ' Technical Lead',
#    'Current Employee',
#    nan,
#    'some leaders are trying hard to change culture and bring in agile ways but it is not being heard',
#    'Neutral',
#    'Neutral',
#    'Not Recommended',
#    86),
#   ('3 Jun 2022 ',
#    ' Technical Lead',
#    'Current Employee',
#    nan,
#    'they are being shut down totally.',
#    'Neutral',
#    'Neutral',
#    'Not Recommended',
#    86),
#   ('3 Jun 2022 ',
#    ' Technical Lead',
#    'Current Employee',
#    nan,
#    '',
#    'Neutral',
#    'Neutral',
#    'Not Recommended',
#    86),
#   ('3 Jun 2022 ',
#    ' Technical Lead',
#    'Current Employee',
#    nan,
#    'ibgt which is known to be the worst area of dbs is now slowly ruling c2e',
#    'Neutral',
#    'Neutral',
#    'Not Recommended',
#    86),
#   ('3 Jun 2022 ',
#    ' Technical Lead',
#    'Current Employee',
#    nan,
#    'it seems like they have put in a puppet in c2e who is so fearful of others that he simply cannot lead from the front',
#    'Neutral',
#    'Neutral',
#    'Not Recommended',
#    86),
#   ('3 Jun 2022 ',
#    ' Technical Lead',
#    'Current Employee',
#    nan,
#    '',
#    'Neutral',
#    'Neutral',
#    'Not Recommended',
#    86),
#   ('3 Jun 2022 ',
#    ' Technical Lead',
#    'Current Employee',
#    nan,
#    '',
#    'Neutral',
#    'Neutral',
#    'Not Recommended',
#    86),
#   ('3 Jun 2022 ',
#    ' Technical Lead',
#    'Current Employee',
#    nan,
#    'piyush says that the company is agile, it is far from that',
#    'Neutral',
#    'Neutral',
#    'Not Recommended',
#    86),
#   ('3 Jun 2022 ',
#    ' Technical Lead',
#    'Current Employee',
#    nan,
#    ' most leaders simply do not even know what agile roles are, what an agile team is and how it must operate',
#    'Neutral',
#    'Neutral',
#    'Not Recommended',
#    86),
#   ('3 Jun 2022 ',
#    ' Technical Lead',
#    'Current Employee',
#    nan,
#    'they just quote from some theory and expect that',
#    'Neutral',
#    'Neutral',
#    'Not Recommended',
#    86),
#   ('3 Jun 2022 ',
#    ' Technical Lead',
#    'Current Employee',
#    nan,
#    'earlier leadership in c2e had brought in a great culture and brought in specialists to make this org agile, but now the new leadership is wiping it all out in the name of cost saving',
#    'Neutral',
#    'Neutral',
#    'Not Recommended',
#    86),
#   ('3 Jun 2022 ',
#    ' Technical Lead',
#    'Current Employee',
#    nan,
#    '',
#    'Neutral',
#    'Neutral',
#    'Not Recommended',
#    86),
#   ('3 Jun 2022 ',
#    ' Technical Lead',
#    'Current Employee',
#    nan,
#    '',
#    'Neutral',
#    'Neutral',
#    'Not Recommended',
#    86),
#   ('3 Jun 2022 ',
#    ' Technical Lead',
#    'Current Employee',
#    nan,
#    'piyush if you still do not open your eyes to reality and get down to the ground level, come to the next level leaders and talk to them then very soon this bank will go back to the stone age.',
#    'Neutral',
#    'Neutral',
#    'Not Recommended',
#    86)],
#  [('3 Jun 2022 ',
#    ' Vice President',
#    'Current Employee',
#    nan,
#    'low treatment for it staff',
#    'Recommended',
#    'Not Recommended',
#    'Recommended',
#    87),
#   ('3 Jun 2022 ',
#    ' Vice President',
#    'Current Employee',
#    nan,
#    'selective policy towards staff in terms of `it claimed it company` approach',
#    'Recommended',
#    'Not Recommended',
#    'Recommended',
#    87)],
#  [('2 Jun 2022 ',
#    ' Associate',
#    'Current Employee',
#    nan,
#    'low salary compare to market',
#    'Neutral',
#    'Recommended',
#    'Recommended',
#    88)],
#  [('2 Jun 2022 ',
#    ' Anonymous Contractor',
#    'Current Contractor',
#    ' less than 1 year',
#    'there is no cons about this job',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    89)],
#  [('2 Jun 2022 ',
#    ' Senior Associate',
#    'Current Employee',
#    ' more than 5 years',
#    'currently pretty much politicised much like an indian bank',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    90)],
#  [('2 Jun 2022 ',
#    ' Applications Support Analyst',
#    'Former Contractor',
#    ' more than 1 year',
#    'after a while, need to be practically brain dead to do the job',
#    'Recommended',
#    'Not Recommended',
#    'Recommended',
#    91)],
#  [('2 Jun 2022 ',
#    ' Employee Relations Specialist',
#    'Current Contractor',
#    ' more than 1 year',
#    'no bonus, no extra allowance',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    92)],
#  [('2 Jun 2022 ',
#    ' Software Developer',
#    'Current Employee',
#    nan,
#    'not enough seats_x000d_',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    93),
#   ('2 Jun 2022 ',
#    ' Software Developer',
#    'Current Employee',
#    nan,
#    'not enough coding for me',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    93)],
#  [('2 Jun 2022 ',
#    ' Senior Manager',
#    'Current Employee',
#    ' more than 10 years',
#    'lack of growth opportunities when outside mumbai',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    94)],
#  [('1 Jun 2022 ',
#    ' KYC Officer',
#    'Current Employee',
#    nan,
#    'very fast pace environment',
#    'Recommended',
#    'Recommended',
#    'Neutral',
#    95),
#   ('1 Jun 2022 ',
#    ' KYC Officer',
#    'Current Employee',
#    nan,
#    'need to be fast and furious.',
#    'Recommended',
#    'Recommended',
#    'Neutral',
#    95)],
#  [('1 Jun 2022 ',
#    ' Financial Planner',
#    'Former Employee',
#    ' less than 1 year',
#    'long working hours _x000d_',
#    'Not Recommended',
#    'Recommended',
#    'Not Recommended',
#    96),
#   ('1 Jun 2022 ',
#    ' Financial Planner',
#    'Former Employee',
#    ' less than 1 year',
#    'stressful_x000d_',
#    'Not Recommended',
#    'Recommended',
#    'Not Recommended',
#    96),
#   ('1 Jun 2022 ',
#    ' Financial Planner',
#    'Former Employee',
#    ' less than 1 year',
#    'not worth',
#    'Not Recommended',
#    'Recommended',
#    'Not Recommended',
#    96)],
#  [('1 Jun 2022 ',
#    ' Executive Director',
#    'Current Employee',
#    ' more than 1 year',
#    'very few, not meaningful to mention.',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    97)],
#  [('1 Jun 2022 ',
#    ' Senior Project Associate',
#    'Current Employee',
#    ' more than 3 years',
#    'management take engineering decisions_x000d_',
#    'Recommended',
#    'Recommended',
#    'Neutral',
#    98),
#   ('1 Jun 2022 ',
#    ' Senior Project Associate',
#    'Current Employee',
#    ' more than 3 years',
#    'team leads are just for namesake and no one cares about code quality,',
#    'Recommended',
#    'Recommended',
#    'Neutral',
#    98)],
#  [('31 May 2022 ',
#    ' Anonymous Contractor',
#    'Current Contractor',
#    nan,
#    'office location may not be desirable as most offices for tech related roles are at ends of singapore.',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    99)],
#  [('31 May 2022 ',
#    ' Anonymous Employee',
#    'Current Employee',
#    ' more than 3 years',
#    'not application for the moment',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    100)],
#  [('31 May 2022 ',
#    ' Senior Relationship Manager',
#    'Current Employee',
#    ' more than 5 years',
#    'work is hectic to the core.',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    101)],
#  [('31 May 2022 ',
#    ' IT Contractor',
#    'Current Employee',
#    nan,
#    'there are lot of policies to follow',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    102)],
#  [('31 May 2022 ',
#    ' Officer',
#    'Current Employee',
#    ' less than 1 year',
#    'long hours sometimes, not enough assistance.',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    103)],
#  [('30 May 2022 ',
#    ' Anonymous Contractor',
#    'Former Contractor',
#    ' more than 1 year',
#    'low salary and slow progression',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    104)],
#  [('30 May 2022 ',
#    ' Operational Risk Specialist',
#    'Former Employee',
#    ' more than 3 years',
#    'depends on whether your department/team follows the culture set out by senior management',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    105)],
#  [('29 May 2022 ',
#    ' Relationship Manager',
#    'Former Employee',
#    nan,
#    'solo working style to chase sales',
#    'Neutral',
#    'Recommended',
#    'Neutral',
#    106)],
#  [('29 May 2022 ',
#    ' Wealth Manager',
#    'Current Employee',
#    nan,
#    'long working hours and high kpo',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    107)],
#  [('28 May 2022 ',
#    ' Customer Service Representative',
#    'Former Employee',
#    ' more than 1 year',
#    'bad environment _x000d_',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    108),
#   ('28 May 2022 ',
#    ' Customer Service Representative',
#    'Former Employee',
#    ' more than 1 year',
#    'need to handle fo and bo stuff_x000d_',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    108),
#   ('28 May 2022 ',
#    ' Customer Service Representative',
#    'Former Employee',
#    ' more than 1 year',
#    'low salary',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    108)],
#  [('28 May 2022 ',
#    ' Assistant Relationship Manager Private Banking',
#    'Former Employee',
#    ' more than 3 years',
#    'arms are required to cover everything.',
#    'Neutral',
#    'Recommended',
#    'Neutral',
#    109)],
#  [('27 May 2022 ',
#    ' Assistant Relationship Manager',
#    'Current Employee',
#    ' more than 1 year',
#    'have to take up the responsibility of rm sometimes',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    110)],
#  [('26 May 2022 ',
#    ' AVP-Project Manager',
#    'Former Employee',
#    ' more than 8 years',
#    'fast paced but at the same time this gives bigger opportunities to learn as well',
#    'Recommended',
#    'Recommended',
#    'Neutral',
#    111)],
#  [('26 May 2022 ',
#    ' Senior Wealth Planning Manager',
#    'Current Employee',
#    nan,
#    'being in a sales line = no work life balance',
#    'Recommended',
#    'Recommended',
#    'Neutral',
#    112)],
#  [('26 May 2022 ',
#    ' Software Engineer',
#    'Current Employee',
#    ' more than 1 year',
#    'too much redundant security measures such that developers are limited access to new technologies advancement and innovative',
#    'Recommended',
#    'Not Recommended',
#    'Recommended',
#    113),
#   ('26 May 2022 ',
#    ' Software Engineer',
#    'Current Employee',
#    ' more than 1 year',
#    'i cant use flutter and docker and k8s sadly to have my own playground',
#    'Recommended',
#    'Not Recommended',
#    'Recommended',
#    113),
#   ('26 May 2022 ',
#    ' Software Engineer',
#    'Current Employee',
#    ' more than 1 year',
#    '_x000d_',
#    'Recommended',
#    'Not Recommended',
#    'Recommended',
#    113),
#   ('26 May 2022 ',
#    ' Software Engineer',
#    'Current Employee',
#    ' more than 1 year',
#    'most senior contributors and pioneers have left the role and can expect heavier responsibilities and efforts needed to maintain or scaling current bau applications.',
#    'Recommended',
#    'Not Recommended',
#    'Recommended',
#    113)],
#  [('26 May 2022 ',
#    ' Anonymous Employee',
#    'Current Employee',
#    ' more than 5 years',
#    'aggressive and unreasonable timelines',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    114),
#   ('26 May 2022 ',
#    ' Anonymous Employee',
#    'Current Employee',
#    ' more than 5 years',
#    'a lot of weekend works due',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    114),
#   ('26 May 2022 ',
#    ' Anonymous Employee',
#    'Current Employee',
#    ' more than 5 years',
#    "it's a bank, not an it company so main focus is still with how bank operates",
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    114),
#   ('26 May 2022 ',
#    ' Anonymous Employee',
#    'Current Employee',
#    ' more than 5 years',
#    'high turnaround rate for both contract and permanent staff.',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    114)],
#  [('25 May 2022 ',
#    ' Software Engineer',
#    'Current Employee',
#    ' more than 1 year',
#    'sometimes team projects can get messy',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    115)],
#  [('25 May 2022 ',
#    ' Data Analyst',
#    'Former Contractor',
#    ' more than 5 years',
#    'you will have too many people working on a project',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    116),
#   ('25 May 2022 ',
#    ' Data Analyst',
#    'Former Contractor',
#    ' more than 5 years',
#    'you will see too many svps and above and be surprised at their lack of domain knowledge, managerial, and technical competence.',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    116)],
#  [('25 May 2022 ',
#    ' Associate',
#    'Current Employee',
#    ' less than 1 year',
#    'no planning of any thing, requirements will keep on coming',
#    'Not Recommended',
#    'Neutral',
#    'Neutral',
#    117)],
#  [('25 May 2022 ',
#    ' Corporate Loans Analyst',
#    'Former Contractor',
#    ' more than 1 year',
#    'little and slow career progression',
#    'Recommended',
#    'Not Recommended',
#    'Neutral',
#    118)],
#  [('24 May 2022 ',
#    ' Analyst',
#    'Current Employee',
#    nan,
#    'none.',
#    'Neutral',
#    'Recommended',
#    'Neutral',
#    119),
#   ('24 May 2022 ',
#    ' Analyst',
#    'Current Employee',
#    nan,
#    'i don’t see any cons',
#    'Neutral',
#    'Recommended',
#    'Neutral',
#    119)],
#  [('24 May 2022 ',
#    ' Vice President',
#    'Current Employee',
#    ' more than 3 years',
#    'there are always 50,000 things to do and everything needs to be done yesterday.',
#    'Not Recommended',
#    'Not Recommended',
#    'Recommended',
#    120)],
#  [('24 May 2022 ',
#    ' Associate',
#    'Current Employee',
#    ' more than 8 years',
#    'too little help to many tasks.',
#    'Recommended',
#    'Not Recommended',
#    'Neutral',
#    121)],
#  [('24 May 2022 ',
#    ' Project Manager',
#    'Current Employee',
#    nan,
#    '- uneven distribution of compensation among various departments',
#    'Neutral',
#    'Not Recommended',
#    'Neutral',
#    122),
#   ('24 May 2022 ',
#    ' Project Manager',
#    'Current Employee',
#    nan,
#    '- ot no work-life balance',
#    'Neutral',
#    'Not Recommended',
#    'Neutral',
#    122),
#   ('24 May 2022 ',
#    ' Project Manager',
#    'Current Employee',
#    nan,
#    '- various departments work in silos',
#    'Neutral',
#    'Not Recommended',
#    'Neutral',
#    122)],
#  [('24 May 2022 ',
#    ' Dealer',
#    'Former Contractor',
#    ' more than 1 year',
#    'hierarchy system maintained in the organiasation',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    123)],
#  [('23 May 2022 ',
#    ' Anonymous Employee',
#    'Current Employee',
#    nan,
#    'everything else especially the management',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    124)],
#  [('23 May 2022 ',
#    ' Anonymous Employee',
#    'Former Employee',
#    nan,
#    'too sales driven, high turnover rate',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    125)],
#  [('23 May 2022 ',
#    ' Internship',
#    'Current Employee',
#    ' less than 1 year',
#    'no cons at all during my internship',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    126)],
#  [('23 May 2022 ',
#    ' Manager',
#    'Former Contractor',
#    nan,
#    'work- life balance has to be worked upon',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    127)],
#  [('23 May 2022 ',
#    ' SVP Product',
#    'Current Employee',
#    nan,
#    'in reality:',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    128),
#   ('23 May 2022 ',
# ...
#    ' Wealth Planning Manager',
#    'Current Employee',
#    nan,
#    'healthy competition is one thing, unnecessary toxicity that inhibits well-being and performance is another',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    942)],
#  [('2 Nov 2021 ',
#    ' Customer Service Officer',
#    'Former Employee',
#    ' more than 1 year',
#    'none.i can’t think of any',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    943)],
#  [('2 Nov 2021 ',
#    ' Manager',
#    'Current Employee',
#    ' more than 3 years',
#    'none i can think of',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    944)],
#  [('1 Nov 2021 ',
#    ' AVP-Operations',
#    'Current Employee',
#    nan,
#    'too many administrative tasks in addition to daily bau activities',
#    'Recommended',
#    'Recommended',
#    'Neutral',
#    945)],
#  [('1 Nov 2021 ',
#    ' Anonymous Employee',
#    'Current Employee',
#    nan,
#    'poor renumeration and limited opportunities',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    946)],
#  [('1 Nov 2021 ',
#    ' Wealth Planning Manager',
#    'Current Employee',
#    ' more than 1 year',
#    'what started off as a month for to contact clients became 3 weeks then subsequently 2 weeks.',
#    'Not Recommended',
#    'Neutral',
#    'Neutral',
#    947),
#   ('1 Nov 2021 ',
#    ' Wealth Planning Manager',
#    'Current Employee',
#    ' more than 1 year',
#    '',
#    'Not Recommended',
#    'Neutral',
#    'Neutral',
#    947),
#   ('1 Nov 2021 ',
#    ' Wealth Planning Manager',
#    'Current Employee',
#    ' more than 1 year',
#    'number of clients expected to be contacted remained at roughly 150-200, targets stayed similar as well',
#    'Not Recommended',
#    'Neutral',
#    'Neutral',
#    947),
#   ('1 Nov 2021 ',
#    ' Wealth Planning Manager',
#    'Current Employee',
#    ' more than 1 year',
#    'zero compassion for clients "close first and pray they dont cancel" mentality.',
#    'Not Recommended',
#    'Neutral',
#    'Neutral',
#    947),
#   ('1 Nov 2021 ',
#    ' Wealth Planning Manager',
#    'Current Employee',
#    ' more than 1 year',
#    '',
#    'Not Recommended',
#    'Neutral',
#    'Neutral',
#    947),
#   ('1 Nov 2021 ',
#    ' Wealth Planning Manager',
#    'Current Employee',
#    ' more than 1 year',
#    'attrition rate at an all time high.',
#    'Not Recommended',
#    'Neutral',
#    'Neutral',
#    947)],
#  [('1 Nov 2021 ',
#    ' Senior Associate',
#    'Current Employee',
#    ' more than 3 years',
#    'work life balance is not good.',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    948)],
#  [('1 Nov 2021 ',
#    ' Branch Manager',
#    'Former Employee',
#    ' more than 3 years',
#    'weekend banking is unavoidable as part of retail banking',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    949)],
#  [('31 Oct 2021 ',
#    ' Senior Associate',
#    'Former Employee',
#    nan,
#    'long working hours',
#    'Not Recommended',
#    'Recommended',
#    'Recommended',
#    950),
#   ('31 Oct 2021 ',
#    ' Senior Associate',
#    'Former Employee',
#    nan,
#    'rushing and fire fightings',
#    'Not Recommended',
#    'Recommended',
#    'Recommended',
#    950)],
#  [('31 Oct 2021 ',
#    ' Relationship Manager',
#    'Current Employee',
#    nan,
#    'nothing i can think of',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    951)],
#  [('31 Oct 2021 ',
#    ' Assistant Vice President',
#    'Current Employee',
#    ' more than 1 year',
#    'work load can get very heavy and fast paced',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    952)],
#  [('31 Oct 2021 ',
#    ' IT Support Specialist',
#    'Current Employee',
#    nan,
#    'work life balance may be insufficient',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    953)],
#  [('30 Oct 2021 ',
#    ' Software Engineer',
#    'Current Employee',
#    nan,
#    'sometime is very busy, but still hold the working life balance.',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    954)],
#  [('30 Oct 2021 ',
#    ' Assistant Vice President',
#    'Current Employee',
#    ' more than 3 years',
#    'bonus is low at 2-3mths and promotion path is slow',
#    'Not Recommended',
#    'Neutral',
#    'Not Recommended',
#    955)],
#  [('29 Oct 2021 ',
#    ' Bank Executive',
#    'Former Contractor',
#    nan,
#    'quite political, so watch out',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    956)],
#  [('29 Oct 2021 ',
#    ' Senior Credit Analyst',
#    'Current Employee',
#    nan,
#    'some colleagues likes to play politics, which is normal in big organization',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    957)],
#  [('29 Oct 2021 ',
#    ' Associate',
#    'Current Employee',
#    ' more than 5 years',
#    'zero work life balance',
#    'Not Recommended',
#    'Neutral',
#    'Recommended',
#    958),
#   ('29 Oct 2021 ',
#    ' Associate',
#    'Current Employee',
#    ' more than 5 years',
#    'you’re expected to be on call 24/7',
#    'Not Recommended',
#    'Neutral',
#    'Recommended',
#    958),
#   ('29 Oct 2021 ',
#    ' Associate',
#    'Current Employee',
#    ' more than 5 years',
#    'most of the people do not respect your time (perpetually late for meetings, scheduling lunch or late night meetings)',
#    'Not Recommended',
#    'Neutral',
#    'Recommended',
#    958),
#   ('29 Oct 2021 ',
#    ' Associate',
#    'Current Employee',
#    ' more than 5 years',
#    'rank-play and disregard for people who are below their rank',
#    'Not Recommended',
#    'Neutral',
#    'Recommended',
#    958),
#   ('29 Oct 2021 ',
#    ' Associate',
#    'Current Employee',
#    ' more than 5 years',
#    'very toxic environment',
#    'Not Recommended',
#    'Neutral',
#    'Recommended',
#    958),
#   ('29 Oct 2021 ',
#    ' Associate',
#    'Current Employee',
#    ' more than 5 years',
#    'a lot of people are overworked and stretched due to the headcount freeze.',
#    'Not Recommended',
#    'Neutral',
#    'Recommended',
#    958)],
#  [('29 Oct 2021 ',
#    ' Risk Manager',
#    'Former Employee',
#    ' more than 5 years',
#    'almost all are nightmare memories',
#    'Not Recommended',
#    'Not Recommended',
#    'Not Recommended',
#    959)],
#  [('29 Oct 2021 ',
#    ' Analyst',
#    'Current Employee',
#    ' more than 3 years',
#    'no progression, manual handlings and lots of enhancements to be done',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    960)],
#  [('28 Oct 2021 ',
#    ' Wealth Planning Manager',
#    'Current Employee',
#    ' more than 1 year',
#    'upper management decisions may not be ideal for staff on the ground.',
#    'Recommended',
#    'Recommended',
#    'Not Recommended',
#    961)],
#  [('28 Oct 2021 ',
#    ' Project Support Trainee',
#    'Former Contractor',
#    ' less than 1 year',
#    'full-time work from home, monotonous.',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    962)],
#  [('28 Oct 2021 ',
#    ' Compensation and Benefits Specialist',
#    'Former Employee',
#    ' more than 3 years',
#    '1',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    963),
#   ('28 Oct 2021 ',
#    ' Compensation and Benefits Specialist',
#    'Former Employee',
#    ' more than 3 years',
#    'balance between strategizing and execution can be better',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    963),
#   ('28 Oct 2021 ',
#    ' Compensation and Benefits Specialist',
#    'Former Employee',
#    ' more than 3 years',
#    'sometimes felt like things move real slow given the highly matrixed style of working',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    963)],
#  [('28 Oct 2021 ',
#    ' Vice President',
#    'Current Employee',
#    ' more than 10 years',
#    'long working hours with huge pressure',
#    'Recommended',
#    'Neutral',
#    'Recommended',
#    964)],
#  [('27 Oct 2021 ',
#    ' Anonymous Contractor',
#    'Former Contractor',
#    ' less than 1 year',
#    'lots of meetings, but really a cons for me',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    965)],
#  [('27 Oct 2021 ',
#    ' Relationship Manager',
#    'Current Employee',
#    nan,
#    'no cons so far in my line',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    966)],
#  [('27 Oct 2021 ',
#    ' CSO/CISO',
#    'Former Contractor',
#    ' less than 1 year',
#    'horrible steep kpi to achieve',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    967),
#   ('27 Oct 2021 ',
#    ' CSO/CISO',
#    'Former Contractor',
#    ' less than 1 year',
#    'you cant take leave as and when you need',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    967),
#   ('27 Oct 2021 ',
#    ' CSO/CISO',
#    'Former Contractor',
#    ' less than 1 year',
#    'if you are getting married too bad they wont grant leave.',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    967)],
#  [('27 Oct 2021 ',
#    ' Analyst',
#    'Current Employee',
#    ' more than 1 year',
#    'high transactional volume, no work life balance, management tends to show favouritism',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    968)],
#  [('26 Oct 2021 ',
#    ' Anonymous Employee',
#    'Current Employee',
#    ' more than 1 year',
#    'very few hikes and incentives.',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    969)],
#  [('25 Oct 2021 ',
#    ' Business Analyst',
#    'Current Employee',
#    ' more than 1 year',
#    'multi level hierarchy difficult to channel ideas and opnions.',
#    'Recommended',
#    'Neutral',
#    'Recommended',
#    970)],
#  [('25 Oct 2021 ',
#    ' Anonymous Contractor',
#    'Current Contractor',
#    ' less than 1 year',
#    'lots of red tape in work',
#    'Not Recommended',
#    'Neutral',
#    'Recommended',
#    971)],
#  [('25 Oct 2021 ',
#    ' Associate',
#    'Current Employee',
#    ' more than 3 years',
#    'organic growth pay scale might be slow',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    972)],
#  [('24 Oct 2021 ',
#    ' Assistant Manager',
#    'Current Employee',
#    nan,
#    'difficult kpi and targets and so on',
#    'Not Recommended',
#    'Neutral',
#    'Neutral',
#    973)],
#  [('24 Oct 2021 ',
#    ' Senior Relationship Manager',
#    'Current Employee',
#    nan,
#    'very busy busy busy busy',
#    'Recommended',
#    'Neutral',
#    'Neutral',
#    974)],
#  [('24 Oct 2021 ',
#    ' Analyst',
#    'Current Employee',
#    nan,
#    '- does not promote merit but experience_x000d_',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    975),
#   ('24 Oct 2021 ',
#    ' Analyst',
#    'Current Employee',
#    nan,
#    '- bosses does not fight for your promotion',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    975)],
#  [('24 Oct 2021 ',
#    ' Software Developer',
#    'Current Employee',
#    nan,
#    'not sure if higher ups really recognise the work you are doing',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    976)],
#  [('24 Oct 2021 ',
#    ' Executive Director',
#    'Current Employee',
#    ' more than 10 years',
#    'limited presence across the globe',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    977)],
#  [('23 Oct 2021 ',
#    ' Assistant Officer',
#    'Current Employee',
#    nan,
#    'too much work and scariest of deadline',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    978)],
#  [('23 Oct 2021 ',
#    ' Relationship Manager',
#    'Current Employee',
#    nan,
#    'a lot of red tapes',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    979)],
#  [('23 Oct 2021 ',
#    ' Relationship Manager',
#    'Current Employee',
#    ' less than 1 year',
#    'corporate culture and for those who like progression',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    980)],
#  [('23 Oct 2021 ',
#    ' Bank Teller',
#    'Former Contractor',
#    ' more than 1 year',
#    'high pressure, no proper training and guidance',
#    'Not Recommended',
#    'Not Recommended',
#    'Neutral',
#    981),
#   ('23 Oct 2021 ',
#    ' Bank Teller',
#    'Former Contractor',
#    ' more than 1 year',
#    'bad supervisory experience which bordered workplace bullying',
#    'Not Recommended',
#    'Not Recommended',
#    'Neutral',
#    981),
#   ('23 Oct 2021 ',
#    ' Bank Teller',
#    'Former Contractor',
#    ' more than 1 year',
#    'lack of diversity with very few locals and forgetting what the "s" mean in dbs',
#    'Not Recommended',
#    'Not Recommended',
#    'Neutral',
#    981),
#   ('23 Oct 2021 ',
#    ' Bank Teller',
#    'Former Contractor',
#    ' more than 1 year',
#    'a diasppointment after knowing the truth behind the facade of "xxxx best bank"',
#    'Not Recommended',
#    'Not Recommended',
#    'Neutral',
#    981),
#   ('23 Oct 2021 ',
#    ' Bank Teller',
#    'Former Contractor',
#    ' more than 1 year',
#    'a lack of competitive products and services.',
#    'Not Recommended',
#    'Not Recommended',
#    'Neutral',
#    981)],
#  [('21 Oct 2021 ',
#    ' Associate',
#    'Current Employee',
#    ' less than 1 year',
#    'lack of team work, non-cohesive culture, poor leadership',
#    'Not Recommended',
#    'Neutral',
#    'Recommended',
#    982)],
#  [('21 Oct 2021 ',
#    ' Investment Counselor',
#    'Current Employee',
#    ' more than 8 years',
#    'big organization cons and woes',
#    'Recommended',
#    'Neutral',
#    'Recommended',
#    983)],
#  [('21 Oct 2021 ',
#    ' Bank Officer',
#    'Former Employee',
#    ' more than 1 year',
#    'fast pace environment and sometimes need to work on weekends',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    984)],
#  [('21 Oct 2021 ',
#    ' Assistant Vice President',
#    'Current Employee',
#    ' more than 10 years',
#    'no cons is here ,except the salary',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    985)],
#  [('21 Oct 2021 ',
#    ' Vice President',
#    'Current Employee',
#    nan,
#    'focussed footprint in 6 core markets',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    986)],
#  [('21 Oct 2021 ',
#    ' Senior Associate',
#    'Current Employee',
#    ' more than 3 years',
#    'few projects doesn’t take care of employee work life balance',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    987)],
#  [('21 Oct 2021 ',
#    ' Analyst',
#    'Current Employee',
#    ' more than 1 year',
#    'no work life balance,long working hours',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    988)],
#  [('21 Oct 2021 ',
#    ' Analyst',
#    'Current Employee',
#    ' more than 1 year',
#    'no work life balance',
#    'Not Recommended',
#    'Recommended',
#    'Not Recommended',
#    989),
#   ('21 Oct 2021 ',
#    ' Analyst',
#    'Current Employee',
#    ' more than 1 year',
#    "can't work remotely forever",
#    'Not Recommended',
#    'Recommended',
#    'Not Recommended',
#    989)],
#  [('21 Oct 2021 ',
#    ' Relationship Banker',
#    'Current Employee',
#    nan,
#    'low pay as compared to competitios',
#    'Recommended',
#    'Recommended',
#    'Recommended',
#    990)],
#  [('20 Oct 2021 ',
#    ' Analyst',
#    'Current Employee',
#    nan,
#    'a lot ot and no ot pay',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    991)],
#  [('20 Oct 2021 ',
#    ' Business Analyst Entry Level',
#    'Current Employee',
#    nan,
#    'some people are difficult to work with',
#    'Recommended',
#    'Recommended',
#    'Neutral',
#    992)],
#  [('20 Oct 2021 ',
#    ' Sales Associate',
#    'Current Employee',
#    nan,
#    'the salaries are a bit low',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    993)],
#  [('19 Oct 2021 ',
#    ' Customer Service Operator (CSO)',
#    'Former Contractor',
#    ' more than 1 year',
#    'working hours are not fix ',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    994),
#   ('19 Oct 2021 ',
#    ' Customer Service Operator (CSO)',
#    'Former Contractor',
#    ' more than 1 year',
#    'always if you taker medical leave, there would be some comment stated by the higher up',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    994)],
#  [('18 Oct 2021 ',
#    ' Analyst',
#    'Current Employee',
#    ' less than 1 year',
#    'lower than average salary',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    995),
#   ('18 Oct 2021 ',
#    ' Analyst',
#    'Current Employee',
#    ' less than 1 year',
#    'progression slightly stagnant',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    995)],
#  [('18 Oct 2021 ',
#    ' Assistant Relationship Manager',
#    'Current Employee',
#    nan,
#    'salary on the low side.',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    996)],
#  [('18 Oct 2021 ',
#    ' Customer Service Ambassador',
#    'Former Employee',
#    ' more than 1 year',
#    'the back office departments lacks support and communication.',
#    'Recommended',
#    'Neutral',
#    'Neutral',
#    997)],
#  [('18 Oct 2021 ',
#    ' Operations',
#    'Current Employee',
#    nan,
#    'under pay salary and unbalance workload',
#    'Not Recommended',
#    'Neutral',
#    'Not Recommended',
#    998)],
#  [('18 Oct 2021 ',
#    ' Data Analyst',
#    'Former Contractor',
#    ' more than 3 years',
#    'team is not diversified enough',
#    'Neutral',
#    'Neutral',
#    'Neutral',
#    999)],
#  ...]

# %%
pros_and_idx_lis2 = []
cons_and_idx_lis2 = []

for i in pros_and_idx_lis:
    pros_and_idx_lis2.extend(i)
for i in cons_and_idx_lis:
    cons_and_idx_lis2.extend(i)

pros_and_idx_lis2
# Out:
# [('27 Jun 2022 ',
#   ' Software Engineer',
#   'Current Employee',
#   ' more than 5 years',
#   'good work life balance and salary',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   0),
#  ('27 Jun 2022 ',
#   ' Senior Associate',
#   'Current Employee',
#   nan,
#   'annual leave granted per year is good',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   1),
#  ('27 Jun 2022 ',
#   ' Senior Associate',
#   'Current Employee',
#   nan,
#   'infrastructure is good and the ambience',
#   'Not Recommended',
#   'Neutral',
#   'Neutral',
#   2),
#  ('27 Jun 2022 ',
#   ' Senior Data Analyst',
#   'Former Contractor',
#   ' more than 1 year',
#   'opportunities to work on interesting and challenging projects',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   3),
#  ('27 Jun 2022 ',
#   ' Graduate Associate',
#   'Current Employee',
#   ' more than 1 year',
#   'you get exposed to multiple skillsets',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   4),
#  ('27 Jun 2022 ',
#   ' Engineer',
#   'Current Employee',
#   nan,
#   'great learning and nice culture',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   5),
#  ('27 Jun 2022 ',
#   ' Anonymous Employee',
#   'Current Employee',
#   ' more than 8 years',
#   'office culture (subjective to team)',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   6),
#  ('26 Jun 2022 ',
#   ' Senior Associate',
#   'Current Employee',
#   nan,
#   'good benefits and culture in it',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   7),
#  ('26 Jun 2022 ',
#   ' Anonymous Employee',
#   'Current Employee',
#   ' more than 3 years',
#   'work culture',
#   'Recommended',
#   'Neutral',
#   'Recommended',
#   8),
#  ('26 Jun 2022 ',
#   ' Anonymous Employee',
#   'Current Employee',
#   ' more than 3 years',
#   '',
#   'Recommended',
#   'Neutral',
#   'Recommended',
#   8),
#  ('26 Jun 2022 ',
#   ' Anonymous Employee',
#   'Current Employee',
#   ' more than 3 years',
#   'pay packages.',
#   'Recommended',
#   'Neutral',
#   'Recommended',
#   8),
#  ('26 Jun 2022 ',
#   ' Anonymous Employee',
#   'Current Employee',
#   ' more than 3 years',
#   'annual leaves.',
#   'Recommended',
#   'Neutral',
#   'Recommended',
#   8),
#  ('26 Jun 2022 ',
#   ' Anonymous Employee',
#   'Current Employee',
#   ' more than 3 years',
#   'career opportunities.',
#   'Recommended',
#   'Neutral',
#   'Recommended',
#   8),
#  ('26 Jun 2022 ',
#   ' AVP-Java Developer',
#   'Former Employee',
#   ' more than 3 years',
#   'good technology stack and high visibility',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   9),
#  ('26 Jun 2022 ',
#   ' Relationship Manager',
#   'Former Employee',
#   ' more than 1 year',
#   'able to express creativity freely and gain recognition',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   10),
#  ('25 Jun 2022 ',
#   ' Vice President - Technology',
#   'Current Employee',
#   nan,
#   'good place to work here',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   11),
#  ('25 Jun 2022 ',
#   ' Senior Associate',
#   'Current Employee',
#   nan,
#   'collaborative team members which makes it bearable with work',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   12),
#  ('25 Jun 2022 ',
#   ' Senior Associate',
#   'Current Employee',
#   ' more than 10 years',
#   'excellent, scope for learning, etc',
#   'Recommended',
#   'Recommended',
#   'Neutral',
#   13),
#  ('24 Jun 2022 ',
#   ' Anonymous Employee',
#   'Current Employee',
#   ' more than 5 years',
#   'work life balance',
#   'Not Recommended',
#   'Recommended',
#   'Not Recommended',
#   14),
#  ('24 Jun 2022 ',
#   ' Anonymous Employee',
#   'Current Employee',
#   ' more than 5 years',
#   'salary is not too bad',
#   'Not Recommended',
#   'Recommended',
#   'Not Recommended',
#   14),
#  ('24 Jun 2022 ',
#   ' Anonymous Employee',
#   'Current Employee',
#   ' more than 5 years',
#   '',
#   'Not Recommended',
#   'Recommended',
#   'Not Recommended',
#   14),
#  ('24 Jun 2022 ',
#   ' Anonymous Employee',
#   'Current Employee',
#   ' more than 5 years',
#   "that's all",
#   'Not Recommended',
#   'Recommended',
#   'Not Recommended',
#   14),
#  ('24 Jun 2022 ',
#   ' Credit Analyst',
#   'Current Employee',
#   ' less than 1 year',
#   'usually no need to ot',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   15),
#  ('23 Jun 2022 ',
#   ' Human Resources Generalist',
#   'Former Employee',
#   nan,
#   'very good work culture and motivating seniors.',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   16),
#  ('23 Jun 2022 ',
#   ' Human Resources Generalist',
#   'Former Employee',
#   nan,
#   'comfortable infrastructure.',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   16),
#  ('23 Jun 2022 ',
#   ' Human Resources Generalist',
#   'Former Employee',
#   nan,
#   'overall, a nice working experience.',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   16),
#  ('23 Jun 2022 ',
#   ' WPM',
#   'Former Employee',
#   ' less than 1 year',
#   'good pay with allowance_x000d_',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   17),
#  ('23 Jun 2022 ',
#   ' WPM',
#   'Former Employee',
#   ' less than 1 year',
#   '21 days leave',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   17),
#  ('23 Jun 2022 ',
#   ' Senior Executive',
#   'Former Contractor',
#   ' more than 1 year',
#   'work life balance and caring manager',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   18),
#  ('23 Jun 2022 ',
#   ' Relationship Manager',
#   'Current Employee',
#   nan,
#   '-staff benefits ',
#   'Neutral',
#   'Recommended',
#   'Neutral',
#   19),
#  ('23 Jun 2022 ',
#   ' Relationship Manager',
#   'Current Employee',
#   nan,
#   '- colleagues ',
#   'Neutral',
#   'Recommended',
#   'Neutral',
#   19),
#  ('23 Jun 2022 ',
#   ' Relationship Manager',
#   'Current Employee',
#   nan,
#   '- flexible working hours',
#   'Neutral',
#   'Recommended',
#   'Neutral',
#   19),
#  ('22 Jun 2022 ',
#   ' ',
#   'Current Employee',
#   ' less than 1 year',
#   "no pros to this company...i didn't like the work culture.management is svery strict to come to the office eve if you are nor feeling well for 3 days",
#   'Neutral',
#   'Not Recommended',
#   'Neutral',
#   20),
#  ('22 Jun 2022 ',
#   ' ',
#   'Current Employee',
#   ' less than 1 year',
#   'one of the worst management i have seen',
#   'Neutral',
#   'Not Recommended',
#   'Neutral',
#   20),
#  ('22 Jun 2022 ',
#   ' Technical Developer',
#   'Former Employee',
#   ' less than 1 year',
#   'stress free work in my team',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   21),
#  ('20 Jun 2022 ',
#   ' Banker',
#   'Current Employee',
#   ' more than 1 year',
#   'employee benefits, it solving efficiency',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   22),
#  ('20 Jun 2022 ',
#   ' Wealth Manager',
#   'Current Employee',
#   ' more than 1 year',
#   'great learning experience and healthy environment',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   23),
#  ('20 Jun 2022 ',
#   ' Customer Service Officer',
#   'Current Contractor',
#   ' less than 1 year',
#   'friendly colleagues',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   24),
#  ('20 Jun 2022 ',
#   ' Customer Service Officer',
#   'Current Contractor',
#   ' less than 1 year',
#   'decent welfare and working hours',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   24),
#  ('20 Jun 2022 ',
#   ' Bank Teller',
#   'Former Employee',
#   nan,
#   'nothing special',
#   'Not Recommended',
#   'Neutral',
#   'Not Recommended',
#   25),
#  ('20 Jun 2022 ',
#   ' Bank Teller',
#   'Former Employee',
#   nan,
#   'no different than any other banks',
#   'Not Recommended',
#   'Neutral',
#   'Not Recommended',
#   25),
#  ('20 Jun 2022 ',
#   ' Anonymous Employee',
#   'Current Employee',
#   ' more than 1 year',
#   'good work life balance_x000d_',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   26),
#  ('20 Jun 2022 ',
#   ' Anonymous Employee',
#   'Current Employee',
#   ' more than 1 year',
#   'good benefits',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   26),
#  ('19 Jun 2022 ',
#   ' Project Management Office (PMO)',
#   'Former Contractor',
#   ' less than 1 year',
#   'hard to say, didnt have an enjoyable time there',
#   'Not Recommended',
#   'Not Recommended',
#   'Neutral',
#   27),
#  ('18 Jun 2022 ',
#   ' Associate',
#   'Current Employee',
#   nan,
#   'friendly environment and attractive package',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   28),
#  ('18 Jun 2022 ',
#   ' Senior Associate',
#   'Current Employee',
#   ' more than 5 years',
#   'employee growth_x000d_',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   29),
#  ('18 Jun 2022 ',
#   ' Senior Associate',
#   'Current Employee',
#   ' more than 5 years',
#   'end to end management_x000d_',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   29),
#  ('18 Jun 2022 ',
#   ' Senior Associate',
#   'Current Employee',
#   ' more than 5 years',
#   'good hikes_x000d_',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   29),
#  ('18 Jun 2022 ',
#   ' Senior Associate',
#   'Current Employee',
#   ' more than 5 years',
#   'work life balance as well_x000d_',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   29),
#  ('18 Jun 2022 ',
#   ' Senior Associate',
#   'Current Employee',
#   ' more than 5 years',
#   'good management',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   29),
#  ('18 Jun 2022 ',
#   ' Anonymous Employee',
#   'Current Employee',
#   nan,
#   'good company, and good benefit',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   30),
#  ('18 Jun 2022 ',
#   ' Customer Service Associate',
#   'Former Contractor',
#   ' less than 1 year',
#   'high salary',
#   'Not Recommended',
#   'Neutral',
#   'Not Recommended',
#   31),
#  ('18 Jun 2022 ',
#   ' Customer Service Associate',
#   'Former Contractor',
#   ' less than 1 year',
#   'regular working hours',
#   'Not Recommended',
#   'Neutral',
#   'Not Recommended',
#   31),
#  ('17 Jun 2022 ',
#   ' Anonymous Employee',
#   'Current Employee',
#   nan,
#   'good benefits_x000d_',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   32),
#  ('17 Jun 2022 ',
#   ' Anonymous Employee',
#   'Current Employee',
#   nan,
#   'medical leave_x000d_',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   32),
#  ('17 Jun 2022 ',
#   ' Anonymous Employee',
#   'Current Employee',
#   nan,
#   'annual leave _x000d_',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   32),
#  ('17 Jun 2022 ',
#   ' Anonymous Employee',
#   'Current Employee',
#   nan,
#   'na_x000d_',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   32),
#  ('17 Jun 2022 ',
#   ' Anonymous Employee',
#   'Current Employee',
#   nan,
#   'na',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   32),
#  ('17 Jun 2022 ',
#   ' Associate',
#   'Current Employee',
#   ' more than 3 years',
#   'good staff benefits and work life',
#   'Recommended',
#   'Neutral',
#   'Recommended',
#   33),
#  ('17 Jun 2022 ',
#   ' Customer Service Officer',
#   'Current Employee',
#   nan,
#   '- competitive salary _x000d_',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   34),
#  ('17 Jun 2022 ',
#   ' Customer Service Officer',
#   'Current Employee',
#   nan,
#   '- good teammates',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   34),
#  ('17 Jun 2022 ',
#   ' Vice President',
#   'Former Employee',
#   ' more than 3 years',
#   '- manager is good_x000d_',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   35),
#  ('17 Jun 2022 ',
#   ' Vice President',
#   'Former Employee',
#   ' more than 3 years',
#   '- a lot of new things to learn',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   35),
#  ('16 Jun 2022 ',
#   ' Anonymous Contractor',
#   'Former Contractor',
#   nan,
#   '-recognised employer_x000d_',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   36),
#  ('16 Jun 2022 ',
#   ' Anonymous Contractor',
#   'Former Contractor',
#   nan,
#   '-have budget for employee gatherings',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   36),
#  ('16 Jun 2022 ',
#   ' Seeder',
#   'Current Employee',
#   ' more than 1 year',
#   '-most people are friendly and willing to help_x000d_',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   37),
#  ('16 Jun 2022 ',
#   ' Seeder',
#   'Current Employee',
#   ' more than 1 year',
#   '-hr for the seeder programme is super helpful and we can always approach them for any issues/ help_x000d_',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   37),
#  ('16 Jun 2022 ',
#   ' Seeder',
#   'Current Employee',
#   ' more than 1 year',
#   '-pretty good support system for the programme',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   37),
#  ('15 Jun 2022 ',
#   ' Relationship Manager',
#   'Former Employee',
#   nan,
#   'good pay and good benefits',
#   'Not Recommended',
#   'Neutral',
#   'Recommended',
#   38),
#  ('15 Jun 2022 ',
#   ' Officer',
#   'Former Employee',
#   nan,
#   'have ot pay but can claim 30 hours only',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   39),
#  ('15 Jun 2022 ',
#   ' Sales Associate',
#   'Current Employee',
#   ' less than 1 year',
#   'good boss',
#   'Recommended',
#   'Not Recommended',
#   'Neutral',
#   40),
#  ('15 Jun 2022 ',
#   ' Sales Associate',
#   'Current Employee',
#   ' less than 1 year',
#   'attractive perks',
#   'Recommended',
#   'Not Recommended',
#   'Neutral',
#   40),
#  ('15 Jun 2022 ',
#   ' Sales Associate',
#   'Current Employee',
#   ' less than 1 year',
#   'everyone is very nice',
#   'Recommended',
#   'Not Recommended',
#   'Neutral',
#   40),
#  ('15 Jun 2022 ',
#   ' Deputy Manager Sales',
#   'Former Employee',
#   ' more than 3 years',
#   'internal mobility,staff benefits,1 hour early off per week',
#   'Recommended',
#   'Recommended',
#   'Not Recommended',
#   41),
#  ('15 Jun 2022 ',
#   ' Private Banking Associate',
#   'Current Employee',
#   nan,
#   'good progression if you work hard',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   42),
#  ('15 Jun 2022 ',
#   ' AVP-Sales',
#   'Former Employee',
#   ' more than 3 years',
#   'stable firm to work for',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   43),
#  ('15 Jun 2022 ',
#   ' Analyst',
#   'Current Contractor',
#   ' less than 1 year',
#   'good place to learn a lot.',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   44),
#  ('14 Jun 2022 ',
#   ' Analyst',
#   'Current Employee',
#   ' more than 3 years',
#   'employee benefits are good, bonus are generous too',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   45),
#  ('14 Jun 2022 ',
#   ' Analyst',
#   'Current Employee',
#   ' more than 3 years',
#   'colleagues are helpful and very family oriented environment.',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   45),
#  ('14 Jun 2022 ',
#   ' Senior Officer',
#   'Current Employee',
#   ' more than 3 years',
#   'work life balance_x000d_',
#   'Not Recommended',
#   'Not Recommended',
#   'Neutral',
#   46),
#  ('14 Jun 2022 ',
#   ' Senior Officer',
#   'Current Employee',
#   ' more than 3 years',
#   'not too much ot',
#   'Not Recommended',
#   'Not Recommended',
#   'Neutral',
#   46),
#  ('14 Jun 2022 ',
#   ' Digital Marketing Executive',
#   'Current Employee',
#   ' more than 1 year',
#   '- high growth_x000d_',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   47),
#  ('14 Jun 2022 ',
#   ' Digital Marketing Executive',
#   'Current Employee',
#   ' more than 1 year',
#   '- attractive to tech leaders_x000d_',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   47),
#  ('14 Jun 2022 ',
#   ' Digital Marketing Executive',
#   'Current Employee',
#   ' more than 1 year',
#   '- agile',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   47),
#  ('14 Jun 2022 ',
#   ' Operations Analyst',
#   'Current Employee',
#   ' more than 1 year',
#   'some staffs are actually kind.',
#   'Not Recommended',
#   'Recommended',
#   'Neutral',
#   48),
#  ('13 Jun 2022 ',
#   ' Software Engineer',
#   'Former Employee',
#   ' more than 1 year',
#   'great learning opportunities and a good place to start your first career.',
#   'Not Recommended',
#   'Not Recommended',
#   'Neutral',
#   49),
#  ('13 Jun 2022 ',
#   ' Finance Intern',
#   'Former Employee',
#   ' less than 1 year',
#   'the colleagues are very professional, and the workplace is comfortable.',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   50),
#  ('13 Jun 2022 ',
#   ' Vice President',
#   'Current Employee',
#   ' more than 1 year',
#   'flexible working style, encourage employees to keep learning and grow',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   51),
#  ('13 Jun 2022 ',
#   ' Account Officer',
#   'Current Contractor',
#   nan,
#   'balanced worklife balance',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   52),
#  ('13 Jun 2022 ',
#   ' Account Officer',
#   'Current Contractor',
#   nan,
#   'manager shows trust in employees',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   52),
#  ('13 Jun 2022 ',
#   ' Anonymous Employee',
#   'Former Employee',
#   ' more than 1 year',
#   'learned a lot from the boss',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   53),
#  ('13 Jun 2022 ',
#   ' Agile Scrum Master',
#   'Former Contractor',
#   ' more than 1 year',
#   'flexible but strong control',
#   'Not Recommended',
#   'Recommended',
#   'Not Recommended',
#   54),
#  ('13 Jun 2022 ',
#   ' Agile Scrum Master',
#   'Former Contractor',
#   ' more than 1 year',
#   'support by tools',
#   'Not Recommended',
#   'Recommended',
#   'Not Recommended',
#   54),
#  ('12 Jun 2022 ',
#   ' Software Developer',
#   'Current Employee',
#   nan,
#   'great place to work and good learning',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   55),
#  ('12 Jun 2022 ',
#   ' Analyst',
#   'Current Employee',
#   ' more than 1 year',
#   'good and supportive culture',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   56),
#  ('12 Jun 2022 ',
#   ' Analyst',
#   'Current Employee',
#   ' more than 1 year',
#   'good staff benefits depending on life circumstances',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   56),
#  ('12 Jun 2022 ',
#   ' Analyst',
#   'Current Employee',
#   ' more than 1 year',
#   'opportunities to move horizontally within the bank',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   56),
#  ('12 Jun 2022 ',
#   ' Analyst',
#   'Current Employee',
#   ' more than 1 year',
#   'great culture within the bank',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   56),
#  ('12 Jun 2022 ',
#   ' Product Manager',
#   'Current Contractor',
#   nan,
#   'reputable bank, steep learning curve.',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   57),
#  ('12 Jun 2022 ',
#   ' Audit Senior Associate',
#   'Current Employee',
#   ' more than 8 years',
#   'stable ok less politics nice',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   58),
#  ('12 Jun 2022 ',
#   ' VP- Operations',
#   'Current Employee',
#   ' more than 10 years',
#   '1',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   59),
#  ('12 Jun 2022 ',
#   ' VP- Operations',
#   'Current Employee',
#   ' more than 10 years',
#   'performance-driven career progression_x000d_',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   59),
#  ('12 Jun 2022 ',
#   ' VP- Operations',
#   'Current Employee',
#   ' more than 10 years',
#   '2',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   59),
#  ('12 Jun 2022 ',
#   ' VP- Operations',
#   'Current Employee',
#   ' more than 10 years',
#   'annual leave above the market _x000d_',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   59),
#  ('12 Jun 2022 ',
#   ' VP- Operations',
#   'Current Employee',
#   ' more than 10 years',
#   '3',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   59),
#  ('12 Jun 2022 ',
#   ' VP- Operations',
#   'Current Employee',
#   ' more than 10 years',
#   'open for innovative ideas_x000d_',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   59),
#  ('12 Jun 2022 ',
#   ' VP- Operations',
#   'Current Employee',
#   ' more than 10 years',
#   '4',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   59),
#  ('12 Jun 2022 ',
#   ' VP- Operations',
#   'Current Employee',
#   ' more than 10 years',
#   'very supportive senior management_x000d_',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   59),
#  ('12 Jun 2022 ',
#   ' VP- Operations',
#   'Current Employee',
#   ' more than 10 years',
#   '5',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   59),
#  ('12 Jun 2022 ',
#   ' VP- Operations',
#   'Current Employee',
#   ' more than 10 years',
#   'awesome work and culture',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   59),
#  ('11 Jun 2022 ',
#   ' Anonymous Employee',
#   'Current Employee',
#   ' more than 3 years',
#   'benefits are good._x000d_',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   60),
#  ('11 Jun 2022 ',
#   ' Anonymous Employee',
#   'Current Employee',
#   ' more than 3 years',
#   'leaves are one of the highest in the industry.',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   60),
#  ('11 Jun 2022 ',
#   ' Assistant Vice President',
#   'Current Employee',
#   nan,
#   'good working culture in the organization',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   61),
#  ('10 Jun 2022 ',
#   ' Anonymous Employee',
#   'Current Employee',
#   ' more than 1 year',
#   'big company with nice office location',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   62),
#  ('9 Jun 2022 ',
#   ' Anonymous Contractor',
#   'Current Contractor',
#   ' less than 1 year',
#   'many meetings as expected, but also learnings to be gained from these alignments.',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   63),
#  ('9 Jun 2022 ',
#   ' Database Administrator (DBA)',
#   'Current Employee',
#   nan,
#   'lot of work and learning opportunity',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   64),
#  ('9 Jun 2022 ',
#   ' AVP-Operations',
#   'Current Employee',
#   ' less than 1 year',
#   'concerned about sales and target',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   65),
#  ('9 Jun 2022 ',
#   ' IT Engineer',
#   'Former Employee',
#   ' more than 5 years',
#   'innovation company',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   66),
#  ('9 Jun 2022 ',
#   ' IT Engineer',
#   'Former Employee',
#   ' more than 5 years',
#   'always provide the excellent service to customers.',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   66),
#  ('9 Jun 2022 ',
#   ' Anonymous Employee',
#   'Current Employee',
#   nan,
#   'nice colleague in work place',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   67),
#  ('9 Jun 2022 ',
#   ' Relationship Manager',
#   'Former Employee',
#   ' more than 3 years',
#   'fast to adopt new technology_x000d_',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   68),
#  ('9 Jun 2022 ',
#   ' Relationship Manager',
#   'Former Employee',
#   ' more than 3 years',
#   'fast promotion if you have good sales',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   68),
#  ('9 Jun 2022 ',
#   ' Assistant Officer',
#   'Current Employee',
#   ' more than 3 years',
#   'leaves are ample enough leaves are there',
#   'Not Recommended',
#   'Neutral',
#   'Not Recommended',
#   69),
#  ('9 Jun 2022 ',
#   ' Software Engineer',
#   'Current Employee',
#   ' less than 1 year',
#   'free environment and good employee benifit',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   70),
#  ('9 Jun 2022 ',
#   ' Senior Associate',
#   'Former Employee',
#   ' more than 3 years',
#   'good salary bonus benefits and awards',
#   'Not Recommended',
#   'Recommended',
#   'Recommended',
#   71),
#  ('8 Jun 2022 ',
#   ' Senior Security Engineer',
#   'Current Employee',
#   ' more than 3 years',
#   'autonomy as ic is amazing',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   72),
#  ('8 Jun 2022 ',
#   ' Senior Associate',
#   'Former Employee',
#   ' more than 5 years',
#   'great ceo, progressive company too',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   73),
#  ('8 Jun 2022 ',
#   ' Senior Associate',
#   'Current Employee',
#   nan,
#   '2 days wfh per week',
#   'Recommended',
#   'Not Recommended',
#   'Neutral',
#   74),
#  ('8 Jun 2022 ',
#   ' Senior Associate',
#   'Current Employee',
#   nan,
#   'good working culture',
#   'Recommended',
#   'Not Recommended',
#   'Neutral',
#   74),
#  ('7 Jun 2022 ',
#   ' AVP-Project Manager',
#   'Former Employee',
#   ' more than 5 years',
#   'ceo and top management do a lot to work with hr to drive work life balance and give competitive salary and other benefits',
#   'Recommended',
#   'Recommended',
#   'Not Recommended',
#   75),
#  ('7 Jun 2022 ',
#   ' AVP-Project Manager',
#   'Former Employee',
#   ' more than 5 years',
#   'honestly it’s a good place to work for with union backing as well.',
#   'Recommended',
#   'Recommended',
#   'Not Recommended',
#   75),
#  ('7 Jun 2022 ',
#   ' Seeder',
#   'Current Employee',
#   ' less than 1 year',
#   'friendly colleagues and nice mentors',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   76),
#  ('7 Jun 2022 ',
#   ' Senior Assocaiate',
#   'Former Employee',
#   ' more than 3 years',
#   'colleagues are helpful_x000d_',
#   'Recommended',
#   'Not Recommended',
#   'Recommended',
#   77),
#  ('7 Jun 2022 ',
#   ' Senior Assocaiate',
#   'Former Employee',
#   ' more than 3 years',
#   'focus on work rather than company politics',
#   'Recommended',
#   'Not Recommended',
#   'Recommended',
#   77),
#  ('7 Jun 2022 ',
#   ' Anonymous Employee',
#   'Former Employee',
#   ' more than 1 year',
#   'working with colleagues can be very casual as everyone is friendly and helpful',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   78),
#  ('7 Jun 2022 ',
#   ' Anonymous Employee',
#   'Former Employee',
#   ' more than 1 year',
#   'great employer branding which helps to make your resume more attractive.',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   78),
#  ('6 Jun 2022 ',
#   ' Sales Representative',
#   'Former Employee',
#   nan,
#   'company benefits are good',
#   'Neutral',
#   'Recommended',
#   'Not Recommended',
#   79),
#  ('6 Jun 2022 ',
#   ' Sales Representative',
#   'Former Employee',
#   nan,
#   'you have an option to branch out to other departments after if sales is not working out for you.',
#   'Neutral',
#   'Recommended',
#   'Not Recommended',
#   79),
#  ('6 Jun 2022 ',
#   ' Software Engineer',
#   'Current Employee',
#   nan,
#   'employee friendly and ample changes for growth',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   80),
#  ('6 Jun 2022 ',
#   ' SVP-Service Delivery Executive',
#   'Current Employee',
#   ' more than 8 years',
#   'good pay and good bonus.',
#   'Not Recommended',
#   'Recommended',
#   'Recommended',
#   81),
#  ('5 Jun 2022 ',
#   ' Relationship Manager',
#   'Current Employee',
#   ' more than 1 year',
#   'nothing much in particular',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   82),
#  ('5 Jun 2022 ',
#   ' Relationship Manager',
#   'Current Employee',
#   ' more than 1 year',
#   'just do ur best',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   82),
#  ('5 Jun 2022 ',
#   ' Assistant Manager',
#   'Current Employee',
#   ' more than 5 years',
#   'good career progress so far',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   83),
#  ('5 Jun 2022 ',
#   ' Sales',
#   'Current Employee',
#   nan,
#   'great place to build experience',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   84),
#  ('4 Jun 2022 ',
#   ' Investment Advisor',
#   'Former Employee',
#   nan,
#   'very very very very good',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   85),
#  ('3 Jun 2022 ',
#   ' Technical Lead',
#   'Current Employee',
#   nan,
#   'great marketing on gandalf, transformation, cloud and being the best bank in the world',
#   'Neutral',
#   'Neutral',
#   'Not Recommended',
#   86),
#  ('3 Jun 2022 ',
#   ' Vice President',
#   'Current Employee',
#   nan,
#   'less political tension',
#   'Recommended',
#   'Not Recommended',
#   'Recommended',
#   87),
#  ('3 Jun 2022 ',
#   ' Vice President',
#   'Current Employee',
#   nan,
#   'most staff are awesome ',
#   'Recommended',
#   'Not Recommended',
#   'Recommended',
#   87),
#  ('3 Jun 2022 ',
#   ' Vice President',
#   'Current Employee',
#   nan,
#   'not too much redundant staff',
#   'Recommended',
#   'Not Recommended',
#   'Recommended',
#   87),
#  ('2 Jun 2022 ',
#   ' Associate',
#   'Current Employee',
#   nan,
#   'good environment to work for fresh graduate',
#   'Neutral',
#   'Recommended',
#   'Recommended',
#   88),
#  ('2 Jun 2022 ',
#   ' Anonymous Contractor',
#   'Current Contractor',
#   ' less than 1 year',
#   'it is a good working environment',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   89),
#  ('2 Jun 2022 ',
#   ' Senior Associate',
#   'Current Employee',
#   ' more than 5 years',
#   'good ambience and working culture',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   90),
#  ('2 Jun 2022 ',
#   ' Senior Associate',
#   'Current Employee',
#   ' more than 5 years',
#   'under singapore control.',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   90),
#  ('2 Jun 2022 ',
#   ' Applications Support Analyst',
#   'Former Contractor',
#   ' more than 1 year',
#   'stable income, pre-defined job scope',
#   'Recommended',
#   'Not Recommended',
#   'Recommended',
#   91),
#  ('2 Jun 2022 ',
#   ' Employee Relations Specialist',
#   'Current Contractor',
#   ' more than 1 year',
#   'good learning experience and good people',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   92),
#  ('2 Jun 2022 ',
#   ' Software Developer',
#   'Current Employee',
#   nan,
#   'great boss colleagues_x000d_',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   93),
#  ('2 Jun 2022 ',
#   ' Software Developer',
#   'Current Employee',
#   nan,
#   'lots of tech tools to learn',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   93),
#  ('2 Jun 2022 ',
#   ' Senior Manager',
#   'Current Employee',
#   ' more than 10 years',
#   'good place to learn ',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   94),
#  ('2 Jun 2022 ',
#   ' Senior Manager',
#   'Current Employee',
#   ' more than 10 years',
#   'reasonable work life balance',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   94),
#  ('1 Jun 2022 ',
#   ' KYC Officer',
#   'Current Employee',
#   nan,
#   'good place to work in.',
#   'Recommended',
#   'Recommended',
#   'Neutral',
#   95),
#  ('1 Jun 2022 ',
#   ' Financial Planner',
#   'Former Employee',
#   ' less than 1 year',
#   'branding is there for you',
#   'Not Recommended',
#   'Recommended',
#   'Not Recommended',
#   96),
#  ('1 Jun 2022 ',
#   ' Executive Director',
#   'Current Employee',
#   ' more than 1 year',
#   'i’m working for some of the best leaders in my entire career! i’ve been able to work on what i’m passionate and good at!',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   97),
#  ('1 Jun 2022 ',
#   ' Senior Project Associate',
#   'Current Employee',
#   ' more than 3 years',
#   'good work life balance._x000d_',
#   'Recommended',
#   'Recommended',
#   'Neutral',
#   98),
#  ('1 Jun 2022 ',
#   ' Senior Project Associate',
#   'Current Employee',
#   ' more than 3 years',
#   'good perks like iflex',
#   'Recommended',
#   'Recommended',
#   'Neutral',
#   98),
#  ('31 May 2022 ',
#   ' Anonymous Contractor',
#   'Current Contractor',
#   nan,
#   'very inclusive culture, blameless work attitude generally a great place to work at.',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   99),
#  ('31 May 2022 ',
#   ' Anonymous Employee',
#   'Current Employee',
#   ' more than 3 years',
#   'dbs is a people-oriented organisation which put employees in the first place.',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   100),
#  ('31 May 2022 ',
#   ' Senior Relationship Manager',
#   'Current Employee',
#   ' more than 5 years',
#   'everything on the forefront',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   101),
#  ('31 May 2022 ',
#   ' Senior Relationship Manager',
#   'Current Employee',
#   ' more than 5 years',
#   'it is essentially trying all kinds of projects to automate job processes.',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   101),
#  ('31 May 2022 ',
#   ' IT Contractor',
#   'Current Employee',
#   nan,
#   'good to work with the company',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   102),
#  ('31 May 2022 ',
#   ' Officer',
#   'Current Employee',
#   ' less than 1 year',
#   'fair management system, good colleagues',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   103),
#  ('30 May 2022 ',
#   ' Anonymous Contractor',
#   'Former Contractor',
#   ' more than 1 year',
#   'good benefits and good opportunity',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   104),
#  ('30 May 2022 ',
#   ' Operational Risk Specialist',
#   'Former Employee',
#   ' more than 3 years',
#   'senior management really listens to employees and introduce changes through policies.',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   105),
#  ('29 May 2022 ',
#   ' Relationship Manager',
#   'Former Employee',
#   nan,
#   'great compensation and branch culture',
#   'Neutral',
#   'Recommended',
#   'Neutral',
#   106),
#  ('29 May 2022 ',
#   ' Wealth Manager',
#   'Current Employee',
#   nan,
#   'friendly environment and great staff benefit',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   107),
#  ('28 May 2022 ',
#   ' Customer Service Representative',
#   'Former Employee',
#   ' more than 1 year',
#   'wfh rotation_x000d_',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   108),
#  ('28 May 2022 ',
#   ' Customer Service Representative',
#   'Former Employee',
#   ' more than 1 year',
#   'contractor no need to work in wfh session due to no access',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   108),
#  ('28 May 2022 ',
#   ' Assistant Relationship Manager Private Banking',
#   'Former Employee',
#   ' more than 3 years',
#   'resourceful and able to learn many things.',
#   'Neutral',
#   'Recommended',
#   'Neutral',
#   109),
#  ('27 May 2022 ',
#   ' Assistant Relationship Manager',
#   'Current Employee',
#   ' more than 1 year',
#   'good working exposure and great colleagues',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   110),
#  ('26 May 2022 ',
#   ' AVP-Project Manager',
#   'Former Employee',
#   ' more than 8 years',
#   'great work culture',
#   'Recommended',
#   'Recommended',
#   'Neutral',
#   111),
#  ('26 May 2022 ',
#   ' AVP-Project Manager',
#   'Former Employee',
#   ' more than 8 years',
#   '_x000d_',
#   'Recommended',
#   'Recommended',
#   'Neutral',
#   111),
#  ('26 May 2022 ',
#   ' AVP-Project Manager',
#   'Former Employee',
#   ' more than 8 years',
#   'competitive salary & benefits package',
#   'Recommended',
#   'Recommended',
#   'Neutral',
#   111),
#  ('26 May 2022 ',
#   ' Senior Wealth Planning Manager',
#   'Current Employee',
#   nan,
#   'i was lucky to have friendly colleagues and an awesome manager.',
#   'Recommended',
#   'Recommended',
#   'Neutral',
#   112),
#  ('26 May 2022 ',
#   ' Software Engineer',
#   'Current Employee',
#   ' more than 1 year',
#   'working in dbs is still very much better than being exploit in singapore smes._x000d_',
#   'Recommended',
#   'Not Recommended',
#   'Recommended',
#   113),
#  ('26 May 2022 ',
#   ' Software Engineer',
#   'Current Employee',
#   ' more than 1 year',
#   'depends on your role and attitude in job nature',
#   'Recommended',
#   'Not Recommended',
#   'Recommended',
#   113),
#  ('26 May 2022 ',
#   ' Software Engineer',
#   'Current Employee',
#   ' more than 1 year',
#   'it will significantly put you to be center of attention to provide solutions to business technologies and recognition from peers._x000d_',
#   'Recommended',
#   'Not Recommended',
#   'Recommended',
#   113),
#  ('26 May 2022 ',
#   ' Software Engineer',
#   'Current Employee',
#   ' more than 1 year',
#   'probably one of the best employee benefits in general that enable to you to get lowest interest rate in home loan and higher rates in savings and also shares allocation at 25% more base on your monthly contribution.',
#   'Recommended',
#   'Not Recommended',
#   'Recommended',
#   113),
#  ('26 May 2022 ',
#   ' Anonymous Employee',
#   'Current Employee',
#   ' more than 5 years',
#   'good compensation and benefits package',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   114),
#  ('25 May 2022 ',
#   ' Software Engineer',
#   'Current Employee',
#   ' more than 1 year',
#   'good working environment, good for junior software enginners',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   115),
#  ('25 May 2022 ',
#   ' Data Analyst',
#   'Former Contractor',
#   ' more than 5 years',
#   'fully digital and you can actually wfh.',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   116),
#  ('25 May 2022 ',
#   ' Associate',
#   'Current Employee',
#   ' less than 1 year',
#   'nothing much, just lot of work',
#   'Not Recommended',
#   'Neutral',
#   'Neutral',
#   117),
#  ('25 May 2022 ',
#   ' Corporate Loans Analyst',
#   'Former Contractor',
#   ' more than 1 year',
#   'people there are friendly and easy to work with',
#   'Recommended',
#   'Not Recommended',
#   'Neutral',
#   118),
#  ('24 May 2022 ',
#   ' Analyst',
#   'Current Employee',
#   nan,
#   'all good in this company',
#   'Neutral',
#   'Recommended',
#   'Neutral',
#   119),
#  ('24 May 2022 ',
#   ' Vice President',
#   'Current Employee',
#   ' more than 3 years',
#   'great supportive team and hardworking culture.',
#   'Not Recommended',
#   'Not Recommended',
#   'Recommended',
#   120),
#  ('24 May 2022 ',
#   ' Associate',
#   'Current Employee',
#   ' more than 8 years',
#   'good leave benefits and fast paced environment.',
#   'Recommended',
#   'Not Recommended',
#   'Neutral',
#   121),
#  ('24 May 2022 ',
#   ' Project Manager',
#   'Current Employee',
#   nan,
#   '- things move fast',
#   'Neutral',
#   'Not Recommended',
#   'Neutral',
#   122),
#  ('24 May 2022 ',
#   ' Project Manager',
#   'Current Employee',
#   nan,
#   '- able to achieve something',
#   'Neutral',
#   'Not Recommended',
#   'Neutral',
#   122),
#  ('24 May 2022 ',
#   ' Dealer',
#   'Former Contractor',
#   ' more than 1 year',
#   'bank has good professional with good ethical background',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   123),
#  ('23 May 2022 ',
#   ' Anonymous Employee',
#   'Current Employee',
#   nan,
#   'good benefits and salary .',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   124),
#  ('23 May 2022 ',
#   ' Anonymous Employee',
#   'Former Employee',
#   nan,
#   'nice colleagues but depends on branch',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   125),
#  ('23 May 2022 ',
#   ' Internship',
#   'Current Employee',
#   ' less than 1 year',
#   'great team, bearable workload, learned a lot',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   126),
#  ('23 May 2022 ',
#   ' Manager',
#   'Former Contractor',
#   nan,
#   'good work culture ',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   127),
#  ('23 May 2022 ',
#   ' Manager',
#   'Former Contractor',
#   nan,
#   'excellent benefits ',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   127),
#  ('23 May 2022 ',
#   ' Manager',
#   'Former Contractor',
#   nan,
#   'diversity is good',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   127),
#  ('23 May 2022 ',
#   ' SVP Product',
#   'Current Employee',
#   nan,
#   'good pay and bonus.',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   128),
#  ('23 May 2022 ',
#   ' SVP Product',
#   'Current Employee',
#   nan,
#   'generous number of leave.',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   128),
#  ('23 May 2022 ',
#   ' SVP Product',
#   'Current Employee',
#   nan,
#   'senior mgmt speaks alot on work life balance and mental wellness.',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   128),
#  ('23 May 2022 ',
#   ' Assistant Vice President',
#   'Current Employee',
#   ' more than 3 years',
#   'career growth ,employee benefits in india_x000d_',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   129),
#  ('23 May 2022 ',
#   ' Assistant Vice President',
#   'Current Employee',
#   ' more than 3 years',
#   "new technology's and supporting leader ship",
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   129),
#  ('23 May 2022 ',
#   ' Associate',
#   'Current Employee',
#   ' more than 3 years',
#   'good culture, benefits, based on project your work life balance depends',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   130),
#  ('23 May 2022 ',
#   ' Associate',
#   'Current Employee',
#   ' more than 3 years',
#   'good employee benefits and work life balance',
#   'Recommended',
#   'Neutral',
#   'Neutral',
#   131),
#  ('23 May 2022 ',
#   ' Human Resources Generalist',
#   'Current Employee',
#   nan,
#   'benefits quite good_x000d_',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   132),
#  ('23 May 2022 ',
#   ' Human Resources Generalist',
#   'Current Employee',
#   nan,
#   'bonus quite good_x000d_',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   132),
#  ('23 May 2022 ',
#   ' Human Resources Generalist',
#   'Current Employee',
#   nan,
#   'nice colleagues_x000d_',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   132),
#  ('23 May 2022 ',
#   ' Human Resources Generalist',
#   'Current Employee',
#   nan,
#   'fun at times',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   132),
#  ('23 May 2022 ',
#   ' Anonymous Employee',
#   'Current Employee',
#   nan,
#   'good career structure designed to succeed',
#   'Not Recommended',
#   'Recommended',
#   'Recommended',
#   133),
#  ('22 May 2022 ',
#   ' Trade Ops Analyst',
#   'Current Employee',
#   ' more than 3 years',
#   'good colleagues_x000d_',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   134),
#  ('22 May 2022 ',
#   ' Trade Ops Analyst',
#   'Current Employee',
#   ' more than 3 years',
#   'good perks once in awhile',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   134),
#  ('22 May 2022 ',
#   ' Senior Associate',
#   'Current Employee',
#   ' more than 3 years',
#   'greater emphasis on work life balance, constant dialogues with senior management, hybrid work arrangements',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   135),
#  ('22 May 2022 ',
#   ' Analyst',
#   'Current Employee',
#   nan,
#   'nice work culture very nice place to learn',
#   'Neutral',
#   'Not Recommended',
#   'Neutral',
#   136),
#  ('22 May 2022 ',
#   ' Analyst',
#   'Current Employee',
#   nan,
#   'we get goodies and vouchers almost once in two months',
#   'Neutral',
#   'Not Recommended',
#   'Neutral',
#   136),
#  ('21 May 2022 ',
#   ' Associate',
#   'Current Employee',
#   nan,
#   'good opportunities , appreciated and good benefits',
#   'Recommended',
#   'Not Recommended',
#   'Recommended',
#   137),
#  ('21 May 2022 ',
#   ' Software Engineer',
#   'Current Employee',
#   ' more than 1 year',
#   'no thing to say about pros',
#   'Not Recommended',
#   'Neutral',
#   'Not Recommended',
#   138),
#  ('20 May 2022 ',
#   ' Associate',
#   'Current Employee',
#   ' less than 1 year',
#   'no pros as so far….',
#   'Not Recommended',
#   'Neutral',
#   'Not Recommended',
#   139),
#  ('20 May 2022 ',
#   ' Analyst',
#   'Current Employee',
#   ' more than 3 years',
#   'decent employee benefits_x000d_',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   140),
#  ('20 May 2022 ',
#   ' Analyst',
#   'Current Employee',
#   ' more than 3 years',
#   'good amount of annual leave',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   140),
#  ('20 May 2022 ',
#   ' Senior Vice President',
#   'Current Employee',
#   ' more than 1 year',
#   'good strategy and profit earning',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   141),
#  ('20 May 2022 ',
#   ' Mac Administrator',
#   'Current Employee',
#   ' more than 3 years',
#   'wfh gives me more time on doing my work and rest',
#   'Recommended',
#   'Recommended',
#   'Neutral',
#   142),
#  ('20 May 2022 ',
#   ' Mac Administrator',
#   'Current Employee',
#   ' more than 3 years',
#   'the freedom which allows me to delivery',
#   'Recommended',
#   'Recommended',
#   'Neutral',
#   142),
#  ('20 May 2022 ',
#   ' Anonymous Employee',
#   'Current Employee',
#   ' more than 5 years',
#   'very good culture and environment',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   143),
#  ('20 May 2022 ',
#   ' Assistant Relationship Manager Private Banking',
#   'Current Employee',
#   nan,
#   'good place to learn and develop your skills and knowledge',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   144),
#  ('20 May 2022 ',
#   ' Analyst',
#   'Current Employee',
#   ' more than 1 year',
#   'perks and work life balance',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   145),
#  ('20 May 2022 ',
#   ' Senior RM',
#   'Current Employee',
#   ' more than 1 year',
#   'the bank has fabulous hr policies and take very good care of their employees',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   146),
#  ('20 May 2022 ',
#   ' Senior RM',
#   'Current Employee',
#   ' more than 1 year',
#   'everyone in the organisation is highly approachable',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   146),
#  ('20 May 2022 ',
#   ' Senior RM',
#   'Current Employee',
#   ' more than 1 year',
#   'just loved working here.',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   146),
#  ('19 May 2022 ',
#   ' Analyst',
#   'Current Employee',
#   ' more than 1 year',
#   'good benefits (leaves, flexi, etc)',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   147),
#  ('19 May 2022 ',
#   ' Corporate Action Specialist',
#   'Current Employee',
#   ' more than 5 years',
#   'leave benefits_x000d_',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   148),
#  ('19 May 2022 ',
#   ' Corporate Action Specialist',
#   'Current Employee',
#   ' more than 5 years',
#   'management not bad_x000d_',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   148),
#  ('19 May 2022 ',
#   ' Corporate Action Specialist',
#   'Current Employee',
#   ' more than 5 years',
#   'colleagues are helpful',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   148),
#  ('19 May 2022 ',
#   ' Analyst',
#   'Current Employee',
#   ' less than 1 year',
#   'good chance to learn new technologies._x000d_',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   149),
#  ('19 May 2022 ',
#   ' Analyst',
#   'Current Employee',
#   ' less than 1 year',
#   'good leadership',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   149),
#  ('18 May 2022 ',
#   ' Engineer',
#   'Former Employee',
#   ' more than 1 year',
#   'good benefits, structured jd, digital banking.',
#   'Recommended',
#   'Recommended',
#   'Not Recommended',
#   150),
#  ('18 May 2022 ',
#   ' Analyst',
#   'Former Employee',
#   nan,
#   'good work place and good people',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   151),
#  ('18 May 2022 ',
#   ' Anonymous Employee',
#   'Former Employee',
#   ' more than 3 years',
#   'if you don’t want to have to work very hard or deliver any impact._x000d_',
#   'Not Recommended',
#   'Recommended',
#   'Not Recommended',
#   152),
#  ('18 May 2022 ',
#   ' Anonymous Employee',
#   'Former Employee',
#   ' more than 3 years',
#   '_x000d_',
#   'Not Recommended',
#   'Recommended',
#   'Not Recommended',
#   152),
#  ('18 May 2022 ',
#   ' Anonymous Employee',
#   'Former Employee',
#   ' more than 3 years',
#   'ceo is good',
#   'Not Recommended',
#   'Recommended',
#   'Not Recommended',
#   152),
#  ('18 May 2022 ',
#   ' Managing Director',
#   'Current Employee',
#   ' more than 8 years',
#   'flexible work arrangements, future oriented, customer oriented',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   153),
#  ('18 May 2022 ',
#   ' Assistant Manager',
#   'Current Employee',
#   ' more than 5 years',
#   'best office timings and culture',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   154),
#  ('18 May 2022 ',
#   ' Business Analyst',
#   'Current Contractor',
#   ' more than 1 year',
#   'seniors and managers in the dept very helpful and manage their expectations_x000d_',
#   'Recommended',
#   'Not Recommended',
#   'Recommended',
#   155),
#  ('18 May 2022 ',
#   ' Business Analyst',
#   'Current Contractor',
#   ' more than 1 year',
#   'great team with the learning process_x000d_',
#   'Recommended',
#   'Not Recommended',
#   'Recommended',
#   155),
#  ('18 May 2022 ',
#   ' Business Analyst',
#   'Current Contractor',
#   ' more than 1 year',
#   'overtime happens only once a while (ie development and testing phases)',
#   'Recommended',
#   'Not Recommended',
#   'Recommended',
#   155),
#  ('18 May 2022 ',
#   ' Vice President',
#   'Former Employee',
#   nan,
#   'trying to grow and trying to incorporate more minor benefits for employees to feel engaged.',
#   'Neutral',
#   'Not Recommended',
#   'Neutral',
#   156),
#  ('17 May 2022 ',
#   ' Project Manager',
#   'Current Employee',
#   nan,
#   'good annual pay and increment',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   157),
#  ('17 May 2022 ',
#   ' Product Manager',
#   'Current Employee',
#   nan,
#   'normal salary    more work less paid',
#   'Neutral',
#   'Not Recommended',
#   'Neutral',
#   158),
#  ('17 May 2022 ',
#   ' Production Specialist',
#   'Current Employee',
#   ' less than 1 year',
#   'lot of new technologies to learn_x000d_',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   159),
#  ('17 May 2022 ',
#   ' Production Specialist',
#   'Current Employee',
#   ' less than 1 year',
#   'if you need challenges dbs is for you',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   159),
#  ('17 May 2022 ',
#   ' Assistant Relationship Manager',
#   'Former Employee',
#   ' more than 5 years',
#   'good work life balance although steep learning curve for new joiners',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   160),
#  ('17 May 2022 ',
#   ' AVP-Project Manager',
#   'Former Employee',
#   nan,
#   'aggressive working culture and env',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   161),
#  ('16 May 2022 ',
#   ' Analyst',
#   'Former Employee',
#   ' more than 1 year',
#   'good learning growth and lots of opportunity',
#   'Not Recommended',
#   'Neutral',
#   'Recommended',
#   162),
#  ('16 May 2022 ',
#   ' Product Manager',
#   'Current Employee',
#   ' more than 10 years',
#   'good place',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   163),
#  ('16 May 2022 ',
#   ' Product Manager',
#   'Current Employee',
#   ' more than 10 years',
#   'supporting hr teams.',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   163),
#  ('16 May 2022 ',
#   ' Customer Service Officer',
#   'Former Employee',
#   ' less than 1 year',
#   "routine, mostly no brainer's jobs",
#   'Not Recommended',
#   'Not Recommended',
#   'Not Recommended',
#   164),
#  ('16 May 2022 ',
#   ' Business Analyst',
#   'Current Employee',
#   nan,
#   'good job prospect, career and role',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   165),
#  ('15 May 2022 ',
#   ' Anonymous Employee',
#   'Former Employee',
#   nan,
#   'good company benefits, like medical.',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   166),
#  ('15 May 2022 ',
#   ' Applications Developer',
#   'Current Employee',
#   ' more than 1 year',
#   'best work place for any one to be part of',
#   'Recommended',
#   'Recommended',
#   'Not Recommended',
#   167),
#  ('14 May 2022 ',
#   ' Anonymous Employee',
#   'Current Employee',
#   ' more than 8 years',
#   'colleagues are genuine and sincere',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   168),
#  ('14 May 2022 ',
#   ' Anonymous Employee',
#   'Current Employee',
#   ' more than 8 years',
# ...
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   584),
#  ('15 Feb 2022 ',
#   ' Vice President',
#   'Current Employee',
#   nan,
#   'excellent infrastructure and exposure to game changing technologies',
#   'Recommended',
#   'Neutral',
#   'Recommended',
#   585),
#  ('15 Feb 2022 ',
#   ' Vice President',
#   'Current Employee',
#   nan,
#   'flexible working model',
#   'Recommended',
#   'Neutral',
#   'Recommended',
#   585),
#  ('15 Feb 2022 ',
#   ' Vice President',
#   'Current Employee',
#   nan,
#   'reasonable monetary benefits',
#   'Recommended',
#   'Neutral',
#   'Recommended',
#   585),
#  ('15 Feb 2022 ',
#   ' SVP-Technology',
#   'Former Employee',
#   nan,
#   'good environment and culture for staff',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   586),
#  ('15 Feb 2022 ',
#   ' Trainee',
#   'Former Contractor',
#   ' less than 1 year',
#   '- a step into banks_x000d_',
#   'Not Recommended',
#   'Not Recommended',
#   'Recommended',
#   587),
#  ('15 Feb 2022 ',
#   ' Trainee',
#   'Former Contractor',
#   ' less than 1 year',
#   '- nice office area (cbd)_x000d_',
#   'Not Recommended',
#   'Not Recommended',
#   'Recommended',
#   587),
#  ('15 Feb 2022 ',
#   ' Trainee',
#   'Former Contractor',
#   ' less than 1 year',
#   '- depends on your team, teammates might be okay',
#   'Not Recommended',
#   'Not Recommended',
#   'Recommended',
#   587),
#  ('15 Feb 2022 ',
#   ' Risk Analyst',
#   'Current Employee',
#   nan,
#   'good pay and working from home arrangements',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   588),
#  ('15 Feb 2022 ',
#   ' Anonymous Employee',
#   'Current Employee',
#   ' more than 3 years',
#   'good pay',
#   'Not Recommended',
#   'Recommended',
#   'Recommended',
#   589),
#  ('15 Feb 2022 ',
#   ' Anonymous Employee',
#   'Current Employee',
#   ' more than 3 years',
#   'decent work hours',
#   'Not Recommended',
#   'Recommended',
#   'Recommended',
#   589),
#  ('15 Feb 2022 ',
#   ' Anonymous Employee',
#   'Current Employee',
#   ' more than 3 years',
#   'excellent ceo',
#   'Not Recommended',
#   'Recommended',
#   'Recommended',
#   589),
#  ('14 Feb 2022 ',
#   ' Anonymous Contractor',
#   'Current Contractor',
#   nan,
#   'opportunity to learn different tech stacks',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   590),
#  ('14 Feb 2022 ',
#   ' Anonymous Employee',
#   'Current Employee',
#   ' more than 3 years',
#   'stable with good staff benefits',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   591),
#  ('14 Feb 2022 ',
#   ' Associate Engineer',
#   'Former Employee',
#   ' less than 1 year',
#   'good place for work._x000d_',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   592),
#  ('14 Feb 2022 ',
#   ' Associate Engineer',
#   'Former Employee',
#   ' less than 1 year',
#   'different opportunities you can get to work on_x000d_',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   592),
#  ('14 Feb 2022 ',
#   ' Associate Engineer',
#   'Former Employee',
#   ' less than 1 year',
#   'you can work on the latest technology stack._x000d_',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   592),
#  ('14 Feb 2022 ',
#   ' Associate Engineer',
#   'Former Employee',
#   ' less than 1 year',
#   'a lot more to learn.',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   592),
#  ('14 Feb 2022 ',
#   ' Relationship Manager',
#   'Former Employee',
#   ' more than 3 years',
#   'no reason unless you count taka vouchers',
#   'Not Recommended',
#   'Not Recommended',
#   'Neutral',
#   593),
#  ('14 Feb 2022 ',
#   ' Relationship Manager',
#   'Former Employee',
#   ' more than 3 years',
#   'but then again i heard they scrapped that.',
#   'Not Recommended',
#   'Not Recommended',
#   'Neutral',
#   593),
#  ('14 Feb 2022 ',
#   ' Anonymous Employee',
#   'Current Employee',
#   ' more than 1 year',
#   'lots of learning opportunity provided',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   594),
#  ('14 Feb 2022 ',
#   ' Financial Representative',
#   'Current Employee',
#   ' more than 10 years',
#   'good people - mid to junior management _x000d_',
#   'Not Recommended',
#   'Recommended',
#   'Recommended',
#   595),
#  ('14 Feb 2022 ',
#   ' Financial Representative',
#   'Current Employee',
#   ' more than 10 years',
#   'good technology_x000d_',
#   'Not Recommended',
#   'Recommended',
#   'Recommended',
#   595),
#  ('14 Feb 2022 ',
#   ' Financial Representative',
#   'Current Employee',
#   ' more than 10 years',
#   'good digital transformation_x000d_',
#   'Not Recommended',
#   'Recommended',
#   'Recommended',
#   595),
#  ('14 Feb 2022 ',
#   ' Financial Representative',
#   'Current Employee',
#   ' more than 10 years',
#   'generally good compensation for the average rank and file staff',
#   'Not Recommended',
#   'Recommended',
#   'Recommended',
#   595),
#  ('13 Feb 2022 ',
#   ' AVP-IT',
#   'Former Employee',
#   ' more than 5 years',
#   'brand recognition, office furniture is well equipped',
#   'Neutral',
#   'Recommended',
#   'Neutral',
#   596),
#  ('13 Feb 2022 ',
#   ' DBS Bank',
#   'Current Employee',
#   ' more than 1 year',
#   'i learned a lot as i joined dbs as a fresher',
#   'Recommended',
#   'Recommended',
#   'Neutral',
#   597),
#  ('13 Feb 2022 ',
#   ' Assistant Relationship Manager Private Banking',
#   'Current Employee',
#   ' more than 10 years',
#   'good system and nice people to work with',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   598),
#  ('13 Feb 2022 ',
#   ' Wealth Planning Manager',
#   'Current Employee',
#   ' less than 1 year',
#   'reputable bank _x000d_',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   599),
#  ('13 Feb 2022 ',
#   ' Wealth Planning Manager',
#   'Current Employee',
#   ' less than 1 year',
#   'a large number of leads_x000d_',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   599),
#  ('13 Feb 2022 ',
#   ' Wealth Planning Manager',
#   'Current Employee',
#   ' less than 1 year',
#   'structured training, teammates and seniors to get help from as a newbie_x000d_',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   599),
#  ('13 Feb 2022 ',
#   ' Wealth Planning Manager',
#   'Current Employee',
#   ' less than 1 year',
#   'a great stepping stone for your career',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   599),
#  ('12 Feb 2022 ',
#   ' Vice President',
#   'Former Employee',
#   ' more than 3 years',
#   'encourages collaboration across the bank and teams',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   600),
#  ('12 Feb 2022 ',
#   ' Deputy Head of Department',
#   'Current Employee',
#   nan,
#   'growing company with funds to invest in growth areas.',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   601),
#  ('12 Feb 2022 ',
#   ' Software Engineer',
#   'Current Employee',
#   nan,
#   'many events, bonuses, good colleague , expose to many international team',
#   'Not Recommended',
#   'Neutral',
#   'Neutral',
#   602),
#  ('12 Feb 2022 ',
#   ' Head of Sales',
#   'Current Employee',
#   nan,
#   'market leader',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   603),
#  ('12 Feb 2022 ',
#   ' Head of Sales',
#   'Current Employee',
#   nan,
#   'wide array of products for clients',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   603),
#  ('12 Feb 2022 ',
#   ' Head of Sales',
#   'Current Employee',
#   nan,
#   'international reach',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   603),
#  ('11 Feb 2022 ',
#   ' Data Analyst',
#   'Former Employee',
#   ' more than 1 year',
#   'good culture in the team',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   604),
#  ('11 Feb 2022 ',
#   ' Analyst',
#   'Current Employee',
#   ' more than 3 years',
#   'great work life balance for everyone',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   605),
#  ('11 Feb 2022 ',
#   ' Customer Service Representative',
#   'Current Employee',
#   ' less than 1 year',
#   'great caring colleagues and benefits',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   606),
#  ('11 Feb 2022 ',
#   ' Technology Analyst',
#   'Current Employee',
#   ' more than 1 year',
#   'good people and less pressure',
#   'Recommended',
#   'Recommended',
#   'Neutral',
#   607),
#  ('11 Feb 2022 ',
#   ' Research Assistant',
#   'Current Employee',
#   nan,
#   'salary is decent compared to other banks.',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   608),
#  ('10 Feb 2022 ',
#   ' Operations',
#   'Current Employee',
#   ' more than 3 years',
#   'good teammates',
#   'Not Recommended',
#   'Not Recommended',
#   'Recommended',
#   609),
#  ('10 Feb 2022 ',
#   ' Operations',
#   'Current Employee',
#   ' more than 3 years',
#   'benefits were okay.',
#   'Not Recommended',
#   'Not Recommended',
#   'Recommended',
#   609),
#  ('10 Feb 2022 ',
#   ' Vice President',
#   'Current Employee',
#   nan,
#   'one of the most forward looking local banks',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   610),
#  ('10 Feb 2022 ',
#   ' Analyst',
#   'Current Employee',
#   ' more than 3 years',
#   '- dbs offers a high package for attracting people initially_x000d_',
#   'Not Recommended',
#   'Neutral',
#   'Not Recommended',
#   611),
#  ('10 Feb 2022 ',
#   ' Analyst',
#   'Current Employee',
#   ' more than 3 years',
#   '- good market value in the market but no hikes for the employee._x000d_',
#   'Not Recommended',
#   'Neutral',
#   'Not Recommended',
#   611),
#  ('10 Feb 2022 ',
#   ' Analyst',
#   'Current Employee',
#   ' more than 3 years',
#   "- i am happy to be working under a green field project where i got to learn otherwise it's mostly maintenance of the system.",
#   'Not Recommended',
#   'Neutral',
#   'Not Recommended',
#   611),
#  ('10 Feb 2022 ',
#   ' Branch Manager Vice President',
#   'Former Employee',
#   ' more than 5 years',
#   'willing to invest in infrastructure',
#   'Recommended',
#   'Not Recommended',
#   'Neutral',
#   612),
#  ('9 Feb 2022 ',
#   ' Business Analyst',
#   'Former Employee',
#   ' less than 1 year',
#   'it’s a good company to work in',
#   'Not Recommended',
#   'Neutral',
#   'Not Recommended',
#   613),
#  ('9 Feb 2022 ',
#   ' Anonymous Contractor',
#   'Former Contractor',
#   ' more than 5 years',
#   'new tech stack_x000d_',
#   'Not Recommended',
#   'Recommended',
#   'Neutral',
#   614),
#  ('9 Feb 2022 ',
#   ' Anonymous Contractor',
#   'Former Contractor',
#   ' more than 5 years',
#   'lot of challenging problems to solve',
#   'Not Recommended',
#   'Recommended',
#   'Neutral',
#   614),
#  ('9 Feb 2022 ',
#   ' Developer',
#   'Current Employee',
#   nan,
#   "it's in singapore, that's the plus",
#   'Recommended',
#   'Neutral',
#   'Recommended',
#   615),
#  ('9 Feb 2022 ',
#   ' Wealth Planning Manager',
#   'Current Employee',
#   ' more than 1 year',
#   'good work life balance if have good sales',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   616),
#  ('9 Feb 2022 ',
#   ' Managing Director',
#   'Current Employee',
#   nan,
#   'good culture - good package',
#   'Recommended',
#   'Neutral',
#   'Neutral',
#   617),
#  ('9 Feb 2022 ',
#   ' Software Engineer',
#   'Current Employee',
#   ' more than 1 year',
#   'good pay, nice bosses and friendly colleagues, many leaves._x000d_',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   618),
#  ('9 Feb 2022 ',
#   ' Software Engineer',
#   'Current Employee',
#   ' more than 1 year',
#   'flexibility to work from home during this pandemic.',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   618),
#  ('9 Feb 2022 ',
#   ' Administrative Assistant',
#   'Former Employee',
#   nan,
#   'great innovation and fun loving colleagues',
#   'Neutral',
#   'Neutral',
#   'Neutral',
#   619),
#  ('9 Feb 2022 ',
#   ' Contract Staff',
#   'Former Contractor',
#   ' more than 1 year',
#   '- angpao to collect during cny_x000d_',
#   'Not Recommended',
#   'Recommended',
#   'Not Recommended',
#   620),
#  ('9 Feb 2022 ',
#   ' Contract Staff',
#   'Former Contractor',
#   ' more than 1 year',
#   '- received $50 foodpanda vouchers for annual d&d_x000d_',
#   'Not Recommended',
#   'Recommended',
#   'Not Recommended',
#   620),
#  ('9 Feb 2022 ',
#   ' Contract Staff',
#   'Former Contractor',
#   ' more than 1 year',
#   '- department sent goodies to our house during covid period_x000d_',
#   'Not Recommended',
#   'Recommended',
#   'Not Recommended',
#   620),
#  ('9 Feb 2022 ',
#   ' Contract Staff',
#   'Former Contractor',
#   ' more than 1 year',
#   '- training courses are available to upgrade our skills_x000d_',
#   'Not Recommended',
#   'Recommended',
#   'Not Recommended',
#   620),
#  ('9 Feb 2022 ',
#   ' Contract Staff',
#   'Former Contractor',
#   ' more than 1 year',
#   "- good location to work as it's cbd area_x000d_",
#   'Not Recommended',
#   'Recommended',
#   'Not Recommended',
#   620),
#  ('9 Feb 2022 ',
#   ' Contract Staff',
#   'Former Contractor',
#   ' more than 1 year',
#   '- work ends at 5pm on friday (but wait.',
#   'Not Recommended',
#   'Recommended',
#   'Not Recommended',
#   620),
#  ('9 Feb 2022 ',
#   ' Contract Staff',
#   'Former Contractor',
#   ' more than 1 year',
#   'this is actually a con)_x000d_',
#   'Not Recommended',
#   'Recommended',
#   'Not Recommended',
#   620),
#  ('9 Feb 2022 ',
#   ' Contract Staff',
#   'Former Contractor',
#   ' more than 1 year',
#   '- ability to wfh from 2019 to end 2021',
#   'Not Recommended',
#   'Recommended',
#   'Not Recommended',
#   620),
#  ('9 Feb 2022 ',
#   ' Associate',
#   'Former Contractor',
#   ' less than 1 year',
#   'brand name',
#   'Not Recommended',
#   'Neutral',
#   'Recommended',
#   621),
#  ('9 Feb 2022 ',
#   ' Associate',
#   'Former Contractor',
#   ' less than 1 year',
#   'this will look good on your cv.',
#   'Not Recommended',
#   'Neutral',
#   'Recommended',
#   621),
#  ('9 Feb 2022 ',
#   ' Associate',
#   'Former Contractor',
#   ' less than 1 year',
#   'competitive salary, good employee benefits',
#   'Not Recommended',
#   'Neutral',
#   'Recommended',
#   621),
#  ('9 Feb 2022 ',
#   ' Associate',
#   'Former Contractor',
#   ' less than 1 year',
#   '',
#   'Not Recommended',
#   'Neutral',
#   'Recommended',
#   621),
#  ('9 Feb 2022 ',
#   ' Associate',
#   'Former Contractor',
#   ' less than 1 year',
#   'that’s it’s',
#   'Not Recommended',
#   'Neutral',
#   'Recommended',
#   621),
#  ('9 Feb 2022 ',
#   ' Associate',
#   'Former Contractor',
#   ' less than 1 year',
#   'for high salary, brand name and employee benefits, you sacrifice your mental health and have to work like crazy.',
#   'Not Recommended',
#   'Neutral',
#   'Recommended',
#   621),
#  ('9 Feb 2022 ',
#   ' Anonymous Employee',
#   'Current Employee',
#   ' more than 1 year',
#   'good culture and working environment',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   622),
#  ('8 Feb 2022 ',
#   ' Change Management Coordinator',
#   'Former Contractor',
#   ' more than 1 year',
#   'benefits of direct contract are the same of permanent staff',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   623),
#  ('8 Feb 2022 ',
#   ' Anonymous Employee',
#   'Current Employee',
#   ' more than 1 year',
#   'family business - good place to retire for svp',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   624),
#  ('8 Feb 2022 ',
#   ' Software Developer',
#   'Former Employee',
#   ' more than 1 year',
#   'managers are willing to listen and work with juniors',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   625),
#  ('7 Feb 2022 ',
#   ' Software Engineer',
#   'Current Employee',
#   ' more than 1 year',
#   'great guidance_x000d_',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   626),
#  ('7 Feb 2022 ',
#   ' Software Engineer',
#   'Current Employee',
#   ' more than 1 year',
#   'good work life balance_x000d_',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   626),
#  ('7 Feb 2022 ',
#   ' Software Engineer',
#   'Current Employee',
#   ' more than 1 year',
#   'empowered to try new things',
#   'Recommended',
#   'Recommended',
#   'Recommended',
#   626),
#  ('7 Feb 2022 ',
#   ' Associate',
#   'Current Employee',
#   ' more than 3 years',
#   'no cuttings in salary_x000d_',
#   'Not Recommended',
#   'Recommended',
#   'Not Recommended',
#   627),
#  ('7 Feb 2022 ',
#   ' Associate',
#   'Current Employee',
#   ' more than 3 years',
#   'infrastructure_x000d_',
#   'Not Recommended',
#   'Recommended',
#   'Not Recommended',
#   627),
#  ('7 Feb 2022 ',
#   ' Associate',
#   'Current Employee',
#   ' more than 3 years',
#   'good stack_x000d_',
#   'Not Recommended',
#   'Recommended',
#   'Not Recommended',
#   627),
#  ('7 Feb 2022 ',
#   ' Associate',
#   'Current Employee',
#   ' more than 3 years',
#   'help from colleagues_x000d_',
#   'Not Recommended',
#   'Recommended',
#   'Not Recommended',
#   627),
#  ('7 Feb 2022 ',
#   ' Associate',
#   'Current Employee',
#   ' more than 3 years',
#   'benefits like iflex point 25 k , itq points',
#   'Not Recommended',
#   'Recommended',
#   'Not Recommended',
#   627),
#  ('7 Feb 2022 ',
#   ' CyberSecurity Engineer',
#   'Current Employee',
#   ' more than 3 years',
#   'good pay and carrer progression',
#   'Neutral',
#   'Recommended',
#   'Neutral',
#   628),
#  ...]

# %%
# date, occupation, employee_status, duration, cons, recommended_or_not,\
#                                      ceo_approval, business_outlook, index
pros_and_idx_lis_df = pd.DataFrame(pros_and_idx_lis2, columns = ['Date', 'Occupation', 'Employee Status', 'Duration', 'Pros',\
                                                                 'Recommended Or Not', 'CEO Approval', 'Business Outlook', 'Review Index'])
cons_and_idx_lis_df = pd.DataFrame(cons_and_idx_lis2, columns = ['Date', 'Occupation', 'Employee Status', 'Duration', 'Cons',\
                                                                 'Recommended Or Not', 'CEO Approval', 'Business Outlook', 'Review Index'])
pros_and_idx_lis_df
# Out:
#               Date             Occupation    Employee Status  \
# 0     27 Jun 2022       Software Engineer   Current Employee
# 1     27 Jun 2022        Senior Associate   Current Employee
# 2     27 Jun 2022        Senior Associate   Current Employee
# 3     27 Jun 2022     Senior Data Analyst  Former Contractor
# 4     27 Jun 2022      Graduate Associate   Current Employee
# ...            ...                    ...                ...
# 7682  22 Aug 2008    Vice President - DII    Former Employee
# 7683  22 Aug 2008    Vice President - DII    Former Employee
# 7684  22 Aug 2008    Vice President - DII    Former Employee
# 7685  22 Aug 2008    Vice President - DII    Former Employee
# 7686  22 Aug 2008    Vice President - DII    Former Employee
#
#                 Duration                                               Pros  \
# 0      more than 5 years                  good work life balance and salary
# 1                    NaN              annual leave granted per year is good
# 2                    NaN            infrastructure is good and the ambience
# 3       more than 1 year  opportunities to work on interesting and chall...
# 4       more than 1 year              you get exposed to multiple skillsets
# ...                  ...                                                ...
# 7682                 NaN  people on the outside think it is a good place...
# 7683                 NaN  it is also well repected name to have on the r...
# 7684                 NaN            senior managemnt is usually top calibre
# 7685                 NaN  i assume as a glc they do have to hire well at...
# 7686                 NaN  it is an ok place for new grad, but you must g...
#
#      Recommended Or Not CEO Approval Business Outlook  Review Index
# 0           Recommended  Recommended      Recommended             0
# 1               Neutral      Neutral          Neutral             1
# 2       Not Recommended      Neutral          Neutral             2
# 3               Neutral      Neutral          Neutral             3
# 4               Neutral      Neutral          Neutral             4
# ...                 ...          ...              ...           ...
# 7682    Not Recommended      Neutral          Neutral          4597
# 7683    Not Recommended      Neutral          Neutral          4597
# 7684    Not Recommended      Neutral          Neutral          4597
# 7685    Not Recommended      Neutral          Neutral          4597
# 7686    Not Recommended      Neutral          Neutral          4597
#
# [7687 rows x 9 columns]

# %% [markdown]
# ### Preprocessing all Pros and Cons
# Steps done for preprocessing:
# - Remove new lines and tabs
# - Expand Contractions
# - Remove white space
# - Remove special characters (E.g., Emoji's)
# - Lower case
#
# Will not be doing the following for pre-processing:
# - Lemmatisation
# - Removing stop words
# - Making corrections to spelling

# %%
pros_and_idx_lis_df['Pros'] = pros_and_idx_lis_df['Pros'].apply(remove_newlines_tabs)
cons_and_idx_lis_df['Cons'] = cons_and_idx_lis_df['Cons'].apply(remove_newlines_tabs)

pros_and_idx_lis_df['Pros'] = pros_and_idx_lis_df['Pros'].apply(expand_contractions).apply(remove_whitespace).apply(removing_special_characters)#.apply(joining)
cons_and_idx_lis_df['Cons'] = cons_and_idx_lis_df['Cons'].apply(expand_contractions).apply(remove_whitespace).apply(removing_special_characters)#.apply(joining)

# %%
pros_and_idx_lis_df
# Out:
#               Date             Occupation    Employee Status  \
# 0     27 Jun 2022       Software Engineer   Current Employee
# 1     27 Jun 2022        Senior Associate   Current Employee
# 2     27 Jun 2022        Senior Associate   Current Employee
# 3     27 Jun 2022     Senior Data Analyst  Former Contractor
# 4     27 Jun 2022      Graduate Associate   Current Employee
# ...            ...                    ...                ...
# 7682  22 Aug 2008    Vice President - DII    Former Employee
# 7683  22 Aug 2008    Vice President - DII    Former Employee
# 7684  22 Aug 2008    Vice President - DII    Former Employee
# 7685  22 Aug 2008    Vice President - DII    Former Employee
# 7686  22 Aug 2008    Vice President - DII    Former Employee
#
#                 Duration                                               Pros  \
# 0      more than 5 years                  good work life balance and salary
# 1                    NaN              annual leave granted per year is good
# 2                    NaN            infrastructure is good and the ambience
# 3       more than 1 year  opportunities to work on interesting and chall...
# 4       more than 1 year              you get exposed to multiple skillsets
# ...                  ...                                                ...
# 7682                 NaN  people on the outside think it is a good place...
# 7683                 NaN  it is also well repected name to have on the r...
# 7684                 NaN            senior managemnt is usually top calibre
# 7685                 NaN  i assume as a glc they do have to hire well at...
# 7686                 NaN  it is an ok place for new grad, but you must g...
#
#      Recommended Or Not CEO Approval Business Outlook  Review Index
# 0           Recommended  Recommended      Recommended             0
# 1               Neutral      Neutral          Neutral             1
# 2       Not Recommended      Neutral          Neutral             2
# 3               Neutral      Neutral          Neutral             3
# 4               Neutral      Neutral          Neutral             4
# ...                 ...          ...              ...           ...
# 7682    Not Recommended      Neutral          Neutral          4597
# 7683    Not Recommended      Neutral          Neutral          4597
# 7684    Not Recommended      Neutral          Neutral          4597
# 7685    Not Recommended      Neutral          Neutral          4597
# 7686    Not Recommended      Neutral          Neutral          4597
#
# [7687 rows x 9 columns]

# %% [markdown]
# ### Make sure that serial number is distinct for all verbatims
#
# Would be better to use 2 dp instead of 1dp for the serial number since certain verbatims take up more than 10 rows once the verbatim has been split based on new line/ exclamation mark, etc

# %%
pros_and_idx_lis_df['Increment'] = pd.DataFrame([0.01] * len(pros_and_idx_lis_df))
for i in range(len(pros_and_idx_lis_df)-1):
    if pros_and_idx_lis_df.loc[i+1, 'Review Index'] == pros_and_idx_lis_df.loc[i, 'Review Index']:
        pros_and_idx_lis_df.loc[i+1, 'Increment'] += pros_and_idx_lis_df.loc[i, 'Increment']
pros_and_idx_lis_df['Serial Number'] = pros_and_idx_lis_df['Review Index'] + pros_and_idx_lis_df['Increment']
pros_and_idx_lis_df = pros_and_idx_lis_df.drop(['Review Index', 'Increment'], axis=1)
pros_and_idx_lis_df
# Out:
#               Date             Occupation    Employee Status  \
# 0     27 Jun 2022       Software Engineer   Current Employee
# 1     27 Jun 2022        Senior Associate   Current Employee
# 2     27 Jun 2022        Senior Associate   Current Employee
# 3     27 Jun 2022     Senior Data Analyst  Former Contractor
# 4     27 Jun 2022      Graduate Associate   Current Employee
# ...            ...                    ...                ...
# 7682  22 Aug 2008    Vice President - DII    Former Employee
# 7683  22 Aug 2008    Vice President - DII    Former Employee
# 7684  22 Aug 2008    Vice President - DII    Former Employee
# 7685  22 Aug 2008    Vice President - DII    Former Employee
# 7686  22 Aug 2008    Vice President - DII    Former Employee
#
#                 Duration                                               Pros  \
# 0      more than 5 years                  good work life balance and salary
# 1                    NaN              annual leave granted per year is good
# 2                    NaN            infrastructure is good and the ambience
# 3       more than 1 year  opportunities to work on interesting and chall...
# 4       more than 1 year              you get exposed to multiple skillsets
# ...                  ...                                                ...
# 7682                 NaN  people on the outside think it is a good place...
# 7683                 NaN  it is also well repected name to have on the r...
# 7684                 NaN            senior managemnt is usually top calibre
# 7685                 NaN  i assume as a glc they do have to hire well at...
# 7686                 NaN  it is an ok place for new grad, but you must g...
#
#      Recommended Or Not CEO Approval Business Outlook  Serial Number
# 0           Recommended  Recommended      Recommended           0.01
# 1               Neutral      Neutral          Neutral           1.01
# 2       Not Recommended      Neutral          Neutral           2.01
# 3               Neutral      Neutral          Neutral           3.01
# 4               Neutral      Neutral          Neutral           4.01
# ...                 ...          ...              ...            ...
# 7682    Not Recommended      Neutral          Neutral        4597.02
# 7683    Not Recommended      Neutral          Neutral        4597.03
# 7684    Not Recommended      Neutral          Neutral        4597.04
# 7685    Not Recommended      Neutral          Neutral        4597.05
# 7686    Not Recommended      Neutral          Neutral        4597.06
#
# [7687 rows x 9 columns]

# %%
pros_and_idx_lis_df['Pros'] = pros_and_idx_lis_df['Pros'].apply(removing_x000d)

# %%
pros_and_idx_lis_df.to_excel('../Employee Reviews/DBS Reviews/All DBS Reviews/DBS_pros_reviews.xlsx', index=False)

# %%
pros_and_idx_lis_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7687 entries, 0 to 7686
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                7687 non-null   object
#  1   Occupation          7687 non-null   object
#  2   Employee Status     7687 non-null   object
#  3   Duration            4841 non-null   object
#  4   Pros                7687 non-null   object
#  5   Recommended Or Not  7687 non-null   object
#  6   CEO Approval        7687 non-null   object
#  7   Business Outlook    7687 non-null   object
#  8   Serial Number       7687 non-null   float64
# dtypes: float64(1), object(8)
# memory usage: 540.6+ KB

# %%
cons_and_idx_lis_df['Increment'] = pd.DataFrame([0.01] * len(cons_and_idx_lis_df))
for i in range(len(cons_and_idx_lis_df)-1):
    if cons_and_idx_lis_df.loc[i+1, 'Review Index'] == cons_and_idx_lis_df.loc[i, 'Review Index']:
        cons_and_idx_lis_df.loc[i+1, 'Increment'] += cons_and_idx_lis_df.loc[i, 'Increment']
cons_and_idx_lis_df['Serial Number'] = cons_and_idx_lis_df['Review Index'] + cons_and_idx_lis_df['Increment']
cons_and_idx_lis_df = cons_and_idx_lis_df.drop(['Review Index', 'Increment'], axis=1)
cons_and_idx_lis_df
# Out:
#               Date             Occupation   Employee Status  \
# 0     27 Jun 2022       Software Engineer  Current Employee
# 1     27 Jun 2022        Senior Associate  Current Employee
# 2     27 Jun 2022        Senior Associate  Current Employee
# 3     27 Jun 2022        Senior Associate  Current Employee
# 4     27 Jun 2022        Senior Associate  Current Employee
# ...            ...                    ...               ...
# 8371  22 Aug 2008    Vice President - DII   Former Employee
# 8372  22 Aug 2008    Vice President - DII   Former Employee
# 8373  22 Aug 2008    Vice President - DII   Former Employee
# 8374  22 Aug 2008    Vice President - DII   Former Employee
# 8375  22 Aug 2008    Vice President - DII   Former Employee
#
#                 Duration                                               Cons  \
# 0      more than 5 years  hierarchical, does not listen to feedback from...
# 1                    NaN  number of carry forward leave allow is too little
# 2                    NaN                              no work life balance.
# 3                    NaN  managers force to work from office..they say s...
# 4                    NaN  no desks cabin for seating..feels like call ce...
# ...                  ...                                                ...
# 8371                 NaN       the middle management is overall farily poor
# 8372                 NaN  middle management at dbs then to hoard informa...
# 8373                 NaN   cronisim and boys club mentatliy in middle ma...
# 8374                 NaN  if you can get away with it you can hide in th...
# 8375                 NaN      as such, there is alot of dead old wood here.
#
#      Recommended Or Not CEO Approval Business Outlook  Serial Number
# 0           Recommended  Recommended      Recommended           0.01
# 1               Neutral      Neutral          Neutral           1.01
# 2       Not Recommended      Neutral          Neutral           2.01
# 3       Not Recommended      Neutral          Neutral           2.02
# 4       Not Recommended      Neutral          Neutral           2.03
# ...                 ...          ...              ...            ...
# 8371    Not Recommended      Neutral          Neutral        4597.02
# 8372    Not Recommended      Neutral          Neutral        4597.03
# 8373    Not Recommended      Neutral          Neutral        4597.04
# 8374    Not Recommended      Neutral          Neutral        4597.05
# 8375    Not Recommended      Neutral          Neutral        4597.06
#
# [8376 rows x 9 columns]

# %%
cons_and_idx_lis_df['Cons'] = cons_and_idx_lis_df['Cons'].apply(removing_x000d)

# %%
cons_and_idx_lis_df.to_excel('../Employee Reviews/DBS Reviews/All DBS Reviews/DBS_cons_reviews.xlsx', index=False)
